# %%
import pandas as pd
import json
from IPython.display import display, HTML

# --- Configuration ---
# Set the file paths for your detailed metric files
FINE_TUNED_FILE = 'evaluation_results_per_entry_AYA_23_SFT.tsv'
FEW_SHOT_FILE = 'metrics_detailed_aya-101_few_shot.tsv'
TEXT_OUTPUT_FILE = 'qualitative_analysis_output.txt'
JSONL_OUTPUT_FILE = 'qualitative_analysis_output.jsonl'

# Number of top definitions to select for analysis
N_SAMPLES = 10

def load_and_prepare_data(file_path, model_type):
    """
    Loads, cleans, and scores a model's result file.
    """
    try:
        df = pd.read_csv(file_path, sep='\t')
    except FileNotFoundError:
        print(f"Error: File not found at '{file_path}'. Please check the file path.")
        return None

    # Standardize column names
    if model_type == 'fine-tuned':
        df = df.rename(columns={'model_prediction': 'cleaned_prediction'})
        df['raw_output'] = df['cleaned_prediction']
    elif model_type == 'few-shot':
        df = df.rename(columns={
            'model_prediction': 'raw_output',
            'model_long_definition': 'cleaned_prediction'
        })
    
    # Ensure score columns are numeric and create combined score
    score_cols = ['comet22_score', 'xcomet_score']
    for col in score_cols:
        df[col] = pd.to_numeric(df[col], errors='coerce')
    df.dropna(subset=score_cols, inplace=True)
    df['combined_score'] = df['comet22_score'] + df['xcomet_score']
    
    return df

def get_final_comparison_list(sft_df, fs_df, n_samples):
    """
    Creates a final list of N*2 unique items for comparison, handling overlaps
    and tracking which model triggered each sample's inclusion.
    """
    # --- Stratum 1 Logic: Filter and Rank ---
    sft_decision_pool = sft_df[
        sft_df['cleaned_prediction'].str.strip().str.lower() != sft_df['DefinitionFull'].str.strip().str.lower()
    ].copy().sort_values(by='combined_score', ascending=False)
    
    fs_decision_pool = fs_df[
        fs_df['cleaned_prediction'].str.strip().str.lower() != fs_df['DefinitionFull'].str.strip().str.lower()
    ].copy().sort_values(by='combined_score', ascending=False)

    # --- Manual Exclusion List ---
    lemmas_to_exclude = [
        'er glijdt een schaduw over iemands gezicht',
        'homohaat'
    ]
    print(f"Excluding {len(lemmas_to_exclude)} specific lemmas from the 'Aya 101 (Few-Shot)' pool.")
    fs_decision_pool = fs_decision_pool[~fs_decision_pool['Lemma'].isin(lemmas_to_exclude)]

    sft_top = sft_decision_pool.head(n_samples + 1)
    fs_top = fs_decision_pool.head(n_samples + 1)
    
    # --- Overlap Check and Resolution ---
    sft_top_dict = {
        tuple(row[['Lemma', 'DefinitionShort']]): row['combined_score']
        for _, row in sft_top.head(n_samples).iterrows()
    }
    fs_top_dict = {
        tuple(row[['Lemma', 'DefinitionShort']]): row['combined_score']
        for _, row in fs_top.head(n_samples).iterrows()
    }

    sft_top_ids = set(sft_top_dict.keys())
    fs_top_ids = set(fs_top_dict.keys())
    
    overlap = sft_top_ids.intersection(fs_top_ids)
    print("--- OVERLAP ANALYSIS ---")
    print(f"Number of overlapping items in the top {n_samples} lists: {len(overlap)}")
    if len(overlap) > 0:
        print("Overlapping items:", overlap)

    final_item_ids = {}
    for item_id, score in sft_top_dict.items():
        final_item_ids[item_id] = ("Aya 23 (Fine-Tuned)", score)
    for item_id, score in fs_top_dict.items():
        if item_id not in final_item_ids:
            final_item_ids[item_id] = ("Aya 101 (Few-Shot)", score)

    if len(final_item_ids) < n_samples * 2 and len(sft_top) > n_samples and len(fs_top) > n_samples:
        sft_11th_item = sft_top.iloc[n_samples]
        fs_11th_item = fs_top.iloc[n_samples]
        
        sft_11th_id = tuple(sft_11th_item[['Lemma', 'DefinitionShort']])
        fs_11th_id = tuple(fs_11th_item[['Lemma', 'DefinitionShort']])
        
        print("\nResolving overlap to get more unique samples...")
        print(f"  Fine-Tuned 11th score: {sft_11th_item['combined_score']:.4f}")
        print(f"  Few-Shot 11th score:   {fs_11th_item['combined_score']:.4f}")
        
        if sft_11th_item['combined_score'] >= fs_11th_item['combined_score']:
            if sft_11th_id not in final_item_ids:
                final_item_ids[sft_11th_id] = ("Aya 23 (Fine-Tuned)", sft_11th_item['combined_score'])
                print("  -> Added 11th best from Fine-Tuned model.")
        else:
            if fs_11th_id not in final_item_ids:
                final_item_ids[fs_11th_id] = ("Aya 101 (Few-Shot)", fs_11th_item['combined_score'])
                print("  -> Added 11th best from Few-Shot model.")

    print(f"Total unique items for analysis: {len(final_item_ids)}")
    print("-" * 26 + "\n")
    
    # --- Build Final Comparison Data ---
    sft_indexed = sft_df.set_index(['Lemma', 'DefinitionShort']).sort_index()
    fs_indexed = fs_df.set_index(['Lemma', 'DefinitionShort']).sort_index()
    
    final_results = []
    for (lemma, short_def), (decision_model, trigger_score) in final_item_ids.items():
        try:
            sft_row = sft_indexed.loc[(lemma, short_def)]
            fs_row = fs_indexed.loc[(lemma, short_def)]
            if isinstance(sft_row, pd.DataFrame): sft_row = sft_row.iloc[0]
            if isinstance(fs_row, pd.DataFrame): fs_row = fs_row.iloc[0]
            
            final_results.append({
                'lemma': lemma,
                'short_def': short_def,
                'decision_model': decision_model,
                'trigger_score': trigger_score,
                'sft_row': sft_row,
                'fs_row': fs_row
            })
        except KeyError:
            print(f"Warning: Could not find match for Lemma='{lemma}' in both files. Skipping.")
            
    return final_results, len(final_item_ids), len(overlap)


def display_and_save_samples(results, sft_model_name, fs_model_name, text_file_handle, jsonl_file_handle):
    """Displays the results and saves them to the provided file handles."""
    
    def write_to_text_file(text):
        """Helper function to print to console and write to text file."""
        print(text)
        text_file_handle.write(text + '\n')

    if not results:
        write_to_text_file(f"No comparative samples to display.")
        return
        
    display(HTML(f"<h2>{len(results)} Unique Samples for Stratum 2 Analysis</h2>"))
    text_file_handle.write(f"--- {len(results)} UNIQUE SAMPLES FOR ANALYSIS (sorted by trigger score) ---\n\n")

    for i, item in enumerate(results):
        sft_row, fs_row = item['sft_row'], item['fs_row']
        lemma, short_def = item['lemma'], item['short_def']
        decision_model = item['decision_model']
        trigger_score = item['trigger_score']
        
        # --- Create JSON object for this sample ---
        json_record = {
            "rank": i + 1,
            "lemma": lemma,
            "source_definition": short_def,
            "reference_definition": sft_row['DefinitionFull'],
            "triggered_by": {
                "model": decision_model,
                "combined_score": round(trigger_score, 4)
            },
            "fine_tuned_output": {
                "model_name": sft_model_name,
                "prediction": sft_row['cleaned_prediction'],
                "comet22_score": round(sft_row['comet22_score'], 4),
                "xcomet_score": round(sft_row['xcomet_score'], 4)
            },
            "few_shot_output": {
                "model_name": fs_model_name,
                "prediction_cleaned": fs_row['cleaned_prediction'],
                "prediction_raw": fs_row['raw_output'],
                "comet22_score": round(fs_row['comet22_score'], 4),
                "xcomet_score": round(fs_row['xcomet_score'], 4)
            }
        }
        jsonl_file_handle.write(json.dumps(json_record) + '\n')

        # --- Write to human-readable text file ---
        write_to_text_file("=" * 80)
        write_to_text_file(f"COMPARISON SAMPLE #{i + 1} (Overall Rank)")
        write_to_text_file("-" * 80)
        write_to_text_file(f"Triggered by High Score from: {decision_model} (Score: {trigger_score:.4f})")
        write_to_text_file(f"Lemma: {lemma}")
        write_to_text_file(f"Source (Short Definition): {short_def}")
        write_to_text_file(f"Reference (Full Definition): {sft_row['DefinitionFull']}")
        write_to_text_file("-" * 80)
        
        write_to_text_file(f"Output from {sft_model_name}:")
        write_to_text_file(f"  Scores: COMET-22 = {sft_row['comet22_score']:.4f}, XCOMET = {sft_row['xcomet_score']:.4f}")
        write_to_text_file(f"  Prediction (Cleaned): {sft_row['cleaned_prediction']}\n")
        
        write_to_text_file(f"Output from {fs_model_name}:")
        write_to_text_file(f"  Scores: COMET-22 = {fs_row['comet22_score']:.4f}, XCOMET = {fs_row['xcomet_score']:.4f}")
        if 'raw_output' in fs_row and fs_row['raw_output'] != fs_row['cleaned_prediction']:
             write_to_text_file(f"  Raw Output: {fs_row['raw_output']}")
        write_to_text_file(f"  Prediction (Cleaned): {fs_row['cleaned_prediction']}\n")
    write_to_text_file("\n\n")

# --- Main Execution ---
sft_df_full = load_and_prepare_data(FINE_TUNED_FILE, 'fine-tuned')
fs_df_full = load_and_prepare_data(FEW_SHOT_FILE, 'few-shot')

if sft_df_full is not None and fs_df_full is not None:
    final_results, total_samples, overlap_count = get_final_comparison_list(sft_df_full, fs_df_full, N_SAMPLES)
    
    final_results.sort(key=lambda x: x['trigger_score'], reverse=True)
    
    with open(TEXT_OUTPUT_FILE, 'w', encoding='utf-8') as txt_f, \
         open(JSONL_OUTPUT_FILE, 'w', encoding='utf-8') as jsonl_f:
        
        summary_text = (
            "--- QUALITATIVE ANALYSIS SAMPLES ---\n\n"
            "--- OVERLAP ANALYSIS SUMMARY ---\n"
            f"Initial top {N_SAMPLES} lists had {overlap_count} overlapping item(s).\n"
            f"Final unique items for analysis: {total_samples}\n"
            "------------------------------\n\n"
        )
        txt_f.write(summary_text)
        
        display_and_save_samples(
            final_results, 
            "Aya 23 (Fine-Tuned)", 
            "Aya 101 (Few-Shot)", 
            txt_f, 
            jsonl_f
        )

    print(f"\n✅ Analysis complete. Output saved to '{TEXT_OUTPUT_FILE}' and '{JSONL_OUTPUT_FILE}'")
# Out:
# Excluding 2 specific lemmas from the 'Aya 101 (Few-Shot)' pool.
# --- OVERLAP ANALYSIS ---
# Number of overlapping items in the top 10 lists: 1
# Overlapping items: {('eenoudergezin', 'gezin met één ouder')}
#
# Resolving overlap to get more unique samples...
#   Fine-Tuned 11th score: 1.9343
#   Few-Shot 11th score:   1.9556
#   -> Added 11th best from Few-Shot model.
# Total unique items for analysis: 20
# --------------------------
# <h2>20 Unique Samples for Stratum 2 Analysis</h2>
# ================================================================================
# COMPARISON SAMPLE #1 (Overall Rank)
# --------------------------------------------------------------------------------
# Triggered by High Score from: Aya 101 (Few-Shot) (Score: 1.9766)
# Lemma: liefhebber
# Source (Short Definition): iemand die veel van iets of iemand houdt
# Reference (Full Definition): iemand die iets of iemand heel leuk of mooi vindt
# --------------------------------------------------------------------------------
# Output from Aya 23 (Fine-Tuned):
#   Scores: COMET-22 = 0.8541, XCOMET = 0.9623
#   Prediction (Cleaned): iemand die veel van iets of iemand houdt
#
# Output from Aya 101 (Few-Shot):
#   Scores: COMET-22 = 0.9766, XCOMET = 1.0000
#   Raw Output: Lange definitie: iemand die iets of iemand heel leuk of mooi vindt.
#   Prediction (Cleaned): iemand die iets of iemand heel leuk of mooi vindt.
#
# ================================================================================
# COMPARISON SAMPLE #2 (Overall Rank)
# --------------------------------------------------------------------------------
# Triggered by High Score from: Aya 101 (Few-Shot) (Score: 1.9740)
# Lemma: lichtgroen
# Source (Short Definition): met een lichtgroene kleur
# Reference (Full Definition): een lichtgroene kleur hebbend
# --------------------------------------------------------------------------------
# Output from Aya 23 (Fine-Tuned):
#   Scores: COMET-22 = 0.9853, XCOMET = 0.9508
#   Prediction (Cleaned): een lichtgroene kleur hebbend
#
# Output from Aya 101 (Few-Shot):
#   Scores: COMET-22 = 0.9740, XCOMET = 1.0000
#   Prediction (Cleaned): Een lichtgroene kleur hebbend.
#
# ================================================================================
# COMPARISON SAMPLE #3 (Overall Rank)
# --------------------------------------------------------------------------------
# Triggered by High Score from: Aya 101 (Few-Shot) (Score: 1.9704)
# Lemma: zeefdruk
# Source (Short Definition): afdruk door zeefdruktechniek
# Reference (Full Definition): afdruk vervaardigd door de zeefdruktechniek
# --------------------------------------------------------------------------------
# Output from Aya 23 (Fine-Tuned):
#   Scores: COMET-22 = 0.9544, XCOMET = 0.9681
#   Prediction (Cleaned): afdruk vervaardigd volgens de zeefdruktechniek
#
# Output from Aya 101 (Few-Shot):
#   Scores: COMET-22 = 0.9704, XCOMET = 1.0000
#   Raw Output: Lange definitie: afdruk vervaardigd door zeefdruktechniek
#   Prediction (Cleaned): afdruk vervaardigd door zeefdruktechniek
#
# ================================================================================
# COMPARISON SAMPLE #4 (Overall Rank)
# --------------------------------------------------------------------------------
# Triggered by High Score from: Aya 101 (Few-Shot) (Score: 1.9658)
# Lemma: ecoroman
# Source (Short Definition): roman over milieuproblematiek
# Reference (Full Definition): roman die over milieuproblematiek of andere milieuvraagstukken gaat
# --------------------------------------------------------------------------------
# Output from Aya 23 (Fine-Tuned):
#   Scores: COMET-22 = 0.8813, XCOMET = 0.9449
#   Prediction (Cleaned): roman waarin milieuproblematiek centraal staat
#
# Output from Aya 101 (Few-Shot):
#   Scores: COMET-22 = 0.9658, XCOMET = 1.0000
#   Raw Output: Lange definitie: roman die over milieuproblematiek en andere milieuvraagstukken gaat
#   Prediction (Cleaned): roman die over milieuproblematiek en andere milieuvraagstukken gaat
#
# ================================================================================
# COMPARISON SAMPLE #5 (Overall Rank)
# --------------------------------------------------------------------------------
# Triggered by High Score from: Aya 101 (Few-Shot) (Score: 1.9635)
# Lemma: muzikante
# Source (Short Definition): vrouwelijke muzikant
# Reference (Full Definition): vrouw die muziek maakt voor haar beroep of uit liefhebberij
# --------------------------------------------------------------------------------
# Output from Aya 23 (Fine-Tuned):
#   Scores: COMET-22 = 0.9550, XCOMET = 0.9643
#   Prediction (Cleaned): vrouw die muziek maakt, voor haar beroep of uit liefhebberij
#
# Output from Aya 101 (Few-Shot):
#   Scores: COMET-22 = 0.9652, XCOMET = 0.9983
#   Raw Output: Lange definitie: vrouw die voor haar beroep of uit liefhebberij muziek maakt
#   Prediction (Cleaned): vrouw die voor haar beroep of uit liefhebberij muziek maakt
#
# ================================================================================
# COMPARISON SAMPLE #6 (Overall Rank)
# --------------------------------------------------------------------------------
# Triggered by High Score from: Aya 101 (Few-Shot) (Score: 1.9611)
# Lemma: Wageningse
# Source (Short Definition): vrouw uit Wageningen
# Reference (Full Definition): vrouw die afkomstig is uit Wageningen
# --------------------------------------------------------------------------------
# Output from Aya 23 (Fine-Tuned):
#   Scores: COMET-22 = 0.9810, XCOMET = 0.9591
#   Prediction (Cleaned): vrouw die afkomstig is uit Wageningen
#
# Output from Aya 101 (Few-Shot):
#   Scores: COMET-22 = 0.9611, XCOMET = 1.0000
#   Prediction (Cleaned): vrouw die afkomstig is uit de gemeente Wageningen
#
# ================================================================================
# COMPARISON SAMPLE #7 (Overall Rank)
# --------------------------------------------------------------------------------
# Triggered by High Score from: Aya 101 (Few-Shot) (Score: 1.9592)
# Lemma: horeca-exploitant
# Source (Short Definition): uitbater van een horecabedrijf
# Reference (Full Definition): iemand die voor zijn beroep een horecabedrijf uitbaat
# --------------------------------------------------------------------------------
# Output from Aya 23 (Fine-Tuned):
#   Scores: COMET-22 = 0.9770, XCOMET = 0.9775
#   Prediction (Cleaned): iemand die voor zijn beroep een horecabedrijf uitbaat
#
# Output from Aya 101 (Few-Shot):
#   Scores: COMET-22 = 0.9592, XCOMET = 1.0000
#   Prediction (Cleaned): iemand die voor zijn beroep een horecabedrijf exploiteert
#
# ================================================================================
# COMPARISON SAMPLE #8 (Overall Rank)
# --------------------------------------------------------------------------------
# Triggered by High Score from: Aya 23 (Fine-Tuned) (Score: 1.9572)
# Lemma: beroepsvereniging
# Source (Short Definition): belangenvereniging van mensen met hetzelfde beroep
# Reference (Full Definition): vereniging van personen die hetzelfde beroep uitoefenen en gezamenlijk opkomen voor hun belangen
# --------------------------------------------------------------------------------
# Output from Aya 23 (Fine-Tuned):
#   Scores: COMET-22 = 0.9662, XCOMET = 0.9910
#   Prediction (Cleaned): vereniging van mensen die hetzelfde beroep uitoefenen en gezamenlijk opkomen voor hun belangen
#
# Output from Aya 101 (Few-Shot):
#   Scores: COMET-22 = 0.9348, XCOMET = 1.0000
#   Raw Output: Lange definitie: vereniging van personen met hetzelfde beroep die gezamenlijk opkomen voor hun belangen
#   Prediction (Cleaned): vereniging van personen met hetzelfde beroep die gezamenlijk opkomen voor hun belangen
#
# ================================================================================
# COMPARISON SAMPLE #9 (Overall Rank)
# --------------------------------------------------------------------------------
# Triggered by High Score from: Aya 101 (Few-Shot) (Score: 1.9571)
# Lemma: groepsspreekuur
# Source (Short Definition): spreekuur voor meer patiënten
# Reference (Full Definition): spreekuur waarbij meer patiënten met een gelijksoortige, vaak chronische aandoening tegelijkertijd geholpen worden
# --------------------------------------------------------------------------------
# Output from Aya 23 (Fine-Tuned):
#   Scores: COMET-22 = 0.7783, XCOMET = 0.9274
#   Prediction (Cleaned): spreekuur dat wordt gehouden door een arts voor een aantal patiënten die dezelfde klacht of ziekte hebben
#
# Output from Aya 101 (Few-Shot):
#   Scores: COMET-22 = 0.9590, XCOMET = 0.9981
#   Prediction (Cleaned): spreekuur waarbij meer patiënten met een gelijksoortige, vaak chronische, aandoening tegelijkertijd geholpen worden
#
# ================================================================================
# COMPARISON SAMPLE #10 (Overall Rank)
# --------------------------------------------------------------------------------
# Triggered by High Score from: Aya 101 (Few-Shot) (Score: 1.9559)
# Lemma: lifestylecoach
# Source (Short Definition): coach voor lifestyle
# Reference (Full Definition): iemand die mensen advies geeft op het gebied van voeding en beweging
# --------------------------------------------------------------------------------
# Output from Aya 23 (Fine-Tuned):
#   Scores: COMET-22 = 0.8382, XCOMET = 0.8794
#   Prediction (Cleaned): coach die mensen adviseert en begeleidt op het gebied van hun leefstijl
#
# Output from Aya 101 (Few-Shot):
#   Scores: COMET-22 = 0.9608, XCOMET = 0.9951
#   Raw Output: Lange definitie: iemand die mensen advies geeft op het gebied van voeding en beweging.
#   Prediction (Cleaned): iemand die mensen advies geeft op het gebied van voeding en beweging.
#
# ================================================================================
# COMPARISON SAMPLE #11 (Overall Rank)
# --------------------------------------------------------------------------------
# Triggered by High Score from: Aya 101 (Few-Shot) (Score: 1.9556)
# Lemma: meisjesmeisje
# Source (Short Definition): zeer meisjesachtig meisje
# Reference (Full Definition): meisje dat zich zeer meisjesachtig gedraagt en kleedt
# --------------------------------------------------------------------------------
# Output from Aya 23 (Fine-Tuned):
#   Scores: COMET-22 = 0.6646, XCOMET = 0.9105
#   Prediction (Cleaned): meisje dat zeer meisjesachtig is
#
# Output from Aya 101 (Few-Shot):
#   Scores: COMET-22 = 0.9583, XCOMET = 0.9973
#   Prediction (Cleaned): Een meisje dat zich zeer meisjesachtig gedraagt en kleedt.
#
# ================================================================================
# COMPARISON SAMPLE #12 (Overall Rank)
# --------------------------------------------------------------------------------
# Triggered by High Score from: Aya 23 (Fine-Tuned) (Score: 1.9541)
# Lemma: eenoudergezin
# Source (Short Definition): gezin met één ouder
# Reference (Full Definition): gezin dat bestaat uit één ouder met een of meer kinderen
# --------------------------------------------------------------------------------
# Output from Aya 23 (Fine-Tuned):
#   Scores: COMET-22 = 0.9694, XCOMET = 0.9847
#   Prediction (Cleaned): gezin dat bestaat uit één ouder en een of meer kinderen
#
# Output from Aya 101 (Few-Shot):
#   Scores: COMET-22 = 0.9727, XCOMET = 1.0000
#   Raw Output: Lange definitie: gezin dat bestaat uit één ouder en een of meer kinderen
#   Prediction (Cleaned): gezin dat bestaat uit één ouder en een of meer kinderen
#
# ================================================================================
# COMPARISON SAMPLE #13 (Overall Rank)
# --------------------------------------------------------------------------------
# Triggered by High Score from: Aya 23 (Fine-Tuned) (Score: 1.9541)
# Lemma: roetschade
# Source (Short Definition): schade door roet
# Reference (Full Definition): schade die veroorzaakt wordt door roet
# --------------------------------------------------------------------------------
# Output from Aya 23 (Fine-Tuned):
#   Scores: COMET-22 = 0.9762, XCOMET = 0.9778
#   Prediction (Cleaned): schade die wordt veroorzaakt door roet
#
# Output from Aya 101 (Few-Shot):
#   Scores: COMET-22 = 0.9533, XCOMET = 1.0000
#   Raw Output: Lange definitie: schade veroorzaakt door roet.
#   Prediction (Cleaned): schade veroorzaakt door roet.
#
# ================================================================================
# COMPARISON SAMPLE #14 (Overall Rank)
# --------------------------------------------------------------------------------
# Triggered by High Score from: Aya 23 (Fine-Tuned) (Score: 1.9431)
# Lemma: poëziewedstrijd
# Source (Short Definition): wedstrijd in het schrijven van gedichten
# Reference (Full Definition): wedstrijd waarbij de deelnemers een gedicht schrijven en een jury bepaalt wie daarin het beste is geslaagd
# --------------------------------------------------------------------------------
# Output from Aya 23 (Fine-Tuned):
#   Scores: COMET-22 = 0.9695, XCOMET = 0.9736
#   Prediction (Cleaned): wedstrijd waarbij de deelnemers een gedicht schrijven en een jury bepaalt wie daarin het beste geslaagd is
#
# Output from Aya 101 (Few-Shot):
#   Scores: COMET-22 = 0.7641, XCOMET = 0.9431
#   Raw Output: Lange definitie: poëziewedstrijd is een wedstrijd in het schrijven van gedichten.
#   Prediction (Cleaned): poëziewedstrijd is een wedstrijd in het schrijven van gedichten.
#
# ================================================================================
# COMPARISON SAMPLE #15 (Overall Rank)
# --------------------------------------------------------------------------------
# Triggered by High Score from: Aya 23 (Fine-Tuned) (Score: 1.9406)
# Lemma: trouwplanner
# Source (Short Definition): iemand die bruiloften organiseert
# Reference (Full Definition): iemand die zich voor zijn beroep bezighoudt met de organisatie van bruiloften
# --------------------------------------------------------------------------------
# Output from Aya 23 (Fine-Tuned):
#   Scores: COMET-22 = 0.9607, XCOMET = 0.9799
#   Prediction (Cleaned): iemand die zich voor zijn beroep bezighoudt met het organiseren van bruiloften
#
# Output from Aya 101 (Few-Shot):
#   Scores: COMET-22 = 0.7330, XCOMET = 1.0000
#   Prediction (Cleaned): Een trouwplanner is iemand die bruiloften organiseert.
#
# ================================================================================
# COMPARISON SAMPLE #16 (Overall Rank)
# --------------------------------------------------------------------------------
# Triggered by High Score from: Aya 23 (Fine-Tuned) (Score: 1.9401)
# Lemma: staalproduct
# Source (Short Definition): product van staal
# Reference (Full Definition): product waarin staal de belangrijkste grondstof is
# --------------------------------------------------------------------------------
# Output from Aya 23 (Fine-Tuned):
#   Scores: COMET-22 = 0.9716, XCOMET = 0.9685
#   Prediction (Cleaned): product waarvan staal de belangrijkste grondstof is
#
# Output from Aya 101 (Few-Shot):
#   Scores: COMET-22 = 0.9818, XCOMET = 1.0000
#   Prediction (Cleaned): Product waarin staal de belangrijkste grondstof is
#
# ================================================================================
# COMPARISON SAMPLE #17 (Overall Rank)
# --------------------------------------------------------------------------------
# Triggered by High Score from: Aya 23 (Fine-Tuned) (Score: 1.9366)
# Lemma: benoemingstermijn
# Source (Short Definition): termijn waarvoor iemand benoemd wordt
# Reference (Full Definition): termijn waarvoor iemand in een bepaalde functie benoemd wordt
# --------------------------------------------------------------------------------
# Output from Aya 23 (Fine-Tuned):
#   Scores: COMET-22 = 0.9562, XCOMET = 0.9804
#   Prediction (Cleaned): termijn waarvoor iemand voor een functie of ambt wordt benoemd
#
# Output from Aya 101 (Few-Shot):
#   Scores: COMET-22 = 0.9632, XCOMET = 0.9854
#   Raw Output: Lange definitie: termijn waarvoor iemand benoemd wordt
#   Prediction (Cleaned): termijn waarvoor iemand benoemd wordt
#
# ================================================================================
# COMPARISON SAMPLE #18 (Overall Rank)
# --------------------------------------------------------------------------------
# Triggered by High Score from: Aya 23 (Fine-Tuned) (Score: 1.9347)
# Lemma: dorpswinkelier
# Source (Short Definition): uitbater van een dorpswinkel
# Reference (Full Definition): iemand die voor zijn beroep de dorpswinkel uitbaat
# --------------------------------------------------------------------------------
# Output from Aya 23 (Fine-Tuned):
#   Scores: COMET-22 = 0.9581, XCOMET = 0.9766
#   Prediction (Cleaned): iemand die voor zijn beroep een dorpswinkel uitbaat
#
# Output from Aya 101 (Few-Shot):
#   Scores: COMET-22 = 0.9227, XCOMET = 0.9997
#   Prediction (Cleaned): iemand die voor zijn beroep of als vrijwilliger een dorpswinkel uitbaat
#
# ================================================================================
# COMPARISON SAMPLE #19 (Overall Rank)
# --------------------------------------------------------------------------------
# Triggered by High Score from: Aya 23 (Fine-Tuned) (Score: 1.9344)
# Lemma: aspergerobot
# Source (Short Definition): machine om asperges te oogsten
# Reference (Full Definition): machine die gebruikt wordt om asperges te oogsten
# --------------------------------------------------------------------------------
# Output from Aya 23 (Fine-Tuned):
#   Scores: COMET-22 = 0.9661, XCOMET = 0.9683
#   Prediction (Cleaned): machine die wordt gebruikt om asperges te oogsten
#
# Output from Aya 101 (Few-Shot):
#   Scores: COMET-22 = 0.8457, XCOMET = 0.9385
#   Prediction (Cleaned): Aspergerobot: machine om asperges te oogsten
#
# ================================================================================
# COMPARISON SAMPLE #20 (Overall Rank)
# --------------------------------------------------------------------------------
# Triggered by High Score from: Aya 23 (Fine-Tuned) (Score: 1.9343)
# Lemma: kleutertuin
# Source (Short Definition): gebouw van een kleutertuin
# Reference (Full Definition): gebouw waarin een kleutertuin is gehuisvest
# --------------------------------------------------------------------------------
# Output from Aya 23 (Fine-Tuned):
#   Scores: COMET-22 = 0.9653, XCOMET = 0.9690
#   Prediction (Cleaned): gebouw waarin een kleutertuin gehuisvest is
#
# Output from Aya 101 (Few-Shot):
#   Scores: COMET-22 = 0.7124, XCOMET = 0.9687
#   Prediction (Cleaned): Een kleutertuin is een kinderdagverblijf of peuterspeelzaal voor kinderen van 0 tot 5 jaar.
#
#
#
#
#
# ✅ Analysis complete. Output saved to 'qualitative_analysis_output.txt' and 'qualitative_analysis_output.jsonl'

# %%
import pandas as pd
import json
from IPython.display import display, HTML

# --- Configuration ---
# Define paths for all model result and prompt files.
FINE_TUNED_FILE = 'evaluation_results_per_entry_AYA_23_SFT.tsv'
FEW_SHOT_FILE = 'metrics_detailed_aya-101_few_shot.tsv'
PROMPTS_FILE = 'prompts_alpha_0_8.jsonl'
TEXT_OUTPUT_FILE = 'stratum_3_analysis_output.txt'
JSONL_OUTPUT_FILE = 'stratum_3_analysis_output.jsonl'


# Define the Genus Proxima groups and the specific lemmas you want to analyze.
# This structure allows for precise selection.
STRATUM_3_SELECTION = {
    "liefhebber": [], # Will be auto-populated, then the word 'liefhebber' will be excluded.
    "ologie": [      # A filled list means: only use these specific lemmas for this group.
        'hematologie',
        'nefrologie',
        'pneumologie'
    ]
}


def load_few_shot_prompts(prompts_path):
    """Loads the few-shot examples from the JSONL file into a lookup dictionary."""
    prompts_lookup = {}
    try:
        with open(prompts_path, 'r', encoding='utf-8') as f:
            for line in f:
                record = json.loads(line)
                key = (record['lemma'], record['short_definition'])
                examples = [
                    record.get('few_shot_example_1'),
                    record.get('few_shot_example_2'),
                    record.get('few_shot_example_3')
                ]
                prompts_lookup[key] = [ex for ex in examples if ex is not None]
        print(f"Successfully loaded {len(prompts_lookup)} few-shot prompts.")
    except FileNotFoundError:
        print(f"Warning: Prompts file not found at '{prompts_path}'. Few-shot examples will not be displayed.")
    except Exception as e:
        print(f"An error occurred loading prompts file: {e}")
    return prompts_lookup


def load_and_prepare_data(sft_path, fs_path):
    """Loads and merges the full data from both model result files."""
    # Load Fine-Tuned Data
    sft_df = pd.read_csv(sft_path, sep='\t')
    sft_df = sft_df.rename(columns={
        'model_prediction': 'sft_prediction',
        'comet22_score': 'sft_comet22_score',
        'xcomet_score': 'sft_xcomet_score'
    })
    sft_df['sft_combined_score'] = pd.to_numeric(sft_df['sft_comet22_score'], errors='coerce') + \
                                   pd.to_numeric(sft_df['sft_xcomet_score'], errors='coerce')
    sft_df = sft_df[['Lemma', 'DefinitionShort', 'DefinitionFull', 'sft_prediction', 'sft_comet22_score', 'sft_xcomet_score', 'sft_combined_score']]

    # Load Few-Shot Data
    fs_df = pd.read_csv(fs_path, sep='\t')
    fs_df = fs_df.rename(columns={
        'model_long_definition': 'fs_prediction', 
        'model_prediction': 'fs_raw_prediction',
        'comet22_score': 'fs_comet22_score',
        'xcomet_score': 'fs_xcomet_score'
    })
    fs_df['fs_combined_score'] = pd.to_numeric(fs_df['fs_comet22_score'], errors='coerce') + \
                                 pd.to_numeric(fs_df['fs_xcomet_score'], errors='coerce')
    fs_df = fs_df[['Lemma', 'DefinitionShort', 'fs_prediction', 'fs_raw_prediction', 'fs_comet22_score', 'fs_xcomet_score', 'fs_combined_score']]

    # Merge the two dataframes
    merged_df = pd.merge(sft_df, fs_df, on=['Lemma', 'DefinitionShort'], how='inner')
    merged_df.drop_duplicates(subset=['Lemma', 'DefinitionShort'], inplace=True)
    
    return merged_df

def display_and_save_stratum_3(selection, data_df, prompts_data, txt_handle, jsonl_handle):
    """
    Finds, displays, and saves the detailed comparisons for the selected Stratum 3 groups.
    """
    def write_to_text_file(text):
        print(text)
        txt_handle.write(text + '\n')

    display(HTML("<h2>Detailed Comparisons for Selected Stratum 3 Groups</h2>"))
    txt_handle.write("--- DETAILED COMPARISONS FOR SELECTED STRATUM 3 GROUPS ---\n\n")

    for suffix, group_lemmas in selection.items():
        write_to_text_file("=" * 80)
        write_to_text_file(f"Genus Proxima: '{suffix}'")
        write_to_text_file("=" * 80)
        
        group_df = data_df[data_df['Lemma'].isin(group_lemmas)].sort_values(by='Lemma')
        
        if group_df.empty:
            write_to_text_file("No matching lemmas found in the test set for this group.\n")
            continue

        for _, row in group_df.iterrows():
            lookup_key = (row['Lemma'], row['DefinitionShort'])
            examples = prompts_data.get(lookup_key, [])

            # --- Create JSON object for this sample ---
            json_record = {
                "genus_proxima": suffix,
                "lemma": row['Lemma'],
                "source_definition": row['DefinitionShort'],
                "reference_definition": row['DefinitionFull'],
                "fine_tuned_output": {
                    "model_name": "Aya 23 (Fine-Tuned)",
                    "prediction": row['sft_prediction'],
                    "comet22_score": round(row['sft_comet22_score'], 4) if pd.notna(row['sft_comet22_score']) else None,
                    "xcomet_score": round(row['sft_xcomet_score'], 4) if pd.notna(row['sft_xcomet_score']) else None,
                    "combined_score": round(row['sft_combined_score'], 4) if pd.notna(row['sft_combined_score']) else None
                },
                "few_shot_output": {
                    "model_name": "Aya 101 (Few-Shot)",
                    "prediction_cleaned": row['fs_prediction'],
                    "prediction_raw": row['fs_raw_prediction'],
                    "comet22_score": round(row['fs_comet22_score'], 4) if pd.notna(row['fs_comet22_score']) else None,
                    "xcomet_score": round(row['fs_xcomet_score'], 4) if pd.notna(row['fs_xcomet_score']) else None,
                    "combined_score": round(row['fs_combined_score'], 4) if pd.notna(row['fs_combined_score']) else None,
                    "examples_used": [
                        {
                            "lemma": ex.get('lemma'),
                            "short_definition": ex.get('short_definition'),
                            "long_definition": ex.get('long_definition')
                        } for ex in examples
                    ]
                }
            }
            jsonl_handle.write(json.dumps(json_record) + '\n')

            # --- Write to human-readable text file ---
            write_to_text_file("-" * 60)
            write_to_text_file(f"Lemma: {row['Lemma']}")
            write_to_text_file(f"Source (Short Definition): {row['DefinitionShort']}")
            write_to_text_file(f"Reference (Full Definition): {row['DefinitionFull']}")
            write_to_text_file("-" * 60)

            sft_score_str = f"COMET-22: {row['sft_comet22_score']:.4f}, XCOMET: {row['sft_xcomet_score']:.4f}" if pd.notna(row['sft_combined_score']) else "N/A"
            write_to_text_file(f"Output from Aya 23 (Fine-Tuned) (Scores: {sft_score_str}):")
            write_to_text_file(f"  -> {row['sft_prediction']}\n")

            fs_score_str = f"COMET-22: {row['fs_comet22_score']:.4f}, XCOMET: {row['fs_xcomet_score']:.4f}" if pd.notna(row['fs_combined_score']) else "N/A"
            write_to_text_file(f"Output from Aya 101 (Few-Shot) (Scores: {fs_score_str}):")
            if row['fs_raw_prediction'] != row['fs_prediction']:
                write_to_text_file(f"  Raw: {row['fs_raw_prediction']}")
            write_to_text_file(f"  -> {row['fs_prediction']}\n")

            if examples:
                write_to_text_file("--- Few-Shot Examples Used for This Entry ---")
                for idx, ex in enumerate(examples):
                    write_to_text_file(f"  Example {idx+1}:")
                    write_to_text_file(f"    Lemma: {ex.get('lemma')}")
                    write_to_text_file(f"    Short: {ex.get('short_definition')}")
                    write_to_text_file(f"    Long:  {ex.get('long_definition')}")
                write_to_text_file("-" * 45)
        write_to_text_file("\n")


# --- Main Execution ---
print("--- Stratum 3: Detailed View of Selected Genus Proxima Groups ---")
try:
    # Load all data
    full_data_df = load_and_prepare_data(FINE_TUNED_FILE, FEW_SHOT_FILE)
    prompts_data = load_few_shot_prompts(PROMPTS_FILE)
    print(f"Successfully loaded {len(full_data_df)} unique entries for lookup.")

    # Find all lemmas that match the auto-detect groups (where the list is empty)
    for suffix, lemmas in STRATUM_3_SELECTION.items():
        if not lemmas:
            matching_lemmas = full_data_df[full_data_df['Lemma'].str.endswith(suffix)]['Lemma'].unique().tolist()
            STRATUM_3_SELECTION[suffix] = matching_lemmas
            print(f"Found {len(matching_lemmas)} lemmas for Genus Proxima '{suffix}'.")

    # Apply Manual Exclusions
    if 'liefhebber' in STRATUM_3_SELECTION:
        print("Excluding the lemma 'liefhebber' from its own group.")
        STRATUM_3_SELECTION['liefhebber'] = [l for l in STRATUM_3_SELECTION['liefhebber'] if l != 'liefhebber']

    # Open files and generate output
    with open(TEXT_OUTPUT_FILE, 'w', encoding='utf-8') as txt_f, \
         open(JSONL_OUTPUT_FILE, 'w', encoding='utf-8') as jsonl_f:
        
        display_and_save_stratum_3(STRATUM_3_SELECTION, full_data_df, prompts_data, txt_f, jsonl_f)

    print(f"\n✅ Analysis complete. Output saved to '{TEXT_OUTPUT_FILE}' and '{JSONL_OUTPUT_FILE}'")

except FileNotFoundError:
    print(f"Error: Could not find one of the required files.")
    print(f"Please ensure all .tsv and .jsonl files are in the same directory.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# --- Stratum 3: Detailed View of Selected Genus Proxima Groups ---
# Successfully loaded 3446 few-shot prompts.
# Successfully loaded 3446 unique entries for lookup.
# Found 5 lemmas for Genus Proxima 'liefhebber'.
# Excluding the lemma 'liefhebber' from its own group.
# <h2>Detailed Comparisons for Selected Stratum 3 Groups</h2>
# ================================================================================
# Genus Proxima: 'liefhebber'
# ================================================================================
# ------------------------------------------------------------
# Lemma: operaliefhebber
# Source (Short Definition): liefhebber van operamuziek
# Reference (Full Definition): iemand die veel van het spelen van en/of het luisteren naar operamuziek houdt
# ------------------------------------------------------------
# Output from Aya 23 (Fine-Tuned) (Scores: COMET-22: 0.8390, XCOMET: 0.7690):
#   -> iemand die veel van het zingen van opera en het bijbehorende muziekgenre houdt
#
# Output from Aya 101 (Few-Shot) (Scores: COMET-22: 0.8667, XCOMET: 0.9942):
#   Raw: Lange definitie: iemand die van operamuziek houdt
#   -> iemand die van operamuziek houdt
#
# --- Few-Shot Examples Used for This Entry ---
#   Example 1:
#     Lemma: operacriticus
#     Short: iemand die opera's recenseert
#     Long:  iemand die zich, voor zijn beroep of uit liefhebberij, bezighoudt met het kritisch bespreken van opera's en opera in het algemeen, vooral in de media
#   Example 2:
#     Lemma: operadocent
#     Short: docent opera
#     Long:  docent die operales geeft
#   Example 3:
#     Lemma: klassiekemuziekliefhebber
#     Short: liefhebber van klassieke muziek
#     Long:  iemand die van het spelen van en/of het luisteren naar klassieke muziek houdt
# ---------------------------------------------
# ------------------------------------------------------------
# Lemma: sportliefhebber
# Source (Short Definition): liefhebber van sport
# Reference (Full Definition): iemand die graag sport en/of veel van het kijken naar sport houdt
# ------------------------------------------------------------
# Output from Aya 23 (Fine-Tuned) (Scores: COMET-22: 0.8610, XCOMET: 0.9684):
#   -> iemand die veel van het beoefenen of volgen van sport houdt
#
# Output from Aya 101 (Few-Shot) (Scores: COMET-22: 0.8543, XCOMET: 1.0000):
#   -> Een sportliefhebber is iemand die van sport houdt.
#
# --- Few-Shot Examples Used for This Entry ---
#   Example 1:
#     Lemma: sportlustige
#     Short: iemand met sportlust
#     Long:  iemand die sportlust heeft
#   Example 2:
#     Lemma: sportlievend
#     Short: de sport liefhebbend
#     Long:  een voorliefde voor sport hebbend
#   Example 3:
#     Lemma: sportgek
#     Short: iemand met een voorliefde voor sport
#     Long:  iemand die een grote voorliefde heeft voor sport
# ---------------------------------------------
# ------------------------------------------------------------
# Lemma: taalliefhebber
# Source (Short Definition): liefhebber van taal
# Reference (Full Definition): iemand die veel van taal houdt en daar graag over spreekt en leest
# ------------------------------------------------------------
# Output from Aya 23 (Fine-Tuned) (Scores: COMET-22: 0.8093, XCOMET: 0.9128):
#   -> iemand die veel van taal en taalgebruik houdt
#
# Output from Aya 101 (Few-Shot) (Scores: COMET-22: 0.7481, XCOMET: 0.9962):
#   Raw: Lange definitie: iemand die van taal houdt.
#   -> iemand die van taal houdt.
#
# --- Few-Shot Examples Used for This Entry ---
#   Example 1:
#     Lemma: taalkundige
#     Short: beoefenaar van de taalkunde
#     Long:  iemand die zich voor zijn beroep bezighoudt met het bestuderen en beschrijven van taal
#   Example 2:
#     Lemma: afasie
#     Short: taalstoornis
#     Long:  gedeeltelijk of geheel onvermogen om letters, woorden en zinnen te begrijpen of te produceren als gevolg van hersenletsel
#   Example 3:
#     Lemma: taalmaatje
#     Short: iemand die helpt met taal
#     Long:  iemand die een niet-moedertaalspreker van een taal helpt om zich die taal goed eigen te maken door er geregeld langs te gaan, over allerlei alledaagse zaken te praten, te helpen met het invullen van formulieren en met het bezoeken van officiële instanties, met als doel dat de niet-moedertaalspreker zich steeds beter leert te redden in de taal en het taalmaatje op den duur niet meer nodig heeft om te kunnen functioneren
# ---------------------------------------------
# ------------------------------------------------------------
# Lemma: theaterliefhebber
# Source (Short Definition): liefhebber van theater
# Reference (Full Definition): iemand die veel van het spelen en/of bijwonen van theatervoorstellingen houdt
# ------------------------------------------------------------
# Output from Aya 23 (Fine-Tuned) (Scores: COMET-22: 0.8519, XCOMET: 0.9544):
#   -> iemand die veel van het bezoeken van het theater houdt
#
# Output from Aya 101 (Few-Shot) (Scores: COMET-22: 0.9154, XCOMET: 0.8755):
#   -> iemand die veel van het kijken naar en/of spelen in toneelstukken houdt
#
# --- Few-Shot Examples Used for This Entry ---
#   Example 1:
#     Lemma: toneelliefhebber
#     Short: liefhebber van toneel
#     Long:  iemand die veel van het kijken naar en/of spelen in toneelstukken houdt
#   Example 2:
#     Lemma: theaterdier
#     Short: iemand die graag in het theater optreedt
#     Long:  iemand die zich volkomen thuis voelt op het theaterpodium
#   Example 3:
#     Lemma: theatermaker
#     Short: iemand die theater maakt
#     Long:  iemand die voor zijn beroep theatervoorstellingen maakt
# ---------------------------------------------
#
#
# ================================================================================
# Genus Proxima: 'ologie'
# ================================================================================
# ------------------------------------------------------------
# Lemma: hematologie
# Source (Short Definition): medisch specialisme voor bloedziekten
# Reference (Full Definition): medisch specialisme dat zich bezighoudt met het onderzoek, de diagnose en behandeling van bloedziekten, en aandoeningen aan de bloedvormende organen en de lymfeklieren
# ------------------------------------------------------------
# Output from Aya 23 (Fine-Tuned) (Scores: COMET-22: 0.8857, XCOMET: 0.8990):
#   -> medisch specialisme dat zich bezighoudt met de diagnose, behandeling en het onderzoek van bloedziekten en bloedstoornissen
#
# Output from Aya 101 (Few-Shot) (Scores: COMET-22: 0.9293, XCOMET: 0.9946):
#   -> Hematologie is een medisch specialisme dat zich bezighoudt met de diagnose, behandeling en onderzoek van bloedziekten en aandoeningen aan de bloedvormende organen en de lymfeklieren.
#
# --- Few-Shot Examples Used for This Entry ---
#   Example 1:
#     Lemma: hematoloog
#     Short: arts-specialist voor bloedziekten
#     Long:  arts die is gespecialiseerd in de diagnose, behandeling en het onderzoek van bloedziekten en aandoeningen aan de bloedvormende organen en de lymfeklieren
#   Example 2:
#     Lemma: reumatologie
#     Short: medisch specialisme
#     Long:  wetenschap die zich bezighoudt met het ontstaan en de behandeling van reumatische aandoeningen
#   Example 3:
#     Lemma: hematologisch
#     Short: de hematologie betreffend
#     Long:  in bijwoordelijk gebruik: uit het oogpunt van de hematologie
# ---------------------------------------------
# ------------------------------------------------------------
# Lemma: nefrologie
# Source (Short Definition): medisch specialisme voor nierziekten
# Reference (Full Definition): medisch specialisme dat zich bezighoudt met het onderzoek, de diagnose en behandeling van nierziekten
# ------------------------------------------------------------
# Output from Aya 23 (Fine-Tuned) (Scores: COMET-22: 0.9639, XCOMET: 0.9703):
#   -> medisch specialisme dat zich bezighoudt met de diagnose, behandeling en het onderzoek van nierziekten
#
# Output from Aya 101 (Few-Shot) (Scores: COMET-22: 0.9766, XCOMET: 1.0000):
#   Raw: Lange definitie: medisch specialisme dat zich bezighoudt met het onderzoek, de diagnose en behandeling van nierziekten
#   -> medisch specialisme dat zich bezighoudt met het onderzoek, de diagnose en behandeling van nierziekten
#
# --- Few-Shot Examples Used for This Entry ---
#   Example 1:
#     Lemma: nefroloog
#     Short: nierspecialist
#     Long:  internist die is gespecialiseerd in de diagnose, behandeling en het onderzoek van nierziekten
#   Example 2:
#     Lemma: reumatologie
#     Short: medisch specialisme
#     Long:  wetenschap die zich bezighoudt met het ontstaan en de behandeling van reumatische aandoeningen
#   Example 3:
#     Lemma: urologie
#     Short: geneeskunde voor urinewegen e.d.
#     Long:  medisch specialisme dat zich bezighoudt met het onderzoek, de diagnose en behandeling van uitwendige nieraandoeningen zoals nierstenen of niergezwellen en van de ziekten of afwijkingen aan het urinewegstelsel bij man of vrouw en aan de mannelijke geslachtsorganen
# ---------------------------------------------
# ------------------------------------------------------------
# Lemma: pneumologie
# Source (Short Definition): medisch specialisme voor longziekten
# Reference (Full Definition): medisch specialisme dat zich bezighoudt met het onderzoek, de diagnose en behandeling van longziekten
# ------------------------------------------------------------
# Output from Aya 23 (Fine-Tuned) (Scores: COMET-22: 0.9238, XCOMET: 0.9297):
#   -> medisch specialisme dat zich bezighoudt met de diagnose, behandeling en het onderzoek van longziekten en ademhalingsproblemen
#
# Output from Aya 101 (Few-Shot) (Scores: COMET-22: 0.7562, XCOMET: 1.0000):
#   -> Pneumologie is het medisch specialisme voor longziekten.
#
# --- Few-Shot Examples Used for This Entry ---
#   Example 1:
#     Lemma: longstayer
#     Short: patiënt op een longstayafdeling
#     Long:  iemand die langdurig op een afdeling van een psychatrische instelling, meestal een tbs-kliniek, verblijft
#   Example 2:
#     Lemma: pneumonie
#     Short: longontsteking
#     Long:  ontsteking van de longblaasjes en het longweefsel daaromheen, veroorzaakt door een bacterie, virus of ander micro-organisme, bijvoorbeeld een schimmel
#   Example 3:
#     Lemma: reumatologie
#     Short: medisch specialisme
#     Long:  wetenschap die zich bezighoudt met het ontstaan en de behandeling van reumatische aandoeningen
# ---------------------------------------------
#
#
#
# ✅ Analysis complete. Output saved to 'stratum_3_analysis_output.txt' and 'stratum_3_analysis_output.jsonl'

# %%
import pandas as pd
from collections import defaultdict
from IPython.display import display, HTML

# --- Configuration ---
# Define paths for both model result files to access their scores.
FINE_TUNED_FILE = 'evaluation_results_per_entry_AYA_23_SFT.tsv'
FEW_SHOT_FILE = 'metrics_detailed_aya-101_few_shot.tsv'

# The minimum length of the common ending to be considered a valid genus proximum.
MIN_SUFFIX_LENGTH = 5

# The maximum number of words allowed in a lemma.
MAX_WORDS_IN_LEMMA = 2

# The minimum number of lemmas a group must have to be displayed.
MIN_GROUP_SIZE = 2


def load_and_prepare_data(sft_path, fs_path):
    """Loads and merges the full data from both model result files."""
    # Load Fine-Tuned Data
    sft_df = pd.read_csv(sft_path, sep='\t')
    sft_df = sft_df.rename(columns={'model_prediction': 'sft_prediction'})
    sft_df['sft_combined_score'] = pd.to_numeric(sft_df['comet22_score'], errors='coerce') + \
                                   pd.to_numeric(sft_df['xcomet_score'], errors='coerce')
    sft_df = sft_df[['Lemma', 'DefinitionShort', 'DefinitionFull', 'sft_prediction', 'sft_combined_score']]

    # Load Few-Shot Data
    fs_df = pd.read_csv(fs_path, sep='\t')
    fs_df = fs_df.rename(columns={'model_long_definition': 'fs_prediction'})
    fs_df['fs_combined_score'] = pd.to_numeric(fs_df['comet22_score'], errors='coerce') + \
                                 pd.to_numeric(fs_df['xcomet_score'], errors='coerce')
    fs_df = fs_df[['Lemma', 'DefinitionShort', 'fs_prediction', 'fs_combined_score']]

    # Merge the two dataframes
    merged_df = pd.merge(sft_df, fs_df, on=['Lemma', 'DefinitionShort'], how='inner')
    
    # Drop any unexpected duplicate rows for the same (Lemma, DefinitionShort) pair.
    merged_df.drop_duplicates(subset=['Lemma', 'DefinitionShort'], inplace=True)
    
    return merged_df


def find_common_suffix_groups(lemmas, min_length=5):
    """
    Finds groups of lemmas that share a common suffix of at least min_length.
    """
    print(f"Searching for common suffixes of at least {min_length} characters...")
    groups = defaultdict(list)
    lemma_set = set(lemmas)
    
    for lemma1 in lemmas:
        for lemma2 in lemma_set:
            if lemma1 >= lemma2:
                continue
            
            i = 0
            while i < len(lemma1) and i < len(lemma2) and lemma1[-(i+1)] == lemma2[-(i+1)]:
                i += 1
            
            if i >= min_length:
                common_suffix = lemma1[-i:]
                if lemma1 not in groups[common_suffix]:
                    groups[common_suffix].append(lemma1)
                if lemma2 not in groups[common_suffix]:
                    groups[common_suffix].append(lemma2)
                    
    for suffix in groups:
        groups[suffix].sort()
        
    return groups

# --- Main Execution ---
print("--- Stratum 3: Finding Lexical Pairs with Shared Genus Proxima ---")
try:
    # Load and prepare data from both models
    merged_df = load_and_prepare_data(FINE_TUNED_FILE, FEW_SHOT_FILE)
    print(f"Successfully loaded and merged scores for {len(merged_df)} unique common test entries.")

    # --- Apply Filters ---
    # 1. Filter out entries where BOTH models produced a perfect match
    merged_df['sft_is_perfect'] = merged_df['sft_prediction'].str.strip().str.lower() == merged_df['DefinitionFull'].str.strip().str.lower()
    merged_df['fs_is_perfect'] = merged_df['fs_prediction'].str.strip().str.lower() == merged_df['DefinitionFull'].str.strip().str.lower()
    
    initial_rows = len(merged_df)
    filtered_df = merged_df[~(merged_df['sft_is_perfect'] & merged_df['fs_is_perfect'])].copy()
    print(f"Filtered out {initial_rows - len(filtered_df)} entries where both models had a perfect match.")

    # 2. Filter by word count in the lemma
    initial_rows = len(filtered_df)
    filtered_df['word_count'] = filtered_df['Lemma'].str.split().str.len()
    filtered_df = filtered_df[filtered_df['word_count'] <= MAX_WORDS_IN_LEMMA].copy()
    print(f"Filtered out {initial_rows - len(filtered_df)} entries with lemmas longer than {MAX_WORDS_IN_LEMMA} words.")
    
    # Find groups based on the filtered list of unique lemmas
    unique_lemmas_filtered = filtered_df['Lemma'].unique().tolist()
    genus_groups = find_common_suffix_groups(unique_lemmas_filtered, min_length=MIN_SUFFIX_LENGTH)
    
    # --- Prepare groups for sorting ---
    groups_with_scores = []
    for suffix, group_lemmas in genus_groups.items():
        if len(group_lemmas) >= MIN_GROUP_SIZE:
            max_score_in_group = 0
            # Find the highest score among all entries for lemmas in this group
            for lemma in group_lemmas:
                lemma_entries = filtered_df[filtered_df['Lemma'] == lemma]
                if not lemma_entries.empty:
                    # Get the max score for this lemma across its senses and models
                    max_lemma_score = max(lemma_entries['sft_combined_score'].max(), lemma_entries['fs_combined_score'].max())
                    if max_lemma_score > max_score_in_group:
                        max_score_in_group = max_lemma_score
            
            groups_with_scores.append((suffix, group_lemmas, max_score_in_group))

    # Sort the groups based on the highest score found within each group, in descending order
    groups_with_scores.sort(key=lambda x: x[2], reverse=True)
    
    # --- Display Results ---
    print(f"\nFound {len(groups_with_scores)} potential genus proxima groups matching all criteria.")
    display(HTML("<h3>Potential Pairs/Groups for Stratum 3 Analysis (sorted by score):</h3>"))

    if not groups_with_scores:
        print(f"No groups found with at least {MIN_GROUP_SIZE} members after filtering. Try lowering MIN_SUFFIX_LENGTH or adjusting MAX_WORDS_IN_LEMMA.")
    else:
        for suffix, group_lemmas, max_score in groups_with_scores:
            print(f"Genus Proxima: '{suffix}' (Highest score in group: {max_score:.2f})")
            
            # Display each lemma in the group with its scores for all its senses
            for lemma in group_lemmas:
                lemma_entries = filtered_df[filtered_df['Lemma'] == lemma]
                print(f"  - {lemma}:")
                for _, row in lemma_entries.iterrows():
                    sft_score_str = f"{row['sft_combined_score']:.2f}"
                    fs_score_str = f"{row['fs_combined_score']:.2f}"
                    print(f"    - Short Def: '{row['DefinitionShort'][:40]}...' (SFT: {sft_score_str}, FS: {fs_score_str})")

            print("-" * 60)

except FileNotFoundError:
    print(f"Error: Could not find one of the required files.")
    print(f"Please ensure '{FINE_TUNED_FILE}' and '{FEW_SHOT_FILE}' are in the same directory.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# --- Stratum 3: Finding Lexical Pairs with Shared Genus Proxima ---
# Successfully loaded and merged scores for 3446 unique common test entries.
# Filtered out 118 entries where both models had a perfect match.
# Filtered out 160 entries with lemmas longer than 2 words.
# Searching for common suffixes of at least 5 characters...
#
# Found 406 potential genus proxima groups matching all criteria.
# <h3>Potential Pairs/Groups for Stratum 3 Analysis (sorted by score):</h3>
# Genus Proxima: 'maker' (Highest score in group: 1.99)
#   - doelpuntenmaker:
#     - Short Def: 'iemand die scoort in een wedstrijd...' (SFT: 1.59, FS: 1.69)
#     - Short Def: 'iemand die vaak doelpunten maakt...' (SFT: 1.84, FS: 1.60)
#   - fietsenmaker:
#     - Short Def: 'iemand die fietsen maakt fietsenfabriek ...' (SFT: 1.70, FS: 1.70)
#     - Short Def: 'fietsenfabriek...' (SFT: 1.92, FS: 1.84)
#     - Short Def: 'werkplaats of winkel...' (SFT: 1.53, FS: 1.70)
#   - gelijkmaker:
#     - Short Def: 'gelijkmakend doelpunt gelijkmakend punt ...' (SFT: 1.27, FS: 1.28)
#     - Short Def: 'iets wat mensen gelijk maakt...' (SFT: 1.72, FS: 1.46)
#     - Short Def: 'gelijkmakend punt in basketbal, handbal ...' (SFT: 1.73, FS: 1.60)
#     - Short Def: 'gelegenheid tot gelijkmaken...' (SFT: 1.43, FS: 1.15)
#   - grafmaker:
#     - Short Def: 'iemand die graven maakt...' (SFT: 1.73, FS: 1.73)
#   - instrumentmaker:
#     - Short Def: 'iemand die werktuigen maakt...' (SFT: 1.85, FS: 1.73)
#   - softwaremaker:
#     - Short Def: 'iemand die software maakt...' (SFT: 1.88, FS: 1.99)
#   - spraakmaker:
#     - Short Def: 'invloedrijk mens...' (SFT: 1.63, FS: 1.36)
#     - Short Def: 'iets actueels...' (SFT: 1.68, FS: 1.60)
#   - winstmaker:
#     - Short Def: 'winstgevend product winstgevende bedrijf...' (SFT: 1.59, FS: 1.39)
#     - Short Def: 'winstgevende bedrijfstak...' (SFT: 1.52, FS: 1.59)
#     - Short Def: 'omstandigheid waardoor winst ontstaat...' (SFT: 1.69, FS: 1.89)
# ------------------------------------------------------------
# Genus Proxima: 'iener' (Highest score in group: 1.98)
#   - kleine verdiener:
#     - Short Def: 'iemand die weinig geld verdient...' (SFT: 1.47, FS: 1.98)
#   - tiener:
#     - Short Def: 'iemand tussen de 10 en 20...' (SFT: 1.85, FS: 1.90)
# ------------------------------------------------------------
# Genus Proxima: 'middag' (Highest score in group: 1.98)
#   - kindermiddag:
#     - Short Def: 'middagbijeenkomst voor kinderen...' (SFT: 1.52, FS: 1.45)
#   - themamiddag:
#     - Short Def: 'middagbijeenkomst over een thema...' (SFT: 1.61, FS: 1.83)
#   - vrijdagmiddag:
#     - Short Def: 'op vrijdagmiddag...' (SFT: 1.75, FS: 1.98)
#   - zondagnamiddag:
#     - Short Def: 'op zondagnamiddag...' (SFT: 1.74, FS: 1.98)
# ------------------------------------------------------------
# Genus Proxima: 'amiddag' (Highest score in group: 1.98)
#   - themamiddag:
#     - Short Def: 'middagbijeenkomst over een thema...' (SFT: 1.61, FS: 1.83)
#   - zondagnamiddag:
#     - Short Def: 'op zondagnamiddag...' (SFT: 1.74, FS: 1.98)
# ------------------------------------------------------------
# Genus Proxima: 'leren' (Highest score in group: 1.98)
#   - geitenleren:
#     - Short Def: 'gemaakt van geitenleer...' (SFT: 1.64, FS: 1.98)
#   - halfleren:
#     - Short Def: 'voor een deel van leer gemaakt...' (SFT: 1.52, FS: 1.86)
#   - zomerkleren:
#     - Short Def: 'kleren voor het zomerseizoen...' (SFT: 1.63, FS: 1.93)
# ------------------------------------------------------------
# Genus Proxima: 'product' (Highest score in group: 1.98)
#   - aandelenleaseproduct:
#     - Short Def: 'beleggingsproduct gekocht met geleend ge...' (SFT: 1.75, FS: 1.70)
#   - aardolieproduct:
#     - Short Def: 'product van aardolie...' (SFT: 1.80, FS: 1.73)
#   - diepvriesproduct:
#     - Short Def: 'product in de diepvries...' (SFT: 1.57, FS: 1.56)
#   - eiwitproduct:
#     - Short Def: 'product met eiwit...' (SFT: 1.90, FS: 0.33)
#   - staalproduct:
#     - Short Def: 'product van staal...' (SFT: 1.94, FS: 1.98)
#   - streekproduct:
#     - Short Def: 'product uit een bepaalde streek...' (SFT: 1.83, FS: 1.29)
#   - tussenproduct:
#     - Short Def: 'halfproduct...' (SFT: 1.47, FS: 1.61)
#     - Short Def: 'tussentijds resultaat...' (SFT: 1.26, FS: 1.46)
# ------------------------------------------------------------
# Genus Proxima: 'oduct' (Highest score in group: 1.98)
#   - aandelenleaseproduct:
#     - Short Def: 'beleggingsproduct gekocht met geleend ge...' (SFT: 1.75, FS: 1.70)
#   - aardolieproduct:
#     - Short Def: 'product van aardolie...' (SFT: 1.80, FS: 1.73)
#   - diepvriesproduct:
#     - Short Def: 'product in de diepvries...' (SFT: 1.57, FS: 1.56)
#   - ecoduct:
#     - Short Def: 'oversteekplaats voor wild...' (SFT: 1.74, FS: 1.08)
#   - eiwitproduct:
#     - Short Def: 'product met eiwit...' (SFT: 1.90, FS: 0.33)
#   - staalproduct:
#     - Short Def: 'product van staal...' (SFT: 1.94, FS: 1.98)
#   - streekproduct:
#     - Short Def: 'product uit een bepaalde streek...' (SFT: 1.83, FS: 1.29)
#   - tussenproduct:
#     - Short Def: 'halfproduct...' (SFT: 1.47, FS: 1.61)
#     - Short Def: 'tussentijds resultaat...' (SFT: 1.26, FS: 1.46)
# ------------------------------------------------------------
# Genus Proxima: '-leerling' (Highest score in group: 1.98)
#   - ex-leerling:
#     - Short Def: 'voormalig leerling...' (SFT: 1.66, FS: 1.98)
#   - vbo-leerling:
#     - Short Def: 'leerling op het vbo...' (SFT: 1.62, FS: 1.97)
#   - vmbo-leerling:
#     - Short Def: 'leerling op het vmbo...' (SFT: 1.79, FS: 1.64)
# ------------------------------------------------------------
# Genus Proxima: 'enaar' (Highest score in group: 1.98)
#   - Aalstenaar:
#     - Short Def: 'iemand uit Aalst lid e.d. van een club u...' (SFT: 1.89, FS: 1.86)
#   - Arendonkenaar:
#     - Short Def: 'iemand uit Arendonk...' (SFT: 1.89, FS: 1.98)
#   - Coevordenaar:
#     - Short Def: 'iemand uit Coevorden lid e.d. van een cl...' (SFT: 1.92, FS: 1.86)
#   - Diestenaar:
#     - Short Def: 'iemand uit Diest lid e.d. van een club u...' (SFT: 1.90, FS: 1.88)
#   - Dordrechtenaar:
#     - Short Def: 'iemand uit Dordrecht lid e.d. van een cl...' (SFT: 1.90, FS: 1.85)
#   - Heemstedenaar:
#     - Short Def: 'iemand uit Heemstede lid e.d. van een cl...' (SFT: 1.89, FS: 1.87)
#   - Temsenaar:
#     - Short Def: 'iemand uit Temse lid e.d. van een club u...' (SFT: 1.90, FS: 1.88)
#   - Turnhoutenaar:
#     - Short Def: 'iemand uit Turnhout...' (SFT: 1.95, FS: 1.91)
#   - Zutphenaar:
#     - Short Def: 'iemand uit Zutphen...' (SFT: 1.94, FS: 1.90)
#   - bultenaar:
#     - Short Def: 'gebochelde...' (SFT: 1.11, FS: 1.18)
#   - duivelskunstenaar:
#     - Short Def: 'beoefenaar van zwarte kunst...' (SFT: 1.64, FS: 1.64)
#     - Short Def: 'man die iets perfect beheerst...' (SFT: 1.55, FS: 1.50)
#   - informatieambtenaar:
#     - Short Def: 'ambtenaar voor informatie...' (SFT: 1.87, FS: 1.92)
#   - misdienaar:
#     - Short Def: 'iemand die helpt tijdens een katholieke ...' (SFT: 0.90, FS: 0.97)
#   - videokunstenaar:
#     - Short Def: 'iemand die videokunst maakt...' (SFT: 1.91, FS: 1.57)
#   - zelfmoordenaar:
#     - Short Def: 'iemand die zelfmoord pleegt...' (SFT: 1.58, FS: 1.27)
# ------------------------------------------------------------
# Genus Proxima: 'aanse' (Highest score in group: 1.98)
#   - Amerikaanse:
#     - Short Def: 'vrouw uit Amerika...' (SFT: 1.55, FS: 1.98)
#   - Pathaanse:
#     - Short Def: 'vrouw uit Afghanistan...' (SFT: 1.17, FS: 1.55)
#   - Porto Ricaanse:
#     - Short Def: 'vrouw uit Porto Rico...' (SFT: 1.92, FS: 1.94)
# ------------------------------------------------------------
# Genus Proxima: 'paard' (Highest score in group: 1.98)
#   - Trojaans paard:
#     - Short Def: 'iets wat niet als schadelijk herkend wor...' (SFT: 1.51, FS: 1.48)
#     - Short Def: 'computervirus...' (SFT: 1.15, FS: 1.45)
#   - landbouwpaard:
#     - Short Def: 'zwaargebouwd trekpaard...' (SFT: 0.79, FS: 1.85)
#   - lastpaard:
#     - Short Def: 'paard dat lasten vervoert...' (SFT: 1.73, FS: 1.88)
#   - miniatuurpaard:
#     - Short Def: 'zeer klein paard...' (SFT: 0.78, FS: 1.84)
#   - paard:
#     - Short Def: 'hoefdier met manen paardenvlees...' (SFT: 0.66, FS: 0.62)
#     - Short Def: 'beeld van een paard...' (SFT: 1.60, FS: 1.75)
#     - Short Def: 'speelgoedpaard...' (SFT: 0.94, FS: 1.44)
#     - Short Def: 'schaakstuk...' (SFT: 0.86, FS: 0.70)
#     - Short Def: 'turntoestel...' (SFT: 0.74, FS: 0.69)
#     - Short Def: 'licht rupsvoertuig...' (SFT: 1.32, FS: 0.67)
#     - Short Def: 'Chinees dierenriemteken iemand uit een j...' (SFT: 1.37, FS: 1.20)
#     - Short Def: 'iemand uit een jaar van het paard...' (SFT: 1.82, FS: 1.61)
#   - wandelpaard:
#     - Short Def: 'paard voor wandelritten...' (SFT: 1.53, FS: 1.59)
#   - zeepaard:
#     - Short Def: 'mythisch paard in zee...' (SFT: 1.43, FS: 1.19)
#     - Short Def: 'zeepaardje voorstelling van een zeepaard...' (SFT: 1.18, FS: 1.17)
#     - Short Def: 'voorstelling van een zeepaardje...' (SFT: 1.73, FS: 1.98)
# ------------------------------------------------------------
# Genus Proxima: 'eltje' (Highest score in group: 1.98)
#   - autozeteltje:
#     - Short Def: 'autostoeltje...' (SFT: 1.33, FS: 1.80)
#   - cameramobieltje:
#     - Short Def: 'mobieltje met camera...' (SFT: 1.68, FS: 1.98)
#   - geeltje:
#     - Short Def: 'zelfklevend memoblaadje...' (SFT: 0.97, FS: 1.11)
#     - Short Def: 'afschrift van een bekeuring...' (SFT: 1.41, FS: 1.66)
#     - Short Def: 'gele ijsselsteen...' (SFT: 1.38, FS: 0.91)
#     - Short Def: 'citroenvlinder...' (SFT: 1.51, FS: 0.71)
#   - schoteltje:
#     - Short Def: 'kleine schotel...' (SFT: 0.67, FS: 0.82)
# ------------------------------------------------------------
# Genus Proxima: 'iteit' (Highest score in group: 1.98)
#   - avondactiviteit:
#     - Short Def: 'activiteit in de avonduren...' (SFT: 1.84, FS: 1.98)
#   - beleidsintimiteit:
#     - Short Def: 'vertrouwelijkheid tussen bewindslieden e...' (SFT: 1.85, FS: 1.24)
#   - computercriminaliteit:
#     - Short Def: 'cybercrime...' (SFT: 1.44, FS: 1.87)
#   - hokjesmentaliteit:
#     - Short Def: 'mentaliteit waarbij in hokjes wordt geda...' (SFT: 1.29, FS: 1.37)
#   - horeca-activiteit:
#     - Short Def: 'werkzaamheid van een horecabedrijf...' (SFT: 1.65, FS: 1.85)
#   - internetcriminaliteit:
#     - Short Def: 'cybercrime...' (SFT: 1.49, FS: 1.83)
# ------------------------------------------------------------
# Genus Proxima: 'activiteit' (Highest score in group: 1.98)
#   - avondactiviteit:
#     - Short Def: 'activiteit in de avonduren...' (SFT: 1.84, FS: 1.98)
#   - horeca-activiteit:
#     - Short Def: 'werkzaamheid van een horecabedrijf...' (SFT: 1.65, FS: 1.85)
# ------------------------------------------------------------
# Genus Proxima: 'wedstrijd' (Highest score in group: 1.98)
#   - architectuurwedstrijd:
#     - Short Def: 'ontwerpwedstrijd voor architecten...' (SFT: 1.53, FS: 1.72)
#   - bokswedstrijd:
#     - Short Def: 'wedstrijd in het boksen...' (SFT: 0.71, FS: 0.74)
#   - etappewedstrijd:
#     - Short Def: 'wielerwedstrijd...' (SFT: 1.84, FS: 1.78)
#   - groepswedstrijd:
#     - Short Def: 'wedstrijd in de groepsfase van een toern...' (SFT: 1.55, FS: 1.91)
#   - hardloopwedstrijd:
#     - Short Def: 'wedstrijd in het hardlopen...' (SFT: 1.89, FS: 1.94)
#   - inhaalwedstrijd:
#     - Short Def: 'verplaatste wedstrijd...' (SFT: 1.34, FS: 1.28)
#   - jeugdwedstrijd:
#     - Short Def: 'wedstrijd tussen jeugdteams...' (SFT: 1.76, FS: 1.81)
#   - poëziewedstrijd:
#     - Short Def: 'wedstrijd in het schrijven van gedichten...' (SFT: 1.94, FS: 1.71)
#   - selectiewedstrijd:
#     - Short Def: 'wedstrijd om zich te kwalificeren...' (SFT: 1.84, FS: 1.86)
#   - slotwedstrijd:
#     - Short Def: 'laatste wedstrijd van een reeks...' (SFT: 1.66, FS: 1.98)
#   - verhalenwedstrijd:
#     - Short Def: 'wedstrijd in het schrijven van verhalen...' (SFT: 1.94, FS: 1.67)
# ------------------------------------------------------------
# Genus Proxima: 'ologie' (Highest score in group: 1.98)
#   - cytologie:
#     - Short Def: 'celbiologie...' (SFT: 1.50, FS: 1.95)
#   - hematologie:
#     - Short Def: 'medisch specialisme voor bloedziekten...' (SFT: 1.78, FS: 1.92)
#   - histologie:
#     - Short Def: 'weefselleer...' (SFT: 1.63, FS: 1.46)
#   - nefrologie:
#     - Short Def: 'medisch specialisme voor nierziekten...' (SFT: 1.93, FS: 1.98)
#   - pneumologie:
#     - Short Def: 'medisch specialisme voor longziekten...' (SFT: 1.85, FS: 1.76)
# ------------------------------------------------------------
# Genus Proxima: 'liefhebber' (Highest score in group: 1.98)
#   - liefhebber:
#     - Short Def: 'iemand die veel van iets of iemand houdt...' (SFT: 1.82, FS: 1.98)
#   - operaliefhebber:
#     - Short Def: 'liefhebber van operamuziek...' (SFT: 1.61, FS: 1.86)
#   - sportliefhebber:
#     - Short Def: 'liefhebber van sport...' (SFT: 1.83, FS: 1.85)
#   - taalliefhebber:
#     - Short Def: 'liefhebber van taal...' (SFT: 1.72, FS: 1.74)
#   - theaterliefhebber:
#     - Short Def: 'liefhebber van theater...' (SFT: 1.81, FS: 1.79)
# ------------------------------------------------------------
# Genus Proxima: 'advocaat' (Highest score in group: 1.98)
#   - claimadvocaat:
#     - Short Def: 'advocaat voor schadeclaims...' (SFT: 1.87, FS: 1.86)
#   - letselschadeadvocaat:
#     - Short Def: 'advocaat voor letselschade...' (SFT: 1.90, FS: 1.98)
# ------------------------------------------------------------
# Genus Proxima: 'trice' (Highest score in group: 1.98)
#   - ex-directrice:
#     - Short Def: 'voormalig directrice...' (SFT: 1.72, FS: 1.98)
#   - organisatrice:
#     - Short Def: 'vrouw die iets organiseert...' (SFT: 1.96, FS: 1.62)
# ------------------------------------------------------------
# Genus Proxima: 'loosheid' (Highest score in group: 1.98)
#   - cultuurloosheid:
#     - Short Def: 'het cultuurloos zijn...' (SFT: 1.54, FS: 1.52)
#   - tijdloosheid:
#     - Short Def: 'het niet aan tijd gebonden zijn...' (SFT: 1.49, FS: 1.98)
# ------------------------------------------------------------
# Genus Proxima: 'school' (Highest score in group: 1.98)
#   - bewaarschool:
#     - Short Def: 'kleuterschool...' (SFT: 1.13, FS: 1.84)
#   - bibliotheekschool:
#     - Short Def: 'school voor bibliotheekopleiding...' (SFT: 1.86, FS: 1.73)
#   - concentratieschool:
#     - Short Def: 'zwarte school...' (SFT: 1.11, FS: 0.72)
#   - handelsschool:
#     - Short Def: 'school voor de handel...' (SFT: 1.81, FS: 1.69)
#   - havo-vwo-school:
#     - Short Def: 'school voor havo en vwo...' (SFT: 1.78, FS: 1.11)
#   - havoschool:
#     - Short Def: 'school voor havo...' (SFT: 1.87, FS: 1.89)
#   - landbouwschool:
#     - Short Def: 'school voor landbouw...' (SFT: 1.60, FS: 1.62)
#   - nonnenschool:
#     - Short Def: 'school van nonnen tijd op een nonnenscho...' (SFT: 1.38, FS: 1.52)
#     - Short Def: 'tijd op een nonnenschool...' (SFT: 1.63, FS: 1.71)
#   - panfluitschool:
#     - Short Def: 'school om panfluit te leren spelen...' (SFT: 1.86, FS: 1.79)
#   - politieschool:
#     - Short Def: 'school voor politiefunctionarissen...' (SFT: 1.80, FS: 1.88)
#   - schildersschool:
#     - Short Def: 'school voor schilders...' (SFT: 1.87, FS: 1.05)
#     - Short Def: 'school voor kunstschilders...' (SFT: 1.82, FS: 1.71)
#     - Short Def: 'groep verwante schilders...' (SFT: 1.63, FS: 1.95)
#   - thaiboksschool:
#     - Short Def: 'school om te leren thaiboksen...' (SFT: 1.56, FS: 1.88)
#   - timmerschool:
#     - Short Def: 'school om te leren timmeren...' (SFT: 1.76, FS: 1.86)
#   - vwo-school:
#     - Short Def: 'school voor vwo...' (SFT: 1.25, FS: 1.58)
#   - webschool:
#     - Short Def: 'website voor onderwijs...' (SFT: 1.37, FS: 1.28)
#   - zeilschool:
#     - Short Def: 'school om te leren zeilen locatie van ee...' (SFT: 1.85, FS: 1.82)
#     - Short Def: 'locatie van een zeilschool...' (SFT: 1.85, FS: 1.98)
#   - zwemschool:
#     - Short Def: 'school om te leren zwemmen...' (SFT: 1.87, FS: 1.93)
# ------------------------------------------------------------
# Genus Proxima: 'shirt' (Highest score in group: 1.97)
#   - poloshirt:
#     - Short Def: 'shirt met een polokraag...' (SFT: 1.40, FS: 1.48)
#   - spelersshirt:
#     - Short Def: 'shirt van de spelers van een team...' (SFT: 1.89, FS: 1.97)
# ------------------------------------------------------------
# Genus Proxima: 'bo-leerling' (Highest score in group: 1.97)
#   - vbo-leerling:
#     - Short Def: 'leerling op het vbo...' (SFT: 1.62, FS: 1.97)
#   - vmbo-leerling:
#     - Short Def: 'leerling op het vmbo...' (SFT: 1.79, FS: 1.64)
# ------------------------------------------------------------
# Genus Proxima: 'chtig' (Highest score in group: 1.97)
#   - medeplichtig:
#     - Short Def: 'medeschuldig...' (SFT: 0.63, FS: 1.55)
#   - meisjesachtig:
#     - Short Def: 'als (van) een meisje...' (SFT: 1.54, FS: 1.97)
# ------------------------------------------------------------
# Genus Proxima: 'ziekte' (Highest score in group: 1.97)
#   - verouderingsziekte:
#     - Short Def: 'ziekte die vooral voorkomt bij ouderen...' (SFT: 1.84, FS: 1.97)
#     - Short Def: 'ziekte waardoor iemand zeer snel veroude...' (SFT: 1.48, FS: 1.79)
#   - wegkwijnziekte:
#     - Short Def: 'ziekte bij biggen...' (SFT: 1.11, FS: 1.18)
#   - welvaartsziekte:
#     - Short Def: 'ziekte in landen met hoge welvaart...' (SFT: 1.85, FS: 1.76)
# ------------------------------------------------------------
# Genus Proxima: 'sziekte' (Highest score in group: 1.97)
#   - verouderingsziekte:
#     - Short Def: 'ziekte die vooral voorkomt bij ouderen...' (SFT: 1.84, FS: 1.97)
#     - Short Def: 'ziekte waardoor iemand zeer snel veroude...' (SFT: 1.48, FS: 1.79)
#   - welvaartsziekte:
#     - Short Def: 'ziekte in landen met hoge welvaart...' (SFT: 1.85, FS: 1.76)
# ------------------------------------------------------------
# Genus Proxima: 'hotel' (Highest score in group: 1.97)
#   - afstudeerhotel:
#     - Short Def: 'hotel voor afstudeerders...' (SFT: 1.11, FS: 1.06)
#   - all-inhotel:
#     - Short Def: 'hotel met vele voorzieningen...' (SFT: 1.17, FS: 1.52)
#   - goederenhotel:
#     - Short Def: 'opslagruimte voor particulieren en bedri...' (SFT: 1.65, FS: 1.59)
#   - winterse stoofschotel:
#     - Short Def: 'stoofschotel die hoort bij de winter...' (SFT: 1.83, FS: 1.94)
#   - zorghotel:
#     - Short Def: 'hotel verbonden aan zorginstelling...' (SFT: 1.75, FS: 1.97)
# ------------------------------------------------------------
# Genus Proxima: 'gezin' (Highest score in group: 1.97)
#   - adoptiegezin:
#     - Short Def: 'gezin met adoptiekinderen...' (SFT: 1.89, FS: 1.74)
#     - Short Def: 'gezin dat geadopteerd is...' (SFT: 1.09, FS: 1.32)
#   - eenoudergezin:
#     - Short Def: 'gezin met één ouder...' (SFT: 1.95, FS: 1.97)
#   - hotelgezin:
#     - Short Def: 'gezin met een hotel of hotelketen...' (SFT: 1.91, FS: 1.78)
#     - Short Def: 'gezin met kinderen die thuis blijven won...' (SFT: 1.15, FS: 0.71)
#     - Short Def: 'gezin waarvan iedereen het druk heeft...' (SFT: 1.77, FS: 1.52)
#   - stiefgezin:
#     - Short Def: 'samengesteld gezin...' (SFT: 1.37, FS: 1.93)
# ------------------------------------------------------------
# Genus Proxima: 'marketing' (Highest score in group: 1.97)
#   - affiliate marketing:
#     - Short Def: 'internetmarketing mbv een affiliaat...' (SFT: 1.71, FS: 1.68)
#   - belevingsmarketing:
#     - Short Def: 'belevenismarketing...' (SFT: 1.64, FS: 1.97)
# ------------------------------------------------------------
# Genus Proxima: 'maatschappij' (Highest score in group: 1.97)
#   - 1,5 metermaatschappij:
#     - Short Def: 'maatschappij waarin fysieke afstand nodi...' (SFT: 1.49, FS: 1.92)
#   - bigbrothermaatschappij:
#     - Short Def: 'maatschappij die burgers controleert...' (SFT: 1.71, FS: 1.97)
#   - budgetluchtvaartmaatschappij:
#     - Short Def: 'luchtvaartmaatschappij met goedkope vluc...' (SFT: 1.95, FS: 1.90)
# ------------------------------------------------------------
# Genus Proxima: 'ermaatschappij' (Highest score in group: 1.97)
#   - 1,5 metermaatschappij:
#     - Short Def: 'maatschappij waarin fysieke afstand nodi...' (SFT: 1.49, FS: 1.92)
#   - bigbrothermaatschappij:
#     - Short Def: 'maatschappij die burgers controleert...' (SFT: 1.71, FS: 1.97)
# ------------------------------------------------------------
# Genus Proxima: 'fdruk' (Highest score in group: 1.97)
#   - schermafdruk:
#     - Short Def: 'screenshot...' (SFT: 1.07, FS: 1.80)
#   - zeefdruk:
#     - Short Def: 'grafisch procedé afdruk door zeefdruktec...' (SFT: 1.15, FS: 1.55)
#     - Short Def: 'afdruk door zeefdruktechniek...' (SFT: 1.92, FS: 1.97)
# ------------------------------------------------------------
# Genus Proxima: 'uisje' (Highest score in group: 1.97)
#   - grijs muisje:
#     - Short Def: 'iemand aan wie niets opvallends is...' (SFT: 1.69, FS: 1.97)
#   - scheef huisje:
#     - Short Def: 'woning voor overlastbezorgers...' (SFT: 0.91, FS: 1.89)
# ------------------------------------------------------------
# Genus Proxima: 'potheek' (Highest score in group: 1.97)
#   - flexwerkershypotheek:
#     - Short Def: 'hypotheek voor flexwerkers...' (SFT: 1.97, FS: 1.76)
#   - huisapotheek:
#     - Short Def: 'verzameling geneesmiddelen...' (SFT: 1.81, FS: 1.86)
#   - ziekenhuisapotheek:
#     - Short Def: 'apotheek van een ziekenhuis...' (SFT: 1.82, FS: 1.71)
# ------------------------------------------------------------
# Genus Proxima: 'centrum' (Highest score in group: 1.97)
#   - hyperscale datacentrum:
#     - Short Def: 'megadatacentrum...' (SFT: 1.63, FS: 1.88)
#   - woonwinkelcentrum:
#     - Short Def: 'winkelcentrum met woonwinkels...' (SFT: 1.85, FS: 1.97)
# ------------------------------------------------------------
# Genus Proxima: 'speler' (Highest score in group: 1.97)
#   - doedelzakspeler:
#     - Short Def: 'iemand die doedelzak speelt...' (SFT: 1.76, FS: 1.72)
#   - gitaarspeler:
#     - Short Def: 'bespeler van de gitaar voorstelling van ...' (SFT: 1.59, FS: 1.01)
#     - Short Def: 'voorstelling van een gitaarspeler...' (SFT: 1.45, FS: 1.49)
#   - harpspeler:
#     - Short Def: 'harpist...' (SFT: 1.90, FS: 1.97)
#   - toneelspeler:
#     - Short Def: 'acteur iemand die doet alsof...' (SFT: 1.26, FS: 1.32)
#     - Short Def: 'iemand die doet alsof...' (SFT: 1.32, FS: 1.34)
# ------------------------------------------------------------
# Genus Proxima: 'mster' (Highest score in group: 1.97)
#   - angorahamster:
#     - Short Def: 'langharige Syrische hamster...' (SFT: 1.38, FS: 1.97)
#   - initiatiefneemster:
#     - Short Def: 'vrouwelijke initiatiefnemer...' (SFT: 1.42, FS: 1.17)
# ------------------------------------------------------------
# Genus Proxima: 'ering' (Highest score in group: 1.97)
#   - beleidsadvisering:
#     - Short Def: 'advisering over het te voeren beleid...' (SFT: 1.72, FS: 1.77)
#   - klimaatsverandering:
#     - Short Def: 'verandering van gemiddelde weergesteldhe...' (SFT: 1.46, FS: 1.44)
#     - Short Def: 'verandering van de algemene sfeer...' (SFT: 1.54, FS: 1.10)
#     - Short Def: 'huidige wereldwijde klimaatverandering...' (SFT: 1.62, FS: 1.97)
#   - leerlinggebonden financiering:
#     - Short Def: 'extra financiering afgestemd op leerling...' (SFT: 1.42, FS: 1.45)
#   - verpretparkisering:
#     - Short Def: 'het tot een pretpark maken...' (SFT: 1.44, FS: 1.94)
#   - vliering:
#     - Short Def: 'bergruimte onder het dak...' (SFT: 0.96, FS: 1.45)
# ------------------------------------------------------------
# Genus Proxima: 'aring' (Highest score in group: 1.97)
#   - filesharing:
#     - Short Def: 'het delen van computerbestanden...' (SFT: 1.82, FS: 1.63)
#   - gelijkwaardigheidsverklaring:
#     - Short Def: 'verklaring van technische gelijkwaardigh...' (SFT: 1.43, FS: 1.91)
#     - Short Def: 'verklaring dat een diploma gelijkwaardig...' (SFT: 1.64, FS: 1.21)
#   - onbewoonbaarheidsverklaring:
#     - Short Def: 'verklaring van onbewoonbaarheid...' (SFT: 1.54, FS: 1.97)
# ------------------------------------------------------------
# Genus Proxima: 'heidsverklaring' (Highest score in group: 1.97)
#   - gelijkwaardigheidsverklaring:
#     - Short Def: 'verklaring van technische gelijkwaardigh...' (SFT: 1.43, FS: 1.91)
#     - Short Def: 'verklaring dat een diploma gelijkwaardig...' (SFT: 1.64, FS: 1.21)
#   - onbewoonbaarheidsverklaring:
#     - Short Def: 'verklaring van onbewoonbaarheid...' (SFT: 1.54, FS: 1.97)
# ------------------------------------------------------------
# Genus Proxima: 'opper' (Highest score in group: 1.97)
#   - fopper:
#     - Short Def: 'iemand die iemand of iets fopt speler in...' (SFT: 1.17, FS: 0.89)
#     - Short Def: 'fopspeen...' (SFT: 1.03, FS: 1.46)
#     - Short Def: 'Surinaamse huismiddeltje...' (SFT: 1.00, FS: 0.86)
#     - Short Def: 'speler in het kinderspel fopbal...' (SFT: 1.05, FS: 0.91)
#   - opper:
#     - Short Def: 'opperwachtmeester onderofficier politiea...' (SFT: 1.44, FS: 1.30)
#     - Short Def: 'opperman...' (SFT: 0.71, FS: 0.84)
#     - Short Def: 'schuilplaats voor een schip...' (SFT: 1.42, FS: 1.33)
#     - Short Def: 'stapel gedroogd gras...' (SFT: 1.18, FS: 1.04)
#     - Short Def: 'onderofficier...' (SFT: 1.05, FS: 0.98)
#     - Short Def: 'politieagent...' (SFT: 0.83, FS: 1.97)
#   - personal shopper:
#     - Short Def: 'begeleider bij winkelen...' (SFT: 1.66, FS: 1.65)
# ------------------------------------------------------------
# Genus Proxima: 'vrouw' (Highest score in group: 1.96)
#   - kuisvrouw:
#     - Short Def: 'vrouw die schoonmaakt...' (SFT: 1.57, FS: 1.91)
#   - poetsvrouw:
#     - Short Def: 'vrouw die schoonmaakt...' (SFT: 1.71, FS: 1.96)
#   - werkvrouw:
#     - Short Def: 'vrouw die schoonmaakt...' (SFT: 1.60, FS: 1.96)
#   - zakenvrouw:
#     - Short Def: 'vrouw die in zaken zit...' (SFT: 1.44, FS: 1.33)
# ------------------------------------------------------------
# Genus Proxima: 'svrouw' (Highest score in group: 1.96)
#   - kuisvrouw:
#     - Short Def: 'vrouw die schoonmaakt...' (SFT: 1.57, FS: 1.91)
#   - poetsvrouw:
#     - Short Def: 'vrouw die schoonmaakt...' (SFT: 1.71, FS: 1.96)
# ------------------------------------------------------------
# Genus Proxima: 'chter' (Highest score in group: 1.96)
#   - Zwijndrechter:
#     - Short Def: 'iemand uit Zwijndrecht lid van een club ...' (SFT: 1.77, FS: 1.89)
#   - dochter:
#     - Short Def: 'vrouwelijk kind van iemand dochterbedrij...' (SFT: 0.91, FS: 0.76)
#     - Short Def: 'dochterbedrijf...' (SFT: 1.49, FS: 1.61)
#     - Short Def: 'dochterinstelling...' (SFT: 1.54, FS: 1.06)
#     - Short Def: 'ingezetene...' (SFT: 0.78, FS: 0.56)
#     - Short Def: 'vrouwelijk jong van een dier...' (SFT: 1.40, FS: 1.62)
#   - jeugdrechter:
#     - Short Def: 'rechter die jeugdzaken behandelt...' (SFT: 1.78, FS: 1.93)
#   - lijnrechter:
#     - Short Def: 'assistent van de scheidsrechter...' (SFT: 1.37, FS: 1.96)
#   - oplichter:
#     - Short Def: 'iemand die oplicht...' (SFT: 1.66, FS: 1.35)
#   - oprichter:
#     - Short Def: 'stichter...' (SFT: 1.90, FS: 1.51)
# ------------------------------------------------------------
# Genus Proxima: 'rechter' (Highest score in group: 1.96)
#   - Zwijndrechter:
#     - Short Def: 'iemand uit Zwijndrecht lid van een club ...' (SFT: 1.77, FS: 1.89)
#   - jeugdrechter:
#     - Short Def: 'rechter die jeugdzaken behandelt...' (SFT: 1.78, FS: 1.93)
#   - lijnrechter:
#     - Short Def: 'assistent van de scheidsrechter...' (SFT: 1.37, FS: 1.96)
# ------------------------------------------------------------
# Genus Proxima: 'genoot' (Highest score in group: 1.96)
#   - disgenoot:
#     - Short Def: 'iemand aan dezelfde tafel...' (SFT: 1.53, FS: 1.83)
#   - ex-echtgenoot:
#     - Short Def: 'voormalig echtgenoot...' (SFT: 1.73, FS: 1.96)
# ------------------------------------------------------------
# Genus Proxima: 'rijder' (Highest score in group: 1.96)
#   - Elfstedentochtrijder:
#     - Short Def: 'deelnemer aan de Elfstedentocht...' (SFT: 1.70, FS: 1.96)
#   - motorrijder:
#     - Short Def: 'berijder van een motorfiets...' (SFT: 1.68, FS: 1.87)
#   - oud-strijder:
#     - Short Def: 'oorlogsveteraan...' (SFT: 1.87, FS: 1.55)
#   - spitsrijder:
#     - Short Def: 'automobilist die in de spits rijdt...' (SFT: 1.68, FS: 1.78)
#   - strijder:
#     - Short Def: 'iemand die strijdt...' (SFT: 0.90, FS: 1.04)
#     - Short Def: 'ijveraar...' (SFT: 1.50, FS: 1.90)
#   - vrijheidsstrijder:
#     - Short Def: 'strijder voor vrijheid...' (SFT: 1.75, FS: 1.83)
# ------------------------------------------------------------
# Genus Proxima: 'trijder' (Highest score in group: 1.96)
#   - Elfstedentochtrijder:
#     - Short Def: 'deelnemer aan de Elfstedentocht...' (SFT: 1.70, FS: 1.96)
#   - oud-strijder:
#     - Short Def: 'oorlogsveteraan...' (SFT: 1.87, FS: 1.55)
#   - strijder:
#     - Short Def: 'iemand die strijdt...' (SFT: 0.90, FS: 1.04)
#     - Short Def: 'ijveraar...' (SFT: 1.50, FS: 1.90)
#   - vrijheidsstrijder:
#     - Short Def: 'strijder voor vrijheid...' (SFT: 1.75, FS: 1.83)
# ------------------------------------------------------------
# Genus Proxima: 'winkelier' (Highest score in group: 1.96)
#   - beleggingswinkelier:
#     - Short Def: 'uitbater van een beleggingswinkel...' (SFT: 1.95, FS: 1.92)
#   - dorpswinkelier:
#     - Short Def: 'uitbater van een dorpswinkel...' (SFT: 1.93, FS: 1.92)
#   - fietsenwinkelier:
#     - Short Def: 'uitbater van een fietsenwinkel...' (SFT: 1.96, FS: 1.87)
#   - modewinkelier:
#     - Short Def: 'uitbater van een modewinkel...' (SFT: 1.96, FS: 1.63)
#   - vakwinkelier:
#     - Short Def: 'uitbater van een vakwinkel...' (SFT: 1.96, FS: 1.93)
# ------------------------------------------------------------
# Genus Proxima: 'agina' (Highest score in group: 1.96)
#   - designervagina:
#     - Short Def: 'chirurgisch behandelde vagina...' (SFT: 0.89, FS: 1.35)
#   - webpagina:
#     - Short Def: 'pagina op het internet...' (SFT: 1.84, FS: 1.96)
# ------------------------------------------------------------
# Genus Proxima: 'docent' (Highest score in group: 1.96)
#   - bestuurskundedocent:
#     - Short Def: 'docent bestuurskunde...' (SFT: 1.76, FS: 1.83)
#   - bewegingsdocent:
#     - Short Def: 'docent beweging...' (SFT: 1.68, FS: 1.71)
#   - filmacademiedocent:
#     - Short Def: 'docent op een filmacademie...' (SFT: 1.96, FS: 1.90)
#   - geschiedenisdocent:
#     - Short Def: 'docent geschiedenis...' (SFT: 1.84, FS: 1.20)
#   - godsdienstdocent:
#     - Short Def: 'docent godsdienst...' (SFT: 1.69, FS: 1.46)
#   - handvaardigheidsdocent:
#     - Short Def: 'docent handvaardigheid...' (SFT: 1.89, FS: 1.78)
#   - pabodocent:
#     - Short Def: 'docent op een pabo...' (SFT: 1.82, FS: 1.61)
#   - sociologiedocent:
#     - Short Def: 'docent sociologie...' (SFT: 1.69, FS: 1.86)
#   - vwo-docent:
#     - Short Def: 'docent op het vwo...' (SFT: 1.23, FS: 1.73)
# ------------------------------------------------------------
# Genus Proxima: 'edocent' (Highest score in group: 1.96)
#   - bestuurskundedocent:
#     - Short Def: 'docent bestuurskunde...' (SFT: 1.76, FS: 1.83)
#   - filmacademiedocent:
#     - Short Def: 'docent op een filmacademie...' (SFT: 1.96, FS: 1.90)
#   - sociologiedocent:
#     - Short Def: 'docent sociologie...' (SFT: 1.69, FS: 1.86)
# ------------------------------------------------------------
# Genus Proxima: 'iedocent' (Highest score in group: 1.96)
#   - filmacademiedocent:
#     - Short Def: 'docent op een filmacademie...' (SFT: 1.96, FS: 1.90)
#   - sociologiedocent:
#     - Short Def: 'docent sociologie...' (SFT: 1.69, FS: 1.86)
# ------------------------------------------------------------
# Genus Proxima: 'cultuur' (Highest score in group: 1.96)
#   - afrekencultuur:
#     - Short Def: 'cultuur waarin wordt afgerekend op prest...' (SFT: 1.65, FS: 1.69)
#   - apicultuur:
#     - Short Def: 'bijenteelt...' (SFT: 1.42, FS: 1.34)
#   - beleveniscultuur:
#     - Short Def: 'cultuur waarin de belevenis centraal sta...' (SFT: 1.42, FS: 1.96)
#   - graaicultuur:
#     - Short Def: 'cultuur bepaald door hebzucht...' (SFT: 1.74, FS: 1.20)
#   - leescultuur:
#     - Short Def: 'cultuur waarin veel gelezen wordt...' (SFT: 1.80, FS: 1.82)
# ------------------------------------------------------------
# Genus Proxima: 'scultuur' (Highest score in group: 1.96)
#   - beleveniscultuur:
#     - Short Def: 'cultuur waarin de belevenis centraal sta...' (SFT: 1.42, FS: 1.96)
#   - leescultuur:
#     - Short Def: 'cultuur waarin veel gelezen wordt...' (SFT: 1.80, FS: 1.82)
# ------------------------------------------------------------
# Genus Proxima: 'beleid' (Highest score in group: 1.96)
#   - ad-hocbeleid:
#     - Short Def: 'incidenteel beleid...' (SFT: 1.60, FS: 1.59)
#   - armoedebeleid:
#     - Short Def: 'politiek beleid inzake armoede...' (SFT: 1.88, FS: 1.84)
#   - hapsnapbeleid:
#     - Short Def: 'inconsistent beleid zonder visie...' (SFT: 1.62, FS: 1.96)
#   - klimaatbeleid:
#     - Short Def: 'beleid tegen de klimaatopwarming...' (SFT: 1.81, FS: 1.87)
#   - rugzakbeleid:
#     - Short Def: 'beleid m.b.t. leerlingen met een beperki...' (SFT: 1.10, FS: 1.43)
# ------------------------------------------------------------
# Genus Proxima: 'vereniging' (Highest score in group: 1.96)
#   - amateurvereniging:
#     - Short Def: 'amateurclub...' (SFT: 1.00, FS: 1.90)
#   - atletiekvereniging:
#     - Short Def: 'atletiekclub...' (SFT: 1.54, FS: 1.72)
#   - beroepsvereniging:
#     - Short Def: 'belangenvereniging van mensen met hetzel...' (SFT: 1.96, FS: 1.93)
#   - betaaldvoetbalvereniging:
#     - Short Def: 'voetbalvereniging voor profvoetballers...' (SFT: 1.51, FS: 1.89)
#   - duivensportvereniging:
#     - Short Def: 'duivenvereniging...' (SFT: 1.53, FS: 1.92)
#   - duivenvereniging:
#     - Short Def: 'vereniging voor duivenhouders...' (SFT: 1.53, FS: 1.69)
#   - hockeyvereniging:
#     - Short Def: 'hockeyclub...' (SFT: 1.93, FS: 1.87)
#   - kunstenaarsvereniging:
#     - Short Def: 'belangenvereniging van kunstenaars...' (SFT: 1.76, FS: 1.78)
#   - oratoriumvereniging:
#     - Short Def: 'vereniging van oratoriumzangers...' (SFT: 1.75, FS: 1.80)
#   - postduivenvereniging:
#     - Short Def: 'vereniging voor duivensport...' (SFT: 0.95, FS: 1.74)
#   - schaakvereniging:
#     - Short Def: 'schaakclub...' (SFT: 1.94, FS: 1.88)
# ------------------------------------------------------------
# Genus Proxima: 'svereniging' (Highest score in group: 1.96)
#   - beroepsvereniging:
#     - Short Def: 'belangenvereniging van mensen met hetzel...' (SFT: 1.96, FS: 1.93)
#   - kunstenaarsvereniging:
#     - Short Def: 'belangenvereniging van kunstenaars...' (SFT: 1.76, FS: 1.78)
# ------------------------------------------------------------
# Genus Proxima: 'iging' (Highest score in group: 1.96)
#   - IT-beveiliging:
#     - Short Def: 'beveiliging van IT-middelen of IT-produc...' (SFT: 1.40, FS: 1.71)
#   - amateurvereniging:
#     - Short Def: 'amateurclub...' (SFT: 1.00, FS: 1.90)
#   - atletiekvereniging:
#     - Short Def: 'atletiekclub...' (SFT: 1.54, FS: 1.72)
#   - beroepsvereniging:
#     - Short Def: 'belangenvereniging van mensen met hetzel...' (SFT: 1.96, FS: 1.93)
#   - betaaldvoetbalvereniging:
#     - Short Def: 'voetbalvereniging voor profvoetballers...' (SFT: 1.51, FS: 1.89)
#   - duivensportvereniging:
#     - Short Def: 'duivenvereniging...' (SFT: 1.53, FS: 1.92)
#   - duivenvereniging:
#     - Short Def: 'vereniging voor duivenhouders...' (SFT: 1.53, FS: 1.69)
#   - hockeyvereniging:
#     - Short Def: 'hockeyclub...' (SFT: 1.93, FS: 1.87)
#   - kunstenaarsvereniging:
#     - Short Def: 'belangenvereniging van kunstenaars...' (SFT: 1.76, FS: 1.78)
#   - oratoriumvereniging:
#     - Short Def: 'vereniging van oratoriumzangers...' (SFT: 1.75, FS: 1.80)
#   - postduivenvereniging:
#     - Short Def: 'vereniging voor duivensport...' (SFT: 0.95, FS: 1.74)
#   - schaakvereniging:
#     - Short Def: 'schaakclub...' (SFT: 1.94, FS: 1.88)
# ------------------------------------------------------------
# Genus Proxima: 'coach' (Highest score in group: 1.96)
#   - agressiecoach:
#     - Short Def: 'coach die zich bezighoudt met agressiepr...' (SFT: 1.35, FS: 1.53)
#   - beautycoach:
#     - Short Def: 'coach op het gebied make-up en verzorgin...' (SFT: 1.68, FS: 1.90)
#   - levenscoach:
#     - Short Def: 'coach die het persoonlijk leven begeleid...' (SFT: 1.79, FS: 1.78)
#   - lifestylecoach:
#     - Short Def: 'coach voor lifestyle...' (SFT: 1.72, FS: 1.96)
# ------------------------------------------------------------
# Genus Proxima: 'ecoach' (Highest score in group: 1.96)
#   - agressiecoach:
#     - Short Def: 'coach die zich bezighoudt met agressiepr...' (SFT: 1.35, FS: 1.53)
#   - lifestylecoach:
#     - Short Def: 'coach voor lifestyle...' (SFT: 1.72, FS: 1.96)
# ------------------------------------------------------------
# Genus Proxima: 'periode' (Highest score in group: 1.96)
#   - bezinningsperiode:
#     - Short Def: 'periode waarin men zich bezint...' (SFT: 1.55, FS: 1.53)
#   - brugperiode:
#     - Short Def: 'oriëntatietijd op de middelbare school...' (SFT: 1.56, FS: 1.53)
#   - kerstperiode:
#     - Short Def: 'periode rond Kerstmis...' (SFT: 1.73, FS: 1.96)
#   - koopjesperiode:
#     - Short Def: 'periode voor uitverkoop...' (SFT: 1.56, FS: 1.50)
# ------------------------------------------------------------
# Genus Proxima: 'kster' (Highest score in group: 1.96)
#   - gastspreekster:
#     - Short Def: 'vrouwelijke gastspreker...' (SFT: 1.82, FS: 1.87)
#   - oud-medewerkster:
#     - Short Def: 'voormalig medewerkster...' (SFT: 1.41, FS: 1.96)
#   - werkster:
#     - Short Def: 'vrouw die werkt...' (SFT: 1.54, FS: 1.82)
#     - Short Def: 'vrouw die schoonmaakt...' (SFT: 1.79, FS: 1.47)
#     - Short Def: 'arbeidster...' (SFT: 1.38, FS: 1.49)
#     - Short Def: 'vrouw die handenarbeid verricht...' (SFT: 1.85, FS: 1.81)
#     - Short Def: 'bij of hommel die werkt...' (SFT: 0.90, FS: 0.77)
#     - Short Def: 'mier die werkt...' (SFT: 0.76, FS: 0.93)
# ------------------------------------------------------------
# Genus Proxima: 'werkster' (Highest score in group: 1.96)
#   - oud-medewerkster:
#     - Short Def: 'voormalig medewerkster...' (SFT: 1.41, FS: 1.96)
#   - werkster:
#     - Short Def: 'vrouw die werkt...' (SFT: 1.54, FS: 1.82)
#     - Short Def: 'vrouw die schoonmaakt...' (SFT: 1.79, FS: 1.47)
#     - Short Def: 'arbeidster...' (SFT: 1.38, FS: 1.49)
#     - Short Def: 'vrouw die handenarbeid verricht...' (SFT: 1.85, FS: 1.81)
#     - Short Def: 'bij of hommel die werkt...' (SFT: 0.90, FS: 0.77)
#     - Short Def: 'mier die werkt...' (SFT: 0.76, FS: 0.93)
# ------------------------------------------------------------
# Genus Proxima: 'ening' (Highest score in group: 1.96)
#   - bed-bad-broodvoorziening:
#     - Short Def: 'basisvoorziening voor uitgeprocedeerden...' (SFT: 1.75, FS: 1.96)
#   - bijzonderebijstandsverlening:
#     - Short Def: 'het verlenen van bijzondere bijstand...' (SFT: 1.63, FS: 1.73)
#   - duurzaamheidslening:
#     - Short Def: 'lening voor verduurzaming huis...' (SFT: 1.72, FS: 1.84)
# ------------------------------------------------------------
# Genus Proxima: 'tschade' (Highest score in group: 1.95)
#   - oogstschade:
#     - Short Def: 'schade aan de oogst...' (SFT: 1.40, FS: 1.28)
#   - roetschade:
#     - Short Def: 'schade door roet...' (SFT: 1.95, FS: 1.95)
#   - vorstschade:
#     - Short Def: 'schade door vorst...' (SFT: 1.79, FS: 1.91)
# ------------------------------------------------------------
# Genus Proxima: 'lster' (Highest score in group: 1.95)
#   - ex-voetbalster:
#     - Short Def: 'voormalig topvoetballer...' (SFT: 1.35, FS: 1.43)
#     - Short Def: 'vrouw die gevoetbald heeft...' (SFT: 1.91, FS: 1.55)
#   - pianospeelster:
#     - Short Def: 'vrouwelijke pianist...' (SFT: 1.91, FS: 1.93)
#   - poppenspeelster:
#     - Short Def: 'vrouw die poppenspel speelt...' (SFT: 1.87, FS: 1.95)
# ------------------------------------------------------------
# Genus Proxima: 'speelster' (Highest score in group: 1.95)
#   - pianospeelster:
#     - Short Def: 'vrouwelijke pianist...' (SFT: 1.91, FS: 1.93)
#   - poppenspeelster:
#     - Short Def: 'vrouw die poppenspel speelt...' (SFT: 1.87, FS: 1.95)
# ------------------------------------------------------------
# Genus Proxima: 'elijkheid' (Highest score in group: 1.95)
#   - burgerlijke aansprakelijkheid:
#     - Short Def: 'persoonlijke aansprakelijkheid voor scha...' (SFT: 1.72, FS: 1.39)
#   - gendergelijkheid:
#     - Short Def: 'gelijke behandeling qua gender en sekse...' (SFT: 1.72, FS: 1.93)
#   - kindvriendelijkheid:
#     - Short Def: 'het kindvriendelijk zijn...' (SFT: 1.95, FS: 1.90)
#   - onvriendelijkheid:
#     - Short Def: 'het onvriendelijk zijn...' (SFT: 1.24, FS: 1.00)
#     - Short Def: 'onvriendelijke opmerking of daad...' (SFT: 1.75, FS: 1.77)
#   - scoringsmogelijkheid:
#     - Short Def: 'mogelijkheid om te scoren mogelijkheid o...' (SFT: 1.51, FS: 1.71)
#     - Short Def: 'mogelijkheid om een succesje te boeken...' (SFT: 1.77, FS: 1.86)
#   - trainingsmogelijkheid:
#     - Short Def: 'mogelijkheid tot training voor personen...' (SFT: 1.32, FS: 1.10)
#     - Short Def: 'mogelijkheid tot training voor sportlied...' (SFT: 1.35, FS: 1.54)
#   - uitwijkmogelijkheid:
#     - Short Def: 'mogelijkheid om uit te wijken...' (SFT: 1.32, FS: 1.39)
#     - Short Def: 'mogelijkheid om iets te vermijden...' (SFT: 1.66, FS: 0.78)
#     - Short Def: 'mogelijkheid om over te stappen naar iet...' (SFT: 1.76, FS: 1.47)
#   - vrouwvriendelijkheid:
#     - Short Def: 'het vrouwvriendelijk zijn...' (SFT: 1.91, FS: 1.90)
#     - Short Def: 'blijk van vrouwvriendelijkheid...' (SFT: 1.64, FS: 1.95)
# ------------------------------------------------------------
# Genus Proxima: 'ijkheid' (Highest score in group: 1.95)
#   - burgerlijke aansprakelijkheid:
#     - Short Def: 'persoonlijke aansprakelijkheid voor scha...' (SFT: 1.72, FS: 1.39)
#   - gendergelijkheid:
#     - Short Def: 'gelijke behandeling qua gender en sekse...' (SFT: 1.72, FS: 1.93)
#   - kinderrijkheid:
#     - Short Def: 'het kinderrijk zijn...' (SFT: 1.11, FS: 1.50)
#   - kindvriendelijkheid:
#     - Short Def: 'het kindvriendelijk zijn...' (SFT: 1.95, FS: 1.90)
#   - onvriendelijkheid:
#     - Short Def: 'het onvriendelijk zijn...' (SFT: 1.24, FS: 1.00)
#     - Short Def: 'onvriendelijke opmerking of daad...' (SFT: 1.75, FS: 1.77)
#   - scoringsmogelijkheid:
#     - Short Def: 'mogelijkheid om te scoren mogelijkheid o...' (SFT: 1.51, FS: 1.71)
#     - Short Def: 'mogelijkheid om een succesje te boeken...' (SFT: 1.77, FS: 1.86)
#   - trainingsmogelijkheid:
#     - Short Def: 'mogelijkheid tot training voor personen...' (SFT: 1.32, FS: 1.10)
#     - Short Def: 'mogelijkheid tot training voor sportlied...' (SFT: 1.35, FS: 1.54)
#   - uitwijkmogelijkheid:
#     - Short Def: 'mogelijkheid om uit te wijken...' (SFT: 1.32, FS: 1.39)
#     - Short Def: 'mogelijkheid om iets te vermijden...' (SFT: 1.66, FS: 0.78)
#     - Short Def: 'mogelijkheid om over te stappen naar iet...' (SFT: 1.76, FS: 1.47)
#   - vrouwvriendelijkheid:
#     - Short Def: 'het vrouwvriendelijk zijn...' (SFT: 1.91, FS: 1.90)
#     - Short Def: 'blijk van vrouwvriendelijkheid...' (SFT: 1.64, FS: 1.95)
# ------------------------------------------------------------
# Genus Proxima: 'vriendelijkheid' (Highest score in group: 1.95)
#   - kindvriendelijkheid:
#     - Short Def: 'het kindvriendelijk zijn...' (SFT: 1.95, FS: 1.90)
#   - onvriendelijkheid:
#     - Short Def: 'het onvriendelijk zijn...' (SFT: 1.24, FS: 1.00)
#     - Short Def: 'onvriendelijke opmerking of daad...' (SFT: 1.75, FS: 1.77)
#   - vrouwvriendelijkheid:
#     - Short Def: 'het vrouwvriendelijk zijn...' (SFT: 1.91, FS: 1.90)
#     - Short Def: 'blijk van vrouwvriendelijkheid...' (SFT: 1.64, FS: 1.95)
# ------------------------------------------------------------
# Genus Proxima: 'vakantie' (Highest score in group: 1.95)
#   - bouwvakvakantie:
#     - Short Def: 'collectief zomerverlof voor de bouwsecto...' (SFT: 1.90, FS: 1.89)
#   - herfstvakantie:
#     - Short Def: 'vakantie in de herfst...' (SFT: 1.51, FS: 1.66)
#     - Short Def: 'schoolvakantie in de herfstmaanden...' (SFT: 1.65, FS: 1.95)
# ------------------------------------------------------------
# Genus Proxima: 'iljoen' (Highest score in group: 1.95)
#   - biljoen:
#     - Short Def: 'duizend keer een miljard...' (SFT: 0.95, FS: 0.91)
#     - Short Def: 'getal met twaalf nullen...' (SFT: 1.75, FS: 1.61)
#     - Short Def: 'hoeveelheid van één biljoen...' (SFT: 1.19, FS: 1.93)
#     - Short Def: 'geldbedrag van één biljoen...' (SFT: 1.72, FS: 1.95)
#   - miljoen:
#     - Short Def: 'duizend keer duizend...' (SFT: 0.83, FS: 0.61)
#     - Short Def: 'getal met zes nullen...' (SFT: 1.63, FS: 1.67)
#     - Short Def: 'hoeveelheid van één miljoen...' (SFT: 1.44, FS: 1.75)
#     - Short Def: 'geldbedrag van één miljoen...' (SFT: 1.41, FS: 1.83)
# ------------------------------------------------------------
# Genus Proxima: 'ljoen' (Highest score in group: 1.95)
#   - biljoen:
#     - Short Def: 'duizend keer een miljard...' (SFT: 0.95, FS: 0.91)
#     - Short Def: 'getal met twaalf nullen...' (SFT: 1.75, FS: 1.61)
#     - Short Def: 'hoeveelheid van één biljoen...' (SFT: 1.19, FS: 1.93)
#     - Short Def: 'geldbedrag van één biljoen...' (SFT: 1.72, FS: 1.95)
#   - galjoen:
#     - Short Def: 'groot zeilschip...' (SFT: 1.45, FS: 0.99)
#   - miljoen:
#     - Short Def: 'duizend keer duizend...' (SFT: 0.83, FS: 0.61)
#     - Short Def: 'getal met zes nullen...' (SFT: 1.63, FS: 1.67)
#     - Short Def: 'hoeveelheid van één miljoen...' (SFT: 1.44, FS: 1.75)
#     - Short Def: 'geldbedrag van één miljoen...' (SFT: 1.41, FS: 1.83)
# ------------------------------------------------------------
# Genus Proxima: 'seizoen' (Highest score in group: 1.95)
#   - berkenpollenseizoen:
#     - Short Def: 'seizoen waarin het berkenpollen vrijkomt...' (SFT: 1.58, FS: 1.93)
#   - binnenseizoen:
#     - Short Def: 'seizoen voor binnenwedstrijden e.d....' (SFT: 1.71, FS: 1.87)
#   - dansseizoen:
#     - Short Def: 'seizoen voor dans...' (SFT: 1.68, FS: 1.61)
#   - hoogseizoen:
#     - Short Def: 'drukste periode in een toeristisch seizo...' (SFT: 1.58, FS: 1.26)
#     - Short Def: 'drukste periode voor zekere activiteit...' (SFT: 1.67, FS: 1.62)
#   - naseizoen:
#     - Short Def: 'toeristische periode...' (SFT: 1.44, FS: 1.50)
#     - Short Def: 'wedstrijdperiode...' (SFT: 1.62, FS: 1.76)
#   - oogstseizoen:
#     - Short Def: 'seizoen om te oogsten...' (SFT: 1.56, FS: 1.75)
#   - speelseizoen:
#     - Short Def: 'seizoen met sporttrainingen en competiti...' (SFT: 1.74, FS: 1.68)
#     - Short Def: 'jaarlijkse periode met theatervoorstelli...' (SFT: 1.74, FS: 1.95)
#   - wereldbekerseizoen:
#     - Short Def: 'jaarlijkse competitieperiode voor de wer...' (SFT: 1.86, FS: 1.86)
# ------------------------------------------------------------
# Genus Proxima: 'verslaving' (Highest score in group: 1.95)
#   - mobieletelefoonverslaving:
#     - Short Def: 'verslaving aan de mobiele telefoon...' (SFT: 1.67, FS: 1.95)
#   - spelletjesverslaving:
#     - Short Def: 'verslaving aan spelletjes...' (SFT: 1.81, FS: 1.65)
# ------------------------------------------------------------
# Genus Proxima: 'markt' (Highest score in group: 1.95)
#   - autosupermarkt:
#     - Short Def: 'autodealer die allerlei merken auto's ve...' (SFT: 1.19, FS: 1.46)
#   - dumpsupermarkt:
#     - Short Def: 'supermarkt met restpartijen...' (SFT: 1.49, FS: 1.95)
#   - wereldautomarkt:
#     - Short Def: 'markt voor de wereldwijde autoverkoop...' (SFT: 1.90, FS: 1.71)
# ------------------------------------------------------------
# Genus Proxima: 'supermarkt' (Highest score in group: 1.95)
#   - autosupermarkt:
#     - Short Def: 'autodealer die allerlei merken auto's ve...' (SFT: 1.19, FS: 1.46)
#   - dumpsupermarkt:
#     - Short Def: 'supermarkt met restpartijen...' (SFT: 1.49, FS: 1.95)
# ------------------------------------------------------------
# Genus Proxima: 'onijn' (Highest score in group: 1.95)
#   - blauwvintonijn:
#     - Short Def: 'tonijnsoort...' (SFT: 1.02, FS: 1.67)
#   - proefkonijn:
#     - Short Def: 'konijn gebruikt voor dierproeven...' (SFT: 1.95, FS: 1.91)
#     - Short Def: 'proefpersoon...' (SFT: 1.61, FS: 1.62)
# ------------------------------------------------------------
# Genus Proxima: 'visserij' (Highest score in group: 1.95)
#   - palingvisserij:
#     - Short Def: 'het vissen op paling...' (SFT: 1.94, FS: 1.91)
#   - schelpdiervisserij:
#     - Short Def: 'het vissen op schelpdieren...' (SFT: 1.94, FS: 1.95)
#   - trawlervisserij:
#     - Short Def: 'zeevisserij met trawlers...' (SFT: 1.35, FS: 1.58)
# ------------------------------------------------------------
# Genus Proxima: 'ervisserij' (Highest score in group: 1.95)
#   - schelpdiervisserij:
#     - Short Def: 'het vissen op schelpdieren...' (SFT: 1.94, FS: 1.95)
#   - trawlervisserij:
#     - Short Def: 'zeevisserij met trawlers...' (SFT: 1.35, FS: 1.58)
# ------------------------------------------------------------
# Genus Proxima: 'swinkelier' (Highest score in group: 1.95)
#   - beleggingswinkelier:
#     - Short Def: 'uitbater van een beleggingswinkel...' (SFT: 1.95, FS: 1.92)
#   - dorpswinkelier:
#     - Short Def: 'uitbater van een dorpswinkel...' (SFT: 1.93, FS: 1.92)
# ------------------------------------------------------------
# Genus Proxima: 'tologie' (Highest score in group: 1.95)
#   - cytologie:
#     - Short Def: 'celbiologie...' (SFT: 1.50, FS: 1.95)
#   - hematologie:
# ...
#   - graaispaarder:
#     - Short Def: 'spaarder die op snelle rentewinst uit is...' (SFT: 1.48, FS: 1.63)
#   - huisbewaarder:
#     - Short Def: 'iemand die op een huis past...' (SFT: 0.91, FS: 1.12)
#     - Short Def: 'conciërge...' (SFT: 1.17, FS: 1.38)
#   - kustvaarder:
#     - Short Def: 'coaster...' (SFT: 1.11, FS: 0.77)
# ------------------------------------------------------------
# Genus Proxima: 'sbrief' (Highest score in group: 1.63)
#   - aanmaningsbrief:
#     - Short Def: 'brief met een aanmaning...' (SFT: 1.38, FS: 1.63)
#   - nieuwsbrief:
#     - Short Def: 'informatiebulletin...' (SFT: 0.98, FS: 1.28)
# ------------------------------------------------------------
# Genus Proxima: 'schoen' (Highest score in group: 1.62)
#   - handschoen:
#     - Short Def: 'kledingstuk dat de hand bedekt...' (SFT: 1.62, FS: 1.33)
#     - Short Def: 'kledingstuk dat de handen beschermt...' (SFT: 0.94, FS: 1.25)
#   - lakschoen:
#     - Short Def: 'verlakte schoen...' (SFT: 1.45, FS: 1.52)
# ------------------------------------------------------------
# Genus Proxima: 'rloos' (Highest score in group: 1.60)
#   - geurloos:
#     - Short Def: 'zonder geur...' (SFT: 1.49, FS: 1.55)
#   - sfeerloos:
#     - Short Def: 'zonder sfeer...' (SFT: 1.60, FS: 1.38)
#   - structuurloos:
#     - Short Def: 'zonder structuur...' (SFT: 1.56, FS: 1.53)
# ------------------------------------------------------------
# Genus Proxima: 'ikkertje' (Highest score in group: 1.60)
#   - opkikkertje:
#     - Short Def: 'iets wat opbeurt...' (SFT: 1.03, FS: 1.48)
#     - Short Def: 'middel dat opkikkert...' (SFT: 1.60, FS: 1.13)
#   - tikkertje:
#     - Short Def: 'krijgertje...' (SFT: 0.59, FS: 0.60)
#     - Short Def: 'rikketik...' (SFT: 0.65, FS: 0.61)
# ------------------------------------------------------------
# Genus Proxima: 'ender' (Highest score in group: 1.60)
#   - campingzender:
#     - Short Def: 'televisiezender met weinig diepgang...' (SFT: 1.49, FS: 1.60)
#   - metseldiender:
#     - Short Def: 'opperman...' (SFT: 1.06, FS: 0.77)
# ------------------------------------------------------------
# Genus Proxima: 'vleugel' (Highest score in group: 1.59)
#   - vleugel:
#     - Short Def: 'vliegorgaan van dieren vliegorgaan van e...' (SFT: 0.91, FS: 0.63)
#     - Short Def: 'draagvlak van een vliegtuig...' (SFT: 0.75, FS: 0.95)
#     - Short Def: 'symmetrische helft...' (SFT: 0.79, FS: 0.79)
#     - Short Def: 'haaks uitsteeksel...' (SFT: 0.89, FS: 0.82)
#     - Short Def: 'deel van een gebouw...' (SFT: 1.47, FS: 0.83)
#     - Short Def: 'groep van gelijke strekking...' (SFT: 1.19, FS: 1.56)
#     - Short Def: 'zijde van een terrein personen op een vl...' (SFT: 0.82, FS: 0.66)
#     - Short Def: 'stuk van een rog...' (SFT: 0.98, FS: 1.12)
#     - Short Def: 'verhevenheid op een auto...' (SFT: 0.93, FS: 0.60)
#     - Short Def: 'groot klavierinstrument...' (SFT: 0.92, FS: 0.94)
#     - Short Def: 'vliegorgaan van een mythisch wezen...' (SFT: 1.50, FS: 1.03)
#     - Short Def: 'kunstvleugel...' (SFT: 0.86, FS: 1.05)
#     - Short Def: 'voorstelling van een vleugel...' (SFT: 1.59, FS: 1.22)
#     - Short Def: 'vleugel als gerecht...' (SFT: 1.52, FS: 1.11)
#     - Short Def: 'personen op een vleugel...' (SFT: 0.79, FS: 0.85)
#     - Short Def: 'zijde van dambord of schaakbord...' (SFT: 0.78, FS: 1.15)
#     - Short Def: 'groep pionnen op de flank...' (SFT: 1.47, FS: 0.71)
#   - zwemvleugel:
#     - Short Def: 'opblaasbaar bandje om te blijven drijven...' (SFT: 1.04, FS: 1.20)
# ------------------------------------------------------------
# Genus Proxima: 'pinguïn' (Highest score in group: 1.59)
#   - keizerspinguïn:
#     - Short Def: 'grote Antarctische pinguïn...' (SFT: 1.34, FS: 0.82)
#   - koningspinguïn:
#     - Short Def: 'grote Antarctische pinguïn...' (SFT: 1.59, FS: 1.01)
#   - pinguïn:
#     - Short Def: 'vetgans...' (SFT: 0.98, FS: 0.72)
# ------------------------------------------------------------
# Genus Proxima: 'spinguïn' (Highest score in group: 1.59)
#   - keizerspinguïn:
#     - Short Def: 'grote Antarctische pinguïn...' (SFT: 1.34, FS: 0.82)
#   - koningspinguïn:
#     - Short Def: 'grote Antarctische pinguïn...' (SFT: 1.59, FS: 1.01)
# ------------------------------------------------------------
# Genus Proxima: 'assen' (Highest score in group: 1.58)
#   - boter wassen:
#     - Short Def: 'de karnemelk uit de boter kneden...' (SFT: 1.58, FS: 1.15)
#   - grimassen:
#     - Short Def: 'grimassen maken...' (SFT: 1.20, FS: 0.94)
# ------------------------------------------------------------
# Genus Proxima: 'hommel' (Highest score in group: 1.58)
#   - guerrillaschommel:
#     - Short Def: 'illegale schommel...' (SFT: 1.11, FS: 1.58)
#   - steenhommel:
#     - Short Def: 'zwart-rode hommel...' (SFT: 1.31, FS: 1.44)
# ------------------------------------------------------------
# Genus Proxima: 'icisme' (Highest score in group: 1.58)
#   - anglicisme:
#     - Short Def: 'onzuiver Engels taalelement...' (SFT: 1.51, FS: 1.58)
#   - belgicisme:
#     - Short Def: 'onzuiver Belgisch taalelement...' (SFT: 1.21, FS: 0.84)
#     - Short Def: 'unitarisme...' (SFT: 1.35, FS: 1.15)
#   - gallicisme:
#     - Short Def: 'onzuiver Frans taalelement...' (SFT: 1.34, FS: 1.04)
# ------------------------------------------------------------
# Genus Proxima: 'licisme' (Highest score in group: 1.58)
#   - anglicisme:
#     - Short Def: 'onzuiver Engels taalelement...' (SFT: 1.51, FS: 1.58)
#   - gallicisme:
#     - Short Def: 'onzuiver Frans taalelement...' (SFT: 1.34, FS: 1.04)
# ------------------------------------------------------------
# Genus Proxima: 'enpad' (Highest score in group: 1.57)
#   - binnenpad:
#     - Short Def: 'een pad binnendoor...' (SFT: 1.01, FS: 1.15)
#   - dievenpad:
#     - Short Def: 'sluippaadje...' (SFT: 1.26, FS: 1.17)
#   - olifantenpad:
#     - Short Def: 'sluipweggetje van fietsers of wandelaars...' (SFT: 1.57, FS: 1.20)
# ------------------------------------------------------------
# Genus Proxima: 'erseks' (Highest score in group: 1.57)
#   - breezerseks:
#     - Short Def: 'seks in ruil voor een breezer...' (SFT: 1.50, FS: 1.20)
#   - cyberseks:
#     - Short Def: 'seks op of via internet...' (SFT: 1.57, FS: 0.99)
# ------------------------------------------------------------
# Genus Proxima: 'emoji' (Highest score in group: 1.57)
#   - emoji:
#     - Short Def: 'Japans emoticon...' (SFT: 1.23, FS: 1.00)
#   - selfie-emoji:
#     - Short Def: 'emoji bij het maken van selfies...' (SFT: 1.55, FS: 1.57)
# ------------------------------------------------------------
# Genus Proxima: 'aille' (Highest score in group: 1.57)
#   - journaille:
#     - Short Def: 'sensatiebeluste journalisten...' (SFT: 1.57, FS: 0.92)
#   - trouvaille:
#     - Short Def: 'knappe vondst ontdekking...' (SFT: 1.51, FS: 1.46)
#     - Short Def: 'ontdekking...' (SFT: 1.17, FS: 1.37)
# ------------------------------------------------------------
# Genus Proxima: 'speriode' (Highest score in group: 1.56)
#   - bezinningsperiode:
#     - Short Def: 'periode waarin men zich bezint...' (SFT: 1.55, FS: 1.53)
#   - koopjesperiode:
#     - Short Def: 'periode voor uitverkoop...' (SFT: 1.56, FS: 1.50)
# ------------------------------------------------------------
# Genus Proxima: 'urloos' (Highest score in group: 1.56)
#   - geurloos:
#     - Short Def: 'zonder geur...' (SFT: 1.49, FS: 1.55)
#   - structuurloos:
#     - Short Def: 'zonder structuur...' (SFT: 1.56, FS: 1.53)
# ------------------------------------------------------------
# Genus Proxima: 'varken' (Highest score in group: 1.54)
#   - Iberisch varken:
#     - Short Def: 'varken van het Iberische schiereiland...' (SFT: 1.07, FS: 0.74)
#   - aardvarken:
#     - Short Def: 'Afrikaans zoogdier met varkenssnuit...' (SFT: 1.54, FS: 1.52)
# ------------------------------------------------------------
# Genus Proxima: 'beren' (Highest score in group: 1.53)
#   - flamberen:
#     - Short Def: 'drank op een gerecht aansteken...' (SFT: 1.42, FS: 1.35)
#     - Short Def: 'haar of veren wegschroeien...' (SFT: 1.31, FS: 1.22)
#   - ijsberen:
#     - Short Def: 'rusteloos heen en weer lopen...' (SFT: 1.53, FS: 1.08)
# ------------------------------------------------------------
# Genus Proxima: 'telling' (Highest score in group: 1.52)
#   - afbestelling:
#     - Short Def: 'het afzien van een bestelling...' (SFT: 1.52, FS: 1.46)
#   - storytelling:
#     - Short Def: 'methode om verhalen te delen...' (SFT: 1.38, FS: 1.10)
# ------------------------------------------------------------
# Genus Proxima: 'boord' (Highest score in group: 1.52)
#   - bakboord:
#     - Short Def: 'linkerzijde van een schip...' (SFT: 1.46, FS: 1.52)
#     - Short Def: 'links...' (SFT: 0.60, FS: 0.72)
#   - stuurboord:
#     - Short Def: 'rechterzijde van een schip...' (SFT: 1.40, FS: 1.04)
#     - Short Def: 'aan de rechterzijde van een schip...' (SFT: 1.25, FS: 1.04)
# ------------------------------------------------------------
# Genus Proxima: 'bekwaamheid' (Highest score in group: 1.51)
#   - wilsbekwaamheid:
#     - Short Def: 'het wilsbekwaam zijn...' (SFT: 0.88, FS: 1.26)
#   - wilsonbekwaamheid:
#     - Short Def: 'het wilsonbekwaam zijn...' (SFT: 1.09, FS: 1.51)
# ------------------------------------------------------------
# Genus Proxima: 'eweer' (Highest score in group: 1.51)
#   - aardappelgeweer:
#     - Short Def: 'schiettuig...' (SFT: 1.51, FS: 1.43)
#   - lenteweer:
#     - Short Def: 'weer zoals het in de lente is...' (SFT: 1.38, FS: 1.33)
# ------------------------------------------------------------
# Genus Proxima: 'ikker' (Highest score in group: 1.50)
#   - boomkikker:
#     - Short Def: 'inheemse, lichtgroene kikker...' (SFT: 1.29, FS: 1.46)
#     - Short Def: 'in bomen levende kikker...' (SFT: 0.92, FS: 1.05)
#   - degenslikker:
#     - Short Def: 'artiest die degens slikt...' (SFT: 1.27, FS: 1.18)
#   - driftkikker:
#     - Short Def: 'driftig persoon...' (SFT: 0.92, FS: 0.75)
#   - groene kikker:
#     - Short Def: 'kikker met een groene kleur...' (SFT: 1.49, FS: 1.50)
# ------------------------------------------------------------
# Genus Proxima: 'kikker' (Highest score in group: 1.50)
#   - boomkikker:
#     - Short Def: 'inheemse, lichtgroene kikker...' (SFT: 1.29, FS: 1.46)
#     - Short Def: 'in bomen levende kikker...' (SFT: 0.92, FS: 1.05)
#   - driftkikker:
#     - Short Def: 'driftig persoon...' (SFT: 0.92, FS: 0.75)
#   - groene kikker:
#     - Short Def: 'kikker met een groene kleur...' (SFT: 1.49, FS: 1.50)
# ------------------------------------------------------------
# Genus Proxima: 'scooter' (Highest score in group: 1.49)
#   - elektrische scooter:
#     - Short Def: 'e-scooter...' (SFT: 1.49, FS: 0.97)
#   - sjoemelscooter:
#     - Short Def: 'scooter waarmee gesjoemeld is...' (SFT: 1.18, FS: 1.40)
#     - Short Def: 'fatbike...' (SFT: 1.25, FS: 0.69)
# ------------------------------------------------------------
# Genus Proxima: 'swijn' (Highest score in group: 1.47)
#   - harswijn:
#     - Short Def: 'retsina soort harswijn...' (SFT: 0.78, FS: 1.13)
#   - kwaliteitswijn:
#     - Short Def: 'wijn van goede kwaliteit wijnsoort van g...' (SFT: 0.99, FS: 0.94)
#     - Short Def: 'wijnsoort van goede kwaliteit...' (SFT: 0.92, FS: 1.02)
#   - omfietswijn:
#     - Short Def: 'wijn om voor om te fietsen...' (SFT: 1.47, FS: 1.25)
# ------------------------------------------------------------
# Genus Proxima: 'tswijn' (Highest score in group: 1.47)
#   - kwaliteitswijn:
#     - Short Def: 'wijn van goede kwaliteit wijnsoort van g...' (SFT: 0.99, FS: 0.94)
#     - Short Def: 'wijnsoort van goede kwaliteit...' (SFT: 0.92, FS: 1.02)
#   - omfietswijn:
#     - Short Def: 'wijn om voor om te fietsen...' (SFT: 1.47, FS: 1.25)
# ------------------------------------------------------------
# Genus Proxima: 'atief' (Highest score in group: 1.47)
#   - tentatief:
#     - Short Def: 'proberend...' (SFT: 1.45, FS: 1.35)
#   - verneukeratief:
#     - Short Def: 'bedrieglijk...' (SFT: 1.47, FS: 0.92)
# ------------------------------------------------------------
# Genus Proxima: 'bewijs' (Highest score in group: 1.47)
#   - beginnersrijbewijs:
#     - Short Def: 'rijbewijs voor beginnende bestuurders...' (SFT: 1.18, FS: 0.86)
#   - schouwingsbewijs:
#     - Short Def: 'keuringsbewijs...' (SFT: 1.31, FS: 1.47)
# ------------------------------------------------------------
# Genus Proxima: 'loïde' (Highest score in group: 1.45)
#   - alkaloïde:
#     - Short Def: 'stikstofhoudende verbinding...' (SFT: 1.45, FS: 1.44)
#   - colloïde:
#     - Short Def: 'fijn stofdeeltje fijne stof...' (SFT: 0.70, FS: 0.70)
#     - Short Def: 'fijne stof...' (SFT: 1.17, FS: 1.22)
# ------------------------------------------------------------
# Genus Proxima: 'iering' (Highest score in group: 1.45)
#   - leerlinggebonden financiering:
#     - Short Def: 'extra financiering afgestemd op leerling...' (SFT: 1.42, FS: 1.45)
#   - vliering:
#     - Short Def: 'bergruimte onder het dak...' (SFT: 0.96, FS: 1.45)
# ------------------------------------------------------------
# Genus Proxima: 'dance' (Highest score in group: 1.43)
#   - breakdance:
#     - Short Def: 'acrobatische straatdans...' (SFT: 1.13, FS: 1.01)
#     - Short Def: 'kermisattractie...' (SFT: 0.86, FS: 1.43)
#   - streetdance:
#     - Short Def: 'dansstijl van de straat...' (SFT: 1.16, FS: 1.37)
# ------------------------------------------------------------
# Genus Proxima: 'ankhangen' (Highest score in group: 1.39)
#   - bankhangen:
#     - Short Def: 'op de bank hangen...' (SFT: 1.22, FS: 1.39)
#   - drankhangen:
#     - Short Def: 'met drank op de bank hangen...' (SFT: 0.85, FS: 1.21)
# ------------------------------------------------------------
# Genus Proxima: 'vlieg' (Highest score in group: 1.39)
#   - boorvlieg:
#     - Short Def: 'soort vlieg...' (SFT: 0.79, FS: 0.69)
#   - bromvlieg:
#     - Short Def: 'grote dikke vlieg...' (SFT: 1.39, FS: 1.18)
#   - paardenvlieg:
#     - Short Def: 'daas...' (SFT: 0.87, FS: 0.87)
#   - strontvlieg:
#     - Short Def: 'vlieg die nabij drek leeft...' (SFT: 1.33, FS: 1.07)
# ------------------------------------------------------------
# Genus Proxima: 'cockerspaniël' (Highest score in group: 1.38)
#   - Amerikaanse cockerspaniël:
#     - Short Def: 'soort cockerspaniël...' (SFT: 0.53, FS: 1.38)
#   - cockerspaniël:
#     - Short Def: 'jachthond met lange oren...' (SFT: 1.07, FS: 0.94)
# ------------------------------------------------------------
# Genus Proxima: 'poedel' (Highest score in group: 1.35)
#   - dwergpoedel:
#     - Short Def: 'kleine poedel...' (SFT: 0.99, FS: 1.27)
#   - poedel:
#     - Short Def: 'gezelschapshond met geschoren kroesvacht...' (SFT: 0.95, FS: 1.03)
#     - Short Def: 'fatterige man...' (SFT: 1.00, FS: 0.66)
#     - Short Def: 'kruiperig iemand...' (SFT: 1.35, FS: 0.84)
#     - Short Def: 'misstap of slechte worp...' (SFT: 1.16, FS: 1.29)
# ------------------------------------------------------------
# Genus Proxima: 'random' (Highest score in group: 1.29)
#   - at random:
#     - Short Def: 'door willekeur bepaald...' (SFT: 1.09, FS: 1.29)
#   - random:
#     - Short Def: 'door willekeur bepaald...' (SFT: 1.09, FS: 1.15)
# ------------------------------------------------------------
# Genus Proxima: 'e walvis' (Highest score in group: 1.28)
#   - Groenlandse walvis:
#     - Short Def: 'walvis met grote baleinen...' (SFT: 0.87, FS: 1.28)
#   - witte walvis:
#     - Short Def: 'beloega...' (SFT: 1.00, FS: 0.73)
# ------------------------------------------------------------
# Genus Proxima: 'bijter' (Highest score in group: 1.20)
#   - bullenbijter:
#     - Short Def: 'buldog...' (SFT: 0.97, FS: 0.67)
#     - Short Def: 'barse man...' (SFT: 0.98, FS: 0.78)
#   - ijzerbijter:
#     - Short Def: 'doorzetter...' (SFT: 1.12, FS: 1.20)
#     - Short Def: 'zwartkijker...' (SFT: 0.60, FS: 1.20)
# ------------------------------------------------------------
# Genus Proxima: 'sjaal' (Highest score in group: 1.18)
#   - arafatsjaal:
#     - Short Def: 'sjaal door Arafat gedragen...' (SFT: 0.84, FS: 0.99)
#   - palestinasjaal:
#     - Short Def: 'arafatsjaal...' (SFT: 1.18, FS: 0.83)
# ------------------------------------------------------------
# Genus Proxima: 'eiwijn' (Highest score in group: 1.10)
#   - gloeiwijn:
#     - Short Def: 'warme, toebereide wijn soort gloeiwijn p...' (SFT: 1.10, FS: 0.82)
#   - meiwijn:
#     - Short Def: 'lichte witte wijn met onzelievevrouwebed...' (SFT: 0.69, FS: 0.79)
# ------------------------------------------------------------
