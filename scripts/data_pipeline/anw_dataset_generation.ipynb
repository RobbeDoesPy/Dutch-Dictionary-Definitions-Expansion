# %% [markdown]
# ### **Mount Google Drive**
# (This lets me save files directly to my Drive.)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### **Download the JSON Lemma List**

# %%
import requests
import json

# URL for the JSON lemma list
lemmalist_url = "https://anw.ivdnt.org/backend/lemmalist?output=json"

# Download the JSON lemma list
response = requests.get(lemmalist_url)
response.raise_for_status()  # Stop if there is an error
lemmalist = response.json()

# Print out the total number of lemmas to confirm download
print(f"Total lemmas in the list: {len(lemmalist)}")
# Out:
# Total lemmas in the list: 87196

# %%
lemmalist[:10]

# %% [markdown]
# ## Test Set

# %% [markdown]
# ### **Extract Definitions**

# %% [markdown]
# This cell loops over the first 100 lemmas, skips those with no definitions, fetches their XML pages, extracts definitions from both <Kernbetekenis> and <Subbetekenis> elements and stores the results

# %%
# If resuming after a failure, set start_index to the lemma index where you left off.
start_index = 0

# Set test_limit to a number for a partial run, or None to run through all lemmas.
test_limit = 100  # For testing, I'll process 100 lemmas. Set to None for a complete run.

# %%
import time
from lxml import etree  # lxml is more tolerant than xml.etree.ElementTree

results = []  # This list will hold our output rows.
# List to track lemmas that are expected to have definitions (per JSON) but yield none.
missing_definitions = []

# Loop through lemmas from the specified start index.
for i, entry in enumerate(lemmalist[start_index:], start=start_index):
    if test_limit is not None and i >= start_index + test_limit:
        break

    lemma = entry[0]
    has_no_definition = entry[-1]  # true means no definition available

    # Skip lemmas that JSON says don't have a definition.
    if has_no_definition:
        continue

    print(f"Processing lemma: {lemma} (index {i})")

    # Fetch the XML for this lemma.
    article_url = f"https://anw.ivdnt.org/article/{lemma}?output=xml"
    xml_resp = requests.get(article_url)

    if xml_resp.status_code != 200:
        print(f"Failed to fetch XML for {lemma}")
        missing_definitions.append(lemma)
        continue

    try:
        # Use lxml's parser in recover mode to handle unescaped characters.
        parser = etree.XMLParser(recover=True)
        root = etree.fromstring(xml_resp.content, parser=parser)
    except Exception as e:
        print(f"Error parsing XML for {lemma}: {e}")
        missing_definitions.append(lemma)
        continue

    # Get the article-level lemma_id from the <artikel> element's pid attribute.
    article_lemma_id = root.attrib.get("pid", "")

    # Extract meanings from both <Kernbetekenis> and <Subbetekenis>.
    meaning_elements = root.xpath(".//Kernbetekenis") + root.xpath(".//Subbetekenis")

    if not meaning_elements:
        # If no meaning elements are found, track this lemma.
        missing_definitions.append(lemma)
    else:
        for me in meaning_elements:
            # Get POS from <Woordsoort>/<Type> (if present).
            pos_list = me.xpath(".//Woordsoort/Type/text()")
            pos = " ".join(pos_list).strip() if pos_list else ""

            # Get the meaning number from the element's id attribute (e.g., "bet1.0").
            betekenisnummer = me.attrib.get("id", "")
            if betekenisnummer.startswith("bet"):
                betekenisnummer = betekenisnummer[3:]

            # Get the meaning ID from the element's pid attribute.
            betekenis_id = me.attrib.get("pid", "")

            # Get the full definition (long) from <Definitie> (all nested text).
            definitie_text = " ".join(me.xpath(".//Definitie//text()")).strip()
            # Get the mini definition (short) from <Minidefinitie> (all nested text).
            minidef_text = " ".join(me.xpath(".//Minidefinitie//text()")).strip()

            results.append([lemma, pos, betekenisnummer, article_lemma_id, betekenis_id, definitie_text, minidef_text])

    time.sleep(0.1)

print(f"Processed records for lemmas with indices {start_index} to {i}. Total rows: {len(results)}")

# Verify that every lemma expected to have a definition (per JSON) is in the results.
# Define the end index based on test_limit.
end_index = start_index + test_limit if test_limit is not None else None
expected_lemmas = {entry[0] for entry in lemmalist[start_index:end_index] if not entry[-1]}
actual_lemmas = {row[0] for row in results}
lemmas_missing_in_results = expected_lemmas - actual_lemmas

if lemmas_missing_in_results:
    print("The following lemmas were expected to have definitions but are missing in the results:")
    print(lemmas_missing_in_results)
else:
    print("All lemmas expected to have definitions are present in the results.")

print("Lemmas with issues during processing (missing definitions):")
print(missing_definitions)
# Out:
# Processing lemma: #MeToo (index 0)
# Processing lemma: 06-dealer (index 2)
# Processing lemma: 06-nummer (index 3)
# Processing lemma: 06-prostitutie (index 4)
# Processing lemma: 1,5 metereconomie (index 7)
# Processing lemma: 1,5 metermaatschappij (index 8)
# Processing lemma: 1,5 metersamenleving (index 9)
# Processing lemma: 1 april (index 10)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-389be154e03a> in <cell line: 0>()
#      68             results.append([lemma, pos, betekenisnummer, article_lemma_id, betekenis_id, definitie_text, minidef_text])
#      69
# ---> 70     time.sleep(0.1)
#      71
#      72 print(f"Processed records for lemmas with indices {start_index} to {i}. Total rows: {len(results)}")
#
# KeyboardInterrupt:

# %% [markdown]
# ### **Save the Results to a TSV File**

# %%
import csv
import os  # The os library is used here to handle file paths and ensure the output folder exists.

output_folder = "/content/drive/My Drive/Colab Notebooks/Thesis"
os.makedirs(output_folder, exist_ok=True)  # Create the folder if it doesn't already exist.
output_tsv = os.path.join(output_folder, "anw_definitions_test.tsv")

with open(output_tsv, mode="w", encoding="utf-8", newline="") as tsvfile:
    writer = csv.writer(tsvfile, delimiter="\t")
    # Write a header row corresponding to our target columns:
    writer.writerow([
        "Lemma",         # The headword
        "POS",           # Part of Speech
        "MeaningNumber", # e.g., 1.0 or 1.1 (extracted from the meaning element's id)
        "LemmaID",       # The lemma ID from the article-level attribute
        "MeaningID",     # The meaning ID from the meaning element's attribute
        "DefinitionFull",# Full (long) definition text
        "DefinitionShort"# Mini (short) definition text
    ])
    writer.writerows(results)

print(f"Results written to {output_tsv}")
# Out:
# Results written to /content/drive/My Drive/Colab Notebooks/Thesis/anw_definitions_test.tsv

# %% [markdown]
# ## Full Dataset

# %%
# If resuming after a failure, set start_index to the lemma index where you left off.
start_index = 0

# Set test_limit to a number for a partial run, or None to run through all lemmas.
test_limit = None  # For testing, I'll process 100 lemmas. Set to None for a complete run.

# Define batch size for processing (number of lemmas per batch).
batch_size = 1000  # Adjust based on your needs; a larger batch means fewer checkpoints

# %% [markdown]
# Set Up Environment & Helper Function

# %%
import os
import time
import csv
from lxml import etree
import requests
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry

# Set up a requests session with retry logic
session = requests.Session()
retry = Retry(total=5, backoff_factor=1, status_forcelist=[429, 500, 502, 503, 504])
adapter = HTTPAdapter(max_retries=retry)
session.mount('http://', adapter)
session.mount('https://', adapter)

def process_batch(lemmalist, start_index, batch_size):
    """
    Process a batch of lemmas from the lemmalist starting at start_index,
    processing up to batch_size entries.

    Returns:
      batch_results: list of rows (one per meaning) with:
         [Lemma, POS, MeaningNumber, LemmaID, MeaningID, DefinitionFull, DefinitionShort]
      batch_missing: list of lemmas (strings) that were expected to have definitions but yielded none.
    """
    batch_results = []
    batch_missing = []
    # If test_limit is set, restrict the end index further.
    end_index = start_index + batch_size
    if test_limit is not None:
        end_index = min(end_index, start_index + test_limit)

    for i, entry in enumerate(lemmalist[start_index:end_index], start=start_index):
        lemma = entry[0]
        has_no_definition = entry[-1]  # True means JSON says no definition

        # Skip lemmas that JSON indicates don't have a definition.
        if has_no_definition:
            continue

        print(f"Processing lemma: {lemma} (index {i})")

        article_url = f"https://anw.ivdnt.org/article/{lemma}?output=xml"
        try:
            xml_resp = session.get(article_url, timeout=10)
            xml_resp.raise_for_status()
        except Exception as e:
            print(f"Failed to fetch XML for {lemma}: {e}")
            batch_missing.append(lemma)
            continue

        try:
            parser = etree.XMLParser(recover=True)
            root = etree.fromstring(xml_resp.content, parser=parser)
        except Exception as e:
            print(f"Error parsing XML for {lemma}: {e}")
            batch_missing.append(lemma)
            continue

        # Get article-level lemma ID from the <artikel> element's pid attribute.
        article_lemma_id = root.attrib.get("pid", "")
        # Extract meanings from both <Kernbetekenis> and <Subbetekenis>.
        meaning_elements = root.xpath(".//Kernbetekenis") + root.xpath(".//Subbetekenis")

        if not meaning_elements:
            batch_missing.append(lemma)
        else:
            for me in meaning_elements:
                pos_list = me.xpath(".//Woordsoort/Type/text()")
                pos = " ".join(pos_list).strip() if pos_list else ""
                betekenisnummer = me.attrib.get("id", "")
                if betekenisnummer.startswith("bet"):
                    betekenisnummer = betekenisnummer[3:]
                betekenis_id = me.attrib.get("pid", "")
                definitie_text = " ".join(me.xpath(".//Definitie//text()")).strip()
                minidef_text = " ".join(me.xpath(".//Minidefinitie//text()")).strip()
                batch_results.append([lemma, pos, betekenisnummer, article_lemma_id, betekenis_id, definitie_text, minidef_text])

        time.sleep(0.1)

    return batch_results, batch_missing

# %% [markdown]
#  Batch Processing Loop with Checkpointing

# %%
# Parameters and output file paths
total_lemmas = len(lemmalist)
output_folder = "/content/drive/My Drive/Colab Notebooks/Thesis"
os.makedirs(output_folder, exist_ok=True)
output_tsv = os.path.join(output_folder, "definitions.tsv")
checkpoint_file = os.path.join(output_folder, "checkpoint.txt")
missing_file = os.path.join(output_folder, "missing_definitions.txt")

# Determine starting point from checkpoint, if available.
if os.path.exists(checkpoint_file):
    with open(checkpoint_file, "r") as cp:
        try:
            start_index = int(cp.read().strip())
            print(f"Resuming from index {start_index}")
        except:
            print("Could not parse checkpoint; starting from 0.")
            start_index = 0

# Determine end_index based on test_limit (if set)
if test_limit is not None:
    end_index = start_index + test_limit
else:
    end_index = total_lemmas

# If starting from 0, write header; otherwise, open in append mode.
write_header = start_index == 0
mode = "w" if write_header else "a"

all_missing = []  # To collect missing definitions across all batches.

with open(output_tsv, mode=mode, encoding="utf-8", newline="") as tsvfile:
    writer = csv.writer(tsvfile, delimiter="\t")
    if write_header:
        writer.writerow(["Lemma", "POS", "MeaningNumber", "LemmaID", "MeaningID", "DefinitionFull", "DefinitionShort"])

    # Process batches until we reach the end of the lemma list (or test_limit if set).
    for batch_start in range(start_index, total_lemmas, batch_size):
        # If test_limit is set and we exceed it, break.
        if test_limit is not None and batch_start >= start_index + test_limit:
            break

        print(f"Processing batch starting at index {batch_start}")
        batch_results, batch_missing = process_batch(lemmalist, batch_start, batch_size)
        writer.writerows(batch_results)
        all_missing.extend(batch_missing)

        # Update checkpoint after each batch.
        current_index = batch_start + batch_size
        with open(checkpoint_file, "w") as cp:
            cp.write(str(current_index))
        print(f"Batch complete. Checkpoint updated to {current_index}.")

print("All batches processed.")

# Write out missing definitions to a file.
with open(missing_file, "w", encoding="utf-8") as mf:
    for lemma in sorted(set(all_missing)):
        mf.write(lemma + "\n")

print(f"Results written to {output_tsv}")
print(f"Lemmas missing definitions have been saved to {missing_file}")
# Out:
# Streaming output truncated to the last 5000 lines.
# Processing lemma: toesnibben (index 71179)
# Processing lemma: toestel (index 71187)
# Processing lemma: toeter (index 71194)
# Processing lemma: toeters en bellen (index 71196)
# Processing lemma: toetje (index 71198)
# Processing lemma: toetsenbordterrorist (index 71210)
# Processing lemma: toeval (index 71225)
# Processing lemma: toevalsfactor (index 71229)
# Processing lemma: toezichthouder (index 71258)
# Processing lemma: TOFA (index 71262)
# Processing lemma: tofoe (index 71264)
# Processing lemma: tofu (index 71265)
# Processing lemma: toiletangst (index 71268)
# Processing lemma: toiletbezoek (index 71269)
# Processing lemma: toiletbezoeker (index 71270)
# Processing lemma: toiletborstel (index 71271)
# Processing lemma: toiletbril (index 71272)
# Processing lemma: toiletpapier (index 71277)
# Processing lemma: toiletpapiertje (index 71278)
# Processing lemma: toiletpot (index 71279)
# Processing lemma: toiletrol (index 71280)
# Processing lemma: toiletrolhouder (index 71281)
# Processing lemma: toiletrolletje (index 71282)
# Processing lemma: toiletwinkel (index 71289)
# Processing lemma: tolhuis (index 71302)
# Processing lemma: tolk (index 71303)
# Processing lemma: tolkantoor (index 71304)
# Processing lemma: tolueen (index 71310)
# Processing lemma: tom collins (index 71314)
# Processing lemma: tomaat (index 71315)
# Processing lemma: tomaat crevette (index 71316)
# Processing lemma: tomaat garnaal (index 71317)
# Processing lemma: tomatensalade (index 71321)
# Processing lemma: tomatenteelt (index 71324)
# Processing lemma: tomatenteler (index 71325)
# Processing lemma: tomboy (index 71326)
# Processing lemma: tomografie (index 71329)
# Processing lemma: toneelauteur (index 71337)
# Processing lemma: toneelavond (index 71338)
# Processing lemma: toneelcritica (index 71342)
# Processing lemma: toneelcriticus (index 71343)
# Processing lemma: toneeldocent (index 71345)
# Processing lemma: toneelkijker (index 71352)
# Processing lemma: toneelliefhebber (index 71361)
# Processing lemma: toneelrecensent (index 71373)
# Processing lemma: toneelrecensente (index 71374)
# Processing lemma: toneelschool (index 71376)
# Processing lemma: toneelschrijfster (index 71378)
# Processing lemma: toneelschrijver (index 71379)
# Processing lemma: toneelseizoen (index 71380)
# Processing lemma: toneelspeler (index 71383)
# Processing lemma: toner (index 71396)
# Processing lemma: tong (index 71397)
# Processing lemma: tongen (index 71399)
# Processing lemma: tongpiercing (index 71401)
# Processing lemma: tongpunt (index 71402)
# Processing lemma: tongzoen (index 71409)
# Processing lemma: tongzoenen (index 71410)
# Processing lemma: tonic (index 71411)
# Processing lemma: tonica (index 71412)
# Processing lemma: tonijn (index 71413)
# Processing lemma: tonijnsalade (index 71414)
# Processing lemma: tonisch (index 71417)
# Processing lemma: tonische aanval (index 71418)
# Processing lemma: tonische fase (index 71419)
# Processing lemma: tonische reflex (index 71420)
# Processing lemma: tonische spieren (index 71421)
# Processing lemma: tonisch-klonische aanval (index 71422)
# Processing lemma: TONK (index 71423)
# Processing lemma: tonus (index 71426)
# Processing lemma: tooghanger (index 71428)
# Processing lemma: tooi (index 71430)
# Processing lemma: toondichter (index 71438)
# Processing lemma: toonhaai (index 71441)
# Processing lemma: toost (index 71457)
# Processing lemma: toosten (index 71458)
# Processing lemma: toot (index 71460)
# Processing lemma: topaas (index 71465)
# Processing lemma: topambtenaar (index 71470)
# Processing lemma: topdorp (index 71495)
# Processing lemma: tophypotheek (index 71508)
# Processing lemma: topic (index 71509)
# Processing lemma: topjaar (index 71513)
# Processing lemma: topologie (index 71532)
# Processing lemma: toponiem (index 71537)
# Processing lemma: topos (index 71540)
# Processing lemma: toppen (index 71544)
# Processing lemma: toppredator (index 71551)
# Processing lemma: topschool (index 71561)
# Processing lemma: topsporter (index 71569)
# Processing lemma: toptalent (index 71575)
# Processing lemma: toptienspeler (index 71579)
# Processing lemma: topvoetbal (index 71587)
# Processing lemma: topvoetballer (index 71588)
# Processing lemma: topwedstrijd (index 71591)
# Processing lemma: topwijn (index 71594)
# Processing lemma: toque (index 71597)
# Processing lemma: tor (index 71598)
# Processing lemma: toren (index 71599)
# Processing lemma: toren van Babel (index 71600)
# Processing lemma: torenvalk (index 71604)
# Processing lemma: torero (index 71605)
# Processing lemma: Torhoutenaar (index 71606)
# Processing lemma: Torhoutse (index 71608)
# Processing lemma: torinstinct (index 71609)
# Processing lemma: tors (index 71616)
# Processing lemma: torso (index 71618)
# Processing lemma: tortel (index 71619)
# Processing lemma: tortelduif (index 71620)
# Processing lemma: Toscaan (index 71621)
# Processing lemma: Toscaanse (index 71623)
# Processing lemma: toss (index 71624)
# Processing lemma: tossen (index 71625)
# Processing lemma: tot achter zijn oren blozen (index 71628)
# Processing lemma: tot achter zijn oren kleuren (index 71629)
# Processing lemma: tot achter zijn oren rood worden (index 71630)
# Processing lemma: tot de dag van vandaag (index 71631)
# Processing lemma: tot het hart spreken (index 71632)
# Processing lemma: tot het hart van de zaak komen (index 71633)
# Processing lemma: tot iemands botte hersens doordringen (index 71634)
# Processing lemma: tot in de vingertoppen (index 71635)
# Processing lemma: tot in de wortels van iemands haar of haren (index 71636)
# Processing lemma: tot in het kleinste detail (index 71637)
# Processing lemma: tot in lengte van dagen (index 71638)
# Processing lemma: tot nader datum (index 71639)
# Processing lemma: tot nut van het algemeen (index 71640)
# Processing lemma: tot op de dag van vandaag (index 71641)
# Processing lemma: tot op het bot (index 71642)
# Processing lemma: tot over zijn oren verliefd zijn (index 71643)
# Processing lemma: tot pap (index 71644)
# Processing lemma: tot pap schieten (index 71645)
# Processing lemma: tot pap slaan (index 71646)
# Processing lemma: tot 's avonds (index 71647)
# Processing lemma: tot vanavond (index 71648)
# Processing lemma: tot vanmiddag (index 71649)
# Processing lemma: totaalverbod (index 71681)
# Processing lemma: totaalvoetbal (index 71683)
# Processing lemma: totebag (index 71691)
# Processing lemma: toucheren (index 71694)
# Processing lemma: touchscreen (index 71695)
# Processing lemma: touperen (index 71696)
# Processing lemma: Tourdirecteur (index 71697)
# Processing lemma: tournedos (index 71699)
# Processing lemma: tourniquet (index 71700)
# Processing lemma: Tourzege (index 71704)
# Processing lemma: touwen (index 71707)
# Processing lemma: touwtrekwedstrijd (index 71709)
# Processing lemma: t.o.v. (index 71711)
# Processing lemma: tovenaar (index 71712)
# Processing lemma: tovenaarsschool (index 71714)
# Processing lemma: tovenares (index 71715)
# Processing lemma: toverbal (index 71718)
# Processing lemma: toverdrank (index 71721)
# Processing lemma: toveres (index 71723)
# Processing lemma: toverschool (index 71729)
# Processing lemma: toxische hepatitis (index 71737)
# Processing lemma: Tozo (index 71738)
# Processing lemma: T-profiel (index 71739)
# Processing lemma: traagzaam (index 71742)
# Processing lemma: tractor (index 71762)
# Processing lemma: tradwife (index 71766)
# Processing lemma: trafikant (index 71767)
# Processing lemma: traineeship (index 71770)
# Processing lemma: trainer (index 71772)
# Processing lemma: trainer-speler (index 71781)
# Processing lemma: trainersschool (index 71782)
# Processing lemma: trainingsavond (index 71790)
# Processing lemma: trainingsmogelijkheid (index 71802)
# Processing lemma: trainingspak (index 71804)
# Processing lemma: traject (index 71816)
# Processing lemma: trajectbegeleider (index 71817)
# Processing lemma: tram (index 71826)
# Processing lemma: trampolinepremie (index 71834)
# Processing lemma: tramtunnel (index 71836)
# Processing lemma: tranentrekker (index 71845)
# Processing lemma: tranq (index 71847)
# Processing lemma: tranquillizer (index 71848)
# Processing lemma: transcriberen (index 71853)
# Processing lemma: transcript (index 71854)
# Processing lemma: transfeminien (index 71855)
# Processing lemma: transferperiode (index 71860)
# Processing lemma: transferunie (index 71863)
# Processing lemma: transfobie (index 71867)
# Processing lemma: transfoob (index 71868)
# Processing lemma: transfusie (index 71872)
# Processing lemma: transgemeenschap (index 71874)
# Processing lemma: transgender (index 71875)
# Processing lemma: transgendergemeenschap (index 71876)
# Processing lemma: transgenderisme (index 71877)
# Processing lemma: transgenderist (index 71878)
# Processing lemma: transgenderwet (index 71879)
# Processing lemma: transitiespijt (index 71884)
# Processing lemma: transitievergoeding (index 71885)
# Processing lemma: transitieverlof (index 71886)
# Processing lemma: transitopassagier (index 71888)
# Processing lemma: translatie (index 71890)
# Processing lemma: transman (index 71891)
# Processing lemma: transmasculien (index 71892)
# Processing lemma: transmens (index 71893)
# Processing lemma: transpersoon (index 71899)
# Processing lemma: transponder (index 71908)
# Processing lemma: transportmogelijkheid (index 71927)
# Processing lemma: transportscooter (index 71933)
# Processing lemma: transpositie (index 71945)
# Processing lemma: transseksueel (index 71947)
# Processing lemma: transversaal (index 71948)
# Processing lemma: transvrouw (index 71949)
# Processing lemma: trapgans (index 71954)
# Processing lemma: trapgevel (index 71955)
# Processing lemma: trappenhuis (index 71963)
# Processing lemma: trappist (index 71965)
# Processing lemma: trappistenbier (index 71966)
# Processing lemma: trapvogel (index 71971)
# Processing lemma: trauma (index 71973)
# Processing lemma: traumabus (index 71974)
# Processing lemma: traumatologie (index 71979)
# Processing lemma: travee (index 71982)
# Processing lemma: traverse (index 71983)
# Processing lemma: trawler (index 71984)
# Processing lemma: trawlervisserij (index 71985)
# Processing lemma: traybake (index 71986)
# Processing lemma: trechterspin (index 71988)
# Processing lemma: trechtervormig (index 71989)
# Processing lemma: trefw. (index 71999)
# Batch complete. Checkpoint updated to 72000.
# Processing batch starting at index 72000
# Processing lemma: treiler (index 72002)
# Processing lemma: treinbegeleider (index 72005)
# Processing lemma: treinbestuurder (index 72006)
# Processing lemma: treinconducteur (index 72008)
# Processing lemma: treinen (index 72010)
# Processing lemma: treinkaartje (index 72012)
# Processing lemma: treinmachinist (index 72014)
# Processing lemma: treinongeluk (index 72015)
# Processing lemma: treinongeval (index 72016)
# Processing lemma: treinpassagier (index 72017)
# Processing lemma: treinramp (index 72020)
# Processing lemma: treinreiziger (index 72022)
# Processing lemma: treinrukker (index 72025)
# Processing lemma: treinsafari (index 72026)
# Processing lemma: treintaxi (index 72029)
# Processing lemma: treintunnel (index 72033)
# Processing lemma: treinviaduct (index 72038)
# Processing lemma: treinwachter (index 72039)
# Processing lemma: treinwagon (index 72040)
# Processing lemma: trekdier (index 72047)
# Processing lemma: trekharmonica (index 72050)
# Processing lemma: trekken aan een dood paard (index 72054)
# Processing lemma: trekpaard (index 72063)
# Processing lemma: trekpleister (index 72064)
# Processing lemma: trekschuit (index 72068)
# Processing lemma: trekteller (index 72073)
# Processing lemma: trektijd (index 72074)
# Processing lemma: trekvogel (index 72077)
# Processing lemma: trekzak (index 72080)
# Processing lemma: trema (index 72081)
# Processing lemma: tremolo (index 72082)
# Processing lemma: trenchcoat (index 72083)
# Processing lemma: trending (index 72089)
# Processing lemma: trending topic (index 72090)
# Processing lemma: trendsetter (index 72092)
# Processing lemma: trendwatcher (index 72093)
# Processing lemma: trendy (index 72094)
# Processing lemma: trens (index 72095)
# Processing lemma: treurbuis (index 72099)
# Processing lemma: tri (index 72112)
# Processing lemma: triangel (index 72113)
# Processing lemma: triangelbikini (index 72114)
# Processing lemma: tribalisme (index 72115)
# Processing lemma: trichloorethyleen (index 72119)
# Processing lemma: tricolore (index 72120)
# Processing lemma: trien (index 72121)
# Processing lemma: trigender (index 72126)
# Processing lemma: triggeren (index 72127)
# Processing lemma: triggerwarning (index 72128)
# Processing lemma: triktrak (index 72130)
# Processing lemma: triljard (index 72131)
# Processing lemma: triljoen (index 72132)
# Processing lemma: trimester (index 72140)
# Processing lemma: trimloopvierdaagse (index 72142)
# Processing lemma: triniteit (index 72147)
# Processing lemma: triobaan (index 72149)
# Processing lemma: tripes à la mode de Caen (index 72163)
# Processing lemma: triple A (index 72164)
# Processing lemma: Triple Entente (index 72165)
# Processing lemma: triplet (index 72166)
# Processing lemma: trippen (index 72169)
# Processing lemma: trips (index 72170)
# Processing lemma: triptiek (index 72171)
# Processing lemma: tritium (index 72172)
# Processing lemma: triton (index 72173)
# Processing lemma: trivialiseren (index 72175)
# Processing lemma: troefcall (index 72182)
# Processing lemma: troefcallen (index 72184)
# Processing lemma: troela (index 72189)
# Processing lemma: troetelkind (index 72201)
# Processing lemma: troffel (index 72203)
# Processing lemma: troggelen (index 72204)
# Processing lemma: trogon (index 72205)
# Processing lemma: Trojaans paard (index 72207)
# Processing lemma: trolley (index 72209)
# Processing lemma: trolleybus (index 72210)
# Processing lemma: trombone (index 72211)
# Processing lemma: tromboneschool (index 72212)
# Processing lemma: trommel (index 72214)
# Processing lemma: trommelaar (index 72215)
# Processing lemma: trompe-l'oeil (index 72221)
# Processing lemma: trompet (index 72222)
# Processing lemma: trompetvogel (index 72226)
# Processing lemma: tronie (index 72227)
# Processing lemma: troonrede (index 72230)
# Processing lemma: troonsafstand (index 72231)
# Processing lemma: troonsbestijging (index 72232)
# Processing lemma: troonswisseling (index 72233)
# Processing lemma: tropenhelm (index 72247)
# Processing lemma: tropensmoking (index 72249)
# Processing lemma: tropische dag (index 72251)
# Processing lemma: tropischeplantenteelt (index 72252)
# Processing lemma: troposfeer (index 72254)
# Processing lemma: trosbes (index 72255)
# Processing lemma: trots (index 72257)
# Processing lemma: trottinet (index 72262)
# Processing lemma: trottinette (index 72263)
# Processing lemma: trottoir (index 72264)
# Processing lemma: troubleshooter (index 72267)
# Processing lemma: trouvaille (index 72268)
# Processing lemma: trouwambtenaar (index 72270)
# Processing lemma: trouwdag (index 72272)
# Processing lemma: trouwjurk (index 72282)
# Processing lemma: trouwkleed (index 72285)
# Processing lemma: trouwplanner (index 72288)
# Processing lemma: true crime (index 72300)
# Processing lemma: trui (index 72301)
# Processing lemma: tsaar (index 72309)
# Processing lemma: tsarina (index 72312)
# Processing lemma: tseetseevlieg (index 72313)
# Processing lemma: T-shirt (index 72314)
# Processing lemma: T-shirtbeha (index 72315)
# Processing lemma: Tsjech (index 72316)
# Processing lemma: Tsjechische (index 72317)
# Processing lemma: tsjilp (index 72320)
# Processing lemma: tsjilpen (index 72321)
# Processing lemma: tsunami (index 72324)
# Processing lemma: tsundoku (index 72326)
# Processing lemma: Tswana (index 72327)
# Processing lemma: t.t.v. (index 72328)
# Processing lemma: TTV (index 72329)
# Processing lemma: t.t.z. (index 72330)
# Processing lemma: tu quoque (index 72331)
# Processing lemma: tuba (index 72332)
# Processing lemma: tubifex (index 72334)
# Processing lemma: tuchtschool (index 72347)
# Processing lemma: tuigdorp (index 72354)
# Processing lemma: tuigen (index 72355)
# Processing lemma: tuigpaard (index 72356)
# Processing lemma: tuil (index 72357)
# Processing lemma: tuimelaar (index 72358)
# Processing lemma: tuinarchitect (index 72363)
# Processing lemma: tuinblog (index 72366)
# Processing lemma: tuinbloggen (index 72367)
# Processing lemma: tuinblogger (index 72368)
# Processing lemma: tuinbouwer (index 72371)
# Processing lemma: tuinbouwraad (index 72377)
# Processing lemma: tuinbouwschool (index 72378)
# Processing lemma: tuinbroek (index 72380)
# Processing lemma: tuinder (index 72381)
# Processing lemma: tuinfluiter (index 72385)
# Processing lemma: tuinhommel (index 72388)
# Processing lemma: tuinier (index 72390)
# Processing lemma: tuinkabouter (index 72394)
# Processing lemma: tuinkat (index 72396)
# Processing lemma: tuinliefhebber (index 72400)
# Processing lemma: tuinman (index 72401)
# Processing lemma: tuinpad (index 72408)
# Processing lemma: tuitknak (index 72422)
# Processing lemma: tukker (index 72423)
# Processing lemma: tUL (index 72425)
# Processing lemma: tulband (index 72426)
# Processing lemma: tulpeiland (index 72429)
# Processing lemma: tumor (index 72437)
# Processing lemma: Tunesische (index 72442)
# Processing lemma: tunnel (index 72444)
# Processing lemma: tunneldoseren (index 72449)
# Processing lemma: tunneldosering (index 72450)
# Processing lemma: turbomotor (index 72455)
# Processing lemma: tureluur (index 72458)
# Processing lemma: turfkantoor (index 72461)
# Processing lemma: Turk (index 72467)
# Processing lemma: Turkmeen (index 72468)
# Processing lemma: Turkmeense (index 72470)
# Processing lemma: Turks brood (index 72473)
# Processing lemma: Turks fruit (index 72474)
# Processing lemma: Turkse (index 72475)
# Processing lemma: Turkse tortel (index 72476)
# Processing lemma: Turkse tortelduif (index 72477)
# Processing lemma: Turnhoutenaar (index 72485)
# Processing lemma: Turnhoutse (index 72487)
# Processing lemma: turnleraar (index 72488)
# Processing lemma: turnschool (index 72491)
# Processing lemma: turnzaal (index 72495)
# Processing lemma: tussen de soep en de patatten (index 72497)
# Processing lemma: tussen vier muren (index 72498)
# Processing lemma: tussen-de-orensyndroom (index 72510)
# Processing lemma: tussengerecht (index 72520)
# Processing lemma: tussenhandel (index 72524)
# Processing lemma: tussenhandelaar (index 72525)
# Processing lemma: tussenjaar (index 72528)
# Processing lemma: tussenproduct (index 72553)
# Processing lemma: tussenseizoen (index 72561)
# Processing lemma: tussentijd (index 72573)
# Processing lemma: tussenuur (index 72578)
# Processing lemma: tussenw. (index 72588)
# Processing lemma: tussenwervelschijf (index 72592)
# Processing lemma: tut (index 72598)
# Processing lemma: Tutsi (index 72600)
# Processing lemma: tv-babe (index 72606)
# Processing lemma: tv-critica (index 72611)
# Processing lemma: tv-criticus (index 72612)
# Processing lemma: tv-gids (index 72616)
# Processing lemma: tv-kijker (index 72621)
# Processing lemma: TVL (index 72622)
# Processing lemma: tv-maker (index 72624)
# Processing lemma: tv-portret (index 72630)
# Processing lemma: tv-recensent (index 72635)
# Processing lemma: tv-recensente (index 72636)
# Processing lemma: t.w. (index 72649)
# Processing lemma: Twa (index 72650)
# Processing lemma: twaalfde-eeuws (index 72653)
# Processing lemma: twaalfjarige (index 72660)
# Processing lemma: twaalfkantig (index 72661)
# Processing lemma: twarrel (index 72666)
# Processing lemma: twee linkerhanden hebben (index 72671)
# Processing lemma: twee rechterhanden hebben (index 72673)
# Processing lemma: twee vliegen in één klap slaan (index 72677)
# Processing lemma: tweebultige kameel (index 72683)
# Processing lemma: tweede concertmeester (index 72686)
# Processing lemma: tweede cyclus van het hoger onderwijs (index 72687)
# Processing lemma: tweede dirigent (index 72688)
# Processing lemma: tweede elftal (index 72689)
# Processing lemma: tweede eredame (index 72690)
# Processing lemma: tweede harpiste (index 72691)
# Processing lemma: tweede hypotheek (index 72692)
# Processing lemma: Tweede Kamerlid (index 72697)
# Processing lemma: Tweede Kamervoorzitter (index 72700)
# Processing lemma: tweede keeper (index 72702)
# Processing lemma: tweede kerstdag (index 72703)
# Processing lemma: tweede locoburgemeester (index 72704)
# Processing lemma: tweede paasdag (index 72705)
# Processing lemma: tweede violist (index 72706)
# Processing lemma: tweede viool (index 72707)
# Processing lemma: tweede zittijd (index 72708)
# Processing lemma: tweedegeneratieslachtoffer (index 72710)
# Processing lemma: tweedegraads brandwond (index 72711)
# Processing lemma: tweedegraadsdocent (index 72712)
# Processing lemma: tweedegroeper (index 72713)
# Processing lemma: tweedekker (index 72718)
# Processing lemma: tweedeklasser (index 72719)
# Processing lemma: tweedelegvader (index 72720)
# Processing lemma: tweedeverblijver (index 72725)
# Processing lemma: tweehonderdeurobiljet (index 72760)
# Processing lemma: tweejarige (index 72768)
# Processing lemma: tweekantig (index 72771)
# Processing lemma: tweekleurig (index 72773)
# Processing lemma: tweekleurige vleermuis (index 72774)
# Processing lemma: tweelingbroer (index 72782)
# Processing lemma: tweelingbus (index 72783)
# Processing lemma: tweelingzus (index 72788)
# Processing lemma: tweemaster (index 72793)
# Processing lemma: tweemoedergezin (index 72794)
# Processing lemma: tweemotorig (index 72795)
# Processing lemma: tweeoudergezin (index 72798)
# Processing lemma: tweep (index 72799)
# Processing lemma: tweeslachtig (index 72808)
# Processing lemma: tweeslachtige bloem (index 72809)
# Processing lemma: tweeslachtigheid (index 72810)
# Processing lemma: tweesnijdend (index 72811)
# Processing lemma: tweestatusstelsel (index 72814)
# Processing lemma: tweet (index 72817)
# Processing lemma: tweetakt (index 72818)
# Processing lemma: tweeten (index 72822)
# Processing lemma: tweeter (index 72823)
# Processing lemma: tweetrapsmaking (index 72825)
# Processing lemma: tweevadergezin (index 72826)
# Processing lemma: tweeverdiener (index 72827)
# Processing lemma: tweevingertest (index 72829)
# Processing lemma: tweewielaangedreven (index 72835)
# Processing lemma: twen (index 72841)
# Processing lemma: Twent (index 72842)
# Processing lemma: Twentenaar (index 72843)
# Processing lemma: Twentse (index 72845)
# Processing lemma: twerken (index 72846)
# Processing lemma: twexit (index 72847)
# Processing lemma: twintiger (index 72862)
# Processing lemma: twintigeurobiljet (index 72863)
# Processing lemma: twintigjarige (index 72865)
# Processing lemma: twintigkantig (index 72866)
# Processing lemma: twintigste-eeuws (index 72869)
# Processing lemma: twitteraar (index 72875)
# Processing lemma: twitteraarster (index 72876)
# Processing lemma: Twitteractiviteit (index 72877)
# Processing lemma: twitteren (index 72878)
# Processing lemma: Twitterexcursie (index 72879)
# Processing lemma: Twitterspreekuur (index 72880)
# Processing lemma: t.w.v. (index 72882)
# Processing lemma: twv (index 72883)
# Processing lemma: tycoon (index 72884)
# Processing lemma: tyfus (index 72885)
# Processing lemma: type 1-diabetes (index 72887)
# Processing lemma: type 1-patiënt (index 72888)
# Processing lemma: type 2-diabetes (index 72889)
# Processing lemma: type 2-patiënt (index 72890)
# Processing lemma: typecasting (index 72892)
# Processing lemma: typefoutdomein (index 72895)
# Processing lemma: typiste (index 72906)
# Processing lemma: typograaf (index 72907)
# Processing lemma: tyrannosaurus (index 72910)
# Processing lemma: tyrannosaurus rex (index 72911)
# Processing lemma: t.z.t. (index 72912)
# Processing lemma: u aller vriend (index 72914)
# Processing lemma: u beider belang (index 72915)
# Processing lemma: u blieft? (index 72916)
# Processing lemma: UAP (index 72917)
# Processing lemma: U-balk (index 72919)
# Processing lemma: uberisering (index 72921)
# Processing lemma: U-bocht (index 72922)
# Processing lemma: U-boot (index 72923)
# Processing lemma: UCI (index 72924)
# Processing lemma: UCI-ranking (index 72925)
# Processing lemma: UCI-voorzitter (index 72926)
# Processing lemma: UEFA (index 72927)
# Processing lemma: ufo (index 72928)
# Processing lemma: Ugandese (index 72930)
# Processing lemma: ui (index 72931)
# Processing lemma: uiensoep (index 72935)
# Processing lemma: uil (index 72939)
# Processing lemma: uil van Minerva (index 72940)
# Processing lemma: uilachtig (index 72941)
# Processing lemma: uilen broeden uilen (index 72942)
# Processing lemma: uilen naar Athene dragen (index 72943)
# Processing lemma: uilen vliegen met uilen (index 72944)
# Processing lemma: uilenbal (index 72945)
# Processing lemma: uilenbord (index 72946)
# Processing lemma: uilenbril (index 72947)
# Processing lemma: uilenei (index 72948)
# Processing lemma: uilengat (index 72949)
# Processing lemma: uilenjong (index 72950)
# Processing lemma: uilenkast (index 72951)
# Processing lemma: uilennestkast (index 72952)
# Processing lemma: uilenpan (index 72953)
# Processing lemma: uilin (index 72956)
# Processing lemma: uilskuiken (index 72957)
# Processing lemma: uiltje (index 72958)
# Processing lemma: uit ander hout gesneden zijn (index 72961)
# Processing lemma: uit anderen hoofde (index 72962)
# Processing lemma: uit de aard der zaak (index 72963)
# Processing lemma: uit de bloemkool komen (index 72964)
# Processing lemma: uit de bloemkool kruipen (index 72965)
# Processing lemma: uit de boerenkool komen (index 72966)
# Processing lemma: uit de boot dreigen te vallen (index 72967)
# Processing lemma: uit de boot vallen (index 72968)
# Processing lemma: uit de bus komen (index 72969)
# Processing lemma: uit de bus rollen (index 72970)
# Processing lemma: uit de dieperik geraken (index 72971)
# Processing lemma: uit de grond van iemands hart (index 72972)
# Processing lemma: uit de kerk treden (index 72973)
# Processing lemma: uit de kool komen (index 72974)
# Processing lemma: uit de kuiten schudden (index 72975)
# Processing lemma: uit de kunst (index 72976)
# Processing lemma: uit de luiers (index 72977)
# Processing lemma: uit de ruif van iemand of iets mee-eten (index 72978)
# Processing lemma: uit de spruiten komen (index 72979)
# Processing lemma: uit de vaart nemen (index 72980)
# Processing lemma: uit de verte (index 72981)
# Processing lemma: uit de weg gaan (index 72982)
# Processing lemma: uit de weg ruimen (index 72983)
# Processing lemma: uit de weg slepen (index 72984)
# Processing lemma: uit de weg springen (index 72985)
# Processing lemma: uit de weg staan (index 72986)
# Processing lemma: uit de weg zijn (index 72987)
# Processing lemma: uit den boze (index 72988)
# Processing lemma: uit dezelfde ruif eten (index 72989)
# Processing lemma: uit een goed hart (index 72990)
# Processing lemma: uit één mond (index 72991)
# Processing lemma: uit elkaar drijven (index 72992)
# Processing lemma: uit eten (index 72993)
# Processing lemma: uit eten gaan (index 72994)
# Processing lemma: uit het boekje (index 72995)
# Processing lemma: uit het gezicht verdwijnen (index 72996)
# Processing lemma: uit het goede hout gesneden zijn (index 72997)
# Processing lemma: uit het oog, uit het hart (index 72998)
# Processing lemma: uit hetzelfde hout gesneden zijn (index 72999)
# Batch complete. Checkpoint updated to 73000.
# Processing batch starting at index 73000
# Processing lemma: uit hout waarvan men helden maakt (index 73000)
# Processing lemma: uit iemands hand eten (index 73001)
# Processing lemma: uit iemands hart gegrepen (index 73002)
# Processing lemma: uit volle borst (index 73003)
# Processing lemma: uit vroegere decennia (index 73004)
# Processing lemma: uit vroegere eeuwen (index 73005)
# Processing lemma: uit zijn duim zuigen (index 73006)
# Processing lemma: uit zijn kot komen (index 73007)
# Processing lemma: uit zijn neus eten (index 73008)
# Processing lemma: uit zijn neus vreten (index 73009)
# Processing lemma: uit zijn slof schieten (index 73010)
# Processing lemma: uitbaten (index 73024)
# Processing lemma: uitbater (index 73025)
# Processing lemma: uitbehandeld (index 73032)
# Processing lemma: uitblinker (index 73039)
# Processing lemma: uitbreidingsmogelijkheid (index 73053)
# Processing lemma: uitcheckpaal (index 73070)
# Processing lemma: uitclub (index 73071)
# Processing lemma: uitdager (index 73075)
# Processing lemma: uitdrukkingsmogelijkheid (index 73102)
# Processing lemma: uitduel (index 73106)
# Processing lemma: uitentreuren (index 73116)
# Processing lemma: uiterwaard (index 73123)
# Processing lemma: uitfoeteren (index 73124)
# Processing lemma: uitgaansavond (index 73127)
# Processing lemma: uitgaansmogelijkheid (index 73132)
# Processing lemma: uitgavenvermindering (index 73155)
# Processing lemma: uitgekookt (index 73161)
# Processing lemma: uitgerekende datum (index 73168)
# Processing lemma: uitgespeeld doelpunt (index 73169)
# Processing lemma: uitgestotene (index 73172)
# Processing lemma: uitgetelde datum (index 73175)
# Processing lemma: uitgever (index 73177)
# Processing lemma: uitgewekene (index 73186)
# Processing lemma: uithaler (index 73200)
# Processing lemma: uithalerswet (index 73201)
# Processing lemma: uithof (index 73206)
# Processing lemma: uithollen (index 73207)
# Processing lemma: uitkafferen (index 73225)
# Processing lemma: uitkeringspercentage (index 73242)
# Processing lemma: uitkeringstoerisme (index 73249)
# Processing lemma: uitkleedapp (index 73261)
# Processing lemma: uitleentermijn (index 73282)
# Processing lemma: uitlepelen (index 73296)
# Processing lemma: uitlooptermijn (index 73309)
# Processing lemma: uitmatch (index 73316)
# Processing lemma: uitnederlaag (index 73323)
# Processing lemma: uitoverwinning (index 73335)
# Processing lemma: uitpakvideo (index 73337)
# Processing lemma: uitploeg (index 73339)
# Processing lemma: uitpraatprocedure (index 73341)
# Processing lemma: uitpubliek (index 73343)
# Processing lemma: uitroeien (index 73363)
# Processing lemma: uitroepteken (index 73367)
# Processing lemma: uitsmijter (index 73400)
# Processing lemma: uitsnede (index 73401)
# Processing lemma: uitspelend (index 73408)
# Processing lemma: uitspeler (index 73409)
# Processing lemma: uitstelbaby (index 73436)
# Processing lemma: uitstelmoeder (index 73441)
# Processing lemma: uitstelvader (index 73442)
# Processing lemma: uitstroomopening (index 73456)
# Processing lemma: uitvaartbegeleider (index 73473)
# Processing lemma: uitvaarthotel (index 73476)
# Processing lemma: uitvaarttoerisme (index 73480)
# Processing lemma: uitvaarttoerist (index 73481)
# Processing lemma: uitvaartvereniging (index 73482)
# Processing lemma: uitvaren (index 73488)
# Processing lemma: uitverkoop (index 73492)
# Processing lemma: uitveteren (index 73496)
# Processing lemma: uitvinder (index 73498)
# Processing lemma: uitvoerder (index 73513)
# Processing lemma: uitvoerend beslag (index 73517)
# Processing lemma: uitvoerend kunstenaar (index 73518)
# Processing lemma: uitvoeringstermijn (index 73548)
# Processing lemma: uitwedstrijd (index 73563)
# Processing lemma: uitwendige wond (index 73566)
# Processing lemma: uitwijkmogelijkheid (index 73577)
# Processing lemma: uitzaaiing (index 73598)
# Processing lemma: uitzege (index 73600)
# Processing lemma: uitzendtijdstip (index 73617)
# Processing lemma: uitzendwerker (index 73621)
# Processing lemma: uitzichtgarantie (index 73631)
# Processing lemma: uk (index 73661)
# Processing lemma: ukkepuk (index 73662)
# Processing lemma: uloschool (index 73663)
# Processing lemma: ultrabewerkt (index 73666)
# Processing lemma: ultracultuur (index 73667)
# Processing lemma: ultragroep (index 73669)
# Processing lemma: ultramarijn (index 73670)
# Processing lemma: UMTS (index 73673)
# Processing lemma: UMTS-veiling (index 73674)
# Processing lemma: UN (index 73675)
# Processing lemma: unboxen (index 73677)
# Processing lemma: uncanny valley (index 73678)
# Processing lemma: undercover (index 73679)
# Processing lemma: underground (index 73687)
# Processing lemma: unheimisch (index 73690)
# Processing lemma: unheimlich (index 73691)
# Processing lemma: unicorn (index 73693)
# Processing lemma: uniformbroek (index 73702)
# Processing lemma: uniformpet (index 73709)
# Processing lemma: unitarisme (index 73713)
# Processing lemma: unitarist (index 73714)
# Processing lemma: unitaristisch (index 73715)
# Processing lemma: universitair onderwijs (index 73719)
# Processing lemma: universitair ziekenhuis (index 73720)
# Processing lemma: universiteitsdocent (index 73726)
# Processing lemma: universiteitsprofessor (index 73732)
# Processing lemma: universiteitsziekenhuis (index 73738)
# Processing lemma: unleaded (index 73739)
# Processing lemma: unmuten (index 73740)
# Processing lemma: unverfroren (index 73741)
# Processing lemma: upcyclen (index 73742)
# Processing lemma: upcycling (index 73743)
# Processing lemma: updaten (index 73746)
# Processing lemma: updating (index 73747)
# Processing lemma: upgraden (index 73748)
# Processing lemma: uploaden (index 73749)
# Processing lemma: upper ten (index 73750)
# Processing lemma: uppercut (index 73751)
# Processing lemma: U-profiel (index 73752)
# Processing lemma: upskirting (index 73753)
# Processing lemma: uraan (index 73755)
# Processing lemma: uranium (index 73756)
# Processing lemma: uraniumverwerkend (index 73759)
# Processing lemma: urbi et orbi (index 73764)
# Processing lemma: urenlang (index 73766)
# Processing lemma: ureter (index 73767)
# Processing lemma: urethra (index 73768)
# Processing lemma: ureum (index 73769)
# Processing lemma: urilift (index 73773)
# Processing lemma: urinaal (index 73774)
# Processing lemma: urine (index 73775)
# Processing lemma: urineblaas (index 73776)
# Processing lemma: urinebuis (index 73777)
# Processing lemma: urinedrijvend (index 73778)
# Processing lemma: urineleider (index 73779)
# Processing lemma: urinemonster (index 73780)
# Processing lemma: urineonderzoek (index 73781)
# Processing lemma: urineproductie (index 73782)
# Processing lemma: urineren (index 73783)
# Processing lemma: urinestaal (index 73784)
# Processing lemma: urinetest (index 73785)
# Processing lemma: urineverlies (index 73786)
# Processing lemma: urineweg (index 73787)
# Processing lemma: urineweginfectie (index 73788)
# Processing lemma: urinezuur (index 73789)
# Processing lemma: urinezuurgehalte (index 73790)
# Processing lemma: urinoir (index 73791)
# Processing lemma: Urker (index 73792)
# Processing lemma: Urkse (index 73794)
# Processing lemma: URL (index 73795)
# Processing lemma: urologie (index 73798)
# Processing lemma: urologisch (index 73799)
# Processing lemma: uroloog (index 73800)
# Processing lemma: Uruguayaanse (index 73803)
# Processing lemma: Uruguese (index 73805)
# Processing lemma: US (index 73806)
# Processing lemma: USA (index 73807)
# Processing lemma: USADA (index 73808)
# Processing lemma: usance (index 73809)
# Processing lemma: USB-memorystick (index 73810)
# Processing lemma: USB-stick (index 73811)
# Processing lemma: usual suspects (index 73812)
# Processing lemma: usurpator (index 73813)
# Processing lemma: Utrechtenaar (index 73815)
# Processing lemma: Utrechtse (index 73818)
# Processing lemma: UU (index 73819)
# Processing lemma: Uub (index 73820)
# Processing lemma: Uuh (index 73821)
# Processing lemma: Uuo (index 73822)
# Processing lemma: UUP (index 73823)
# Processing lemma: Uuq (index 73824)
# Processing lemma: uur (index 73825)
# Processing lemma: uurtje (index 73832)
# Processing lemma: uurwijzer (index 73835)
# Processing lemma: Uus (index 73836)
# Processing lemma: Uut (index 73837)
# Processing lemma: U-vormig (index 73840)
# Processing lemma: uw dienstwillige dienaar (index 73843)
# Processing lemma: uzi (index 73845)
# Processing lemma: vaandeldrager (index 73858)
# Processing lemma: vaandrig (index 73861)
# Processing lemma: vaar (index 73862)
# Processing lemma: vaar noch vrees kennen (index 73863)
# Processing lemma: vaars (index 73876)
# Processing lemma: vaarseizoen (index 73878)
# Processing lemma: vaarskalf (index 73879)
# Processing lemma: vaart (index 73881)
# Processing lemma: vaartijd (index 73882)
# Processing lemma: vaaruur (index 73886)
# Processing lemma: vaarverbod (index 73888)
# Processing lemma: vacaturesite (index 73904)
# Processing lemma: vacaturestop (index 73905)
# Processing lemma: vacaturewebsite (index 73906)
# Processing lemma: vaccinongelijkheid (index 73917)
# Processing lemma: vader (index 73926)
# Processing lemma: vader des vaderlands (index 73927)
# Processing lemma: Vaderdag (index 73931)
# Processing lemma: vaderhond (index 73935)
# Processing lemma: vaderloos (index 73954)
# Processing lemma: vaderskind (index 73960)
# Processing lemma: VAE (index 73967)
# Processing lemma: va-et-vient (index 73968)
# Processing lemma: vagant (index 73969)
# Processing lemma: vagebond (index 73970)
# Processing lemma: vaginaal suppositorium (index 73973)
# Processing lemma: vaginale suppo (index 73974)
# Processing lemma: vaginale suppositoire (index 73975)
# Processing lemma: vaginale zetpil (index 73976)
# Processing lemma: vakantie aan zee (index 73980)
# Processing lemma: vakantiedag (index 73987)
# Processing lemma: vakantiefoto (index 73992)
# Processing lemma: vakantieganger (index 73993)
# Batch complete. Checkpoint updated to 74000.
# Processing batch starting at index 74000
# Processing lemma: vakantiekiekje (index 74002)
# Processing lemma: vakantiemogelijkheid (index 74007)
# Processing lemma: vakantieseizoen (index 74014)
# Processing lemma: vakantieweek (index 74021)
# Processing lemma: vak.app. (index 74025)
# Processing lemma: vakbondsafgevaardigde (index 74035)
# Processing lemma: vakbondslid (index 74048)
# Processing lemma: vakbondsvoorzitter (index 74057)
# Processing lemma: vakdocent (index 74066)
# Processing lemma: vakfotograaf (index 74068)
# Processing lemma: vakgebied (index 74069)
# Processing lemma: vakgericht (index 74073)
# Processing lemma: vakleerkracht (index 74087)
# Processing lemma: vakleraar (index 74088)
# Processing lemma: vakschool (index 74098)
# Processing lemma: vakwinkelier (index 74112)
# Processing lemma: valavond (index 74116)
# Processing lemma: vale gier (index 74121)
# Processing lemma: vale vleermuis (index 74122)
# Processing lemma: Valentijnsdag (index 74123)
# Processing lemma: valk (index 74133)
# Processing lemma: Valkenburger (index 74135)
# Processing lemma: Valkenburgse (index 74137)
# Processing lemma: valkenier (index 74138)
# Processing lemma: valkparkiet (index 74140)
# Processing lemma: vallen als vliegen (index 74143)
# Processing lemma: valpoli (index 74148)
# Processing lemma: valpolikliniek (index 74149)
# Processing lemma: valreep (index 74150)
# Processing lemma: valscherm (index 74152)
# Processing lemma: valse baard (index 74154)
# Processing lemma: valse gaviaal (index 74155)
# Processing lemma: valse kat (index 74156)
# Processing lemma: valse kroep (index 74157)
# Processing lemma: valse vriend (index 74158)
# Processing lemma: valserik (index 74160)
# Processing lemma: valsevlagoperatie (index 74161)
# Processing lemma: valsimulator (index 74164)
# Processing lemma: valsspeler (index 74167)
# Processing lemma: valutahandelaar (index 74176)
# Processing lemma: vampier (index 74194)
# Processing lemma: van aangezicht tot aangezicht (index 74197)
# Processing lemma: van aard zijn om (index 74198)
# Processing lemma: van alle eeuwen zijn (index 74199)
# Processing lemma: van alle hout blijven (index 74200)
# Processing lemma: van alle hout wegblijven (index 74201)
# Processing lemma: van alle katten kwaad weten (index 74202)
# Processing lemma: van alle ruiven eten (index 74203)
# Processing lemma: van alle ruiven mee-eten (index 74204)
# Processing lemma: van bakboord naar stuurboord zenden (index 74205)
# Processing lemma: van bietjes rood, worden kindertjes groot (index 74206)
# Processing lemma: van bij de aftrap (index 74207)
# Processing lemma: van boord gaan (index 74208)
# Processing lemma: van dag tot dag (index 74209)
# Processing lemma: van dag tot dag leven (index 74210)
# Processing lemma: van de agenda verdwijnen (index 74211)
# Processing lemma: van de agenda zijn (index 74212)
# Processing lemma: van de drank af zijn (index 74213)
# Processing lemma: van de drukpers rollen (index 74214)
# Processing lemma: van de ene dag in de andere leven (index 74215)
# Processing lemma: van de ene dag op de andere (index 74216)
# Processing lemma: van de ene week op de andere (index 74217)
# Processing lemma: van de hoed en de rand weten (index 74218)
# Processing lemma: van de hond zijn kloten (index 74219)
# Processing lemma: van de koek mee-eten (index 74220)
# Processing lemma: van de kruk willen (index 74221)
# Processing lemma: van de morgen tot de avond (index 74222)
# Processing lemma: van de ochtend tot de avond (index 74223)
# Processing lemma: van de ooievaar komen (index 74224)
# Processing lemma: van de os op de ezel springen (index 74225)
# Processing lemma: van de prins geen kwaad weten (index 74226)
# Processing lemma: van de ratten besnuffeld zijn (index 74227)
# Processing lemma: van de regen in de drop (index 74228)
# Processing lemma: van de wagen gevallen zijn (index 74229)
# Processing lemma: van dien aard zijn dat (index 74230)
# Processing lemma: van dik hout zaagt men planken (index 74231)
# Processing lemma: van een doelpunt houden (index 74232)
# Processing lemma: van een glasachtige kou zijn (index 74233)
# Processing lemma: van een kale kip kun je niet plukken (index 74234)
# Processing lemma: van een mug een olifant maken (index 74235)
# Processing lemma: van ganser harte (index 74236)
# Processing lemma: van geen kwaad weten (index 74237)
# Processing lemma: van gevel tot gevel (index 74238)
# Processing lemma: van God en iedereen verlaten (index 74239)
# Processing lemma: van God los (index 74240)
# Processing lemma: van goede familie (index 74241)
# Processing lemma: van goede wil (index 74242)
# Processing lemma: van goeden huize (index 74243)
# Processing lemma: Van Gogh (index 74244)
# Processing lemma: van harte (index 74246)
# Processing lemma: van het doek af spatten (index 74247)
# Processing lemma: van het houtje zijn (index 74248)
# Processing lemma: van het kastje naar de muur sturen (index 74249)
# Processing lemma: van het lam Gods geslagen (index 74250)
# Processing lemma: van hetzelfde deeg zijn (index 74251)
# Processing lemma: van hetzelfde laken een broek (index 74252)
# Processing lemma: van hetzelfde laken een pak (index 74253)
# Processing lemma: van iemands gezicht af te lezen vallen (index 74254)
# Processing lemma: van iemands gezicht af te lezen zijn (index 74255)
# Processing lemma: van jongere datum (index 74256)
# Processing lemma: van kop naar kont schillen (index 74257)
# Processing lemma: van kop tot staart (index 74258)
# Processing lemma: van kop tot teen (index 74259)
# Processing lemma: van krantenjongen tot miljonair (index 74260)
# Processing lemma: van krantenjongen tot persmagnaat (index 74261)
# Processing lemma: van kromme haas gebaren (index 74262)
# Processing lemma: van kwaad naar erger gaan (index 74263)
# Processing lemma: van kwaad tot erger gaan (index 74264)
# Processing lemma: van kwaad tot erger vervallen (index 74265)
# Processing lemma: van kwade wil (index 74266)
# Processing lemma: van kwade zin (index 74267)
# Processing lemma: van latere datum (index 74268)
# Processing lemma: van mond tot mond gaan (index 74269)
# Processing lemma: van oor tot oor glimmen (index 74270)
# Processing lemma: van oor tot oor glunderen (index 74271)
# Processing lemma: van oor tot oor stralen (index 74272)
# Processing lemma: van oudere datum (index 74273)
# Processing lemma: van recente datum (index 74274)
# Processing lemma: van recentere datum (index 74275)
# Processing lemma: van 's avonds (index 74276)
# Processing lemma: van 's morgens tot 's avonds (index 74277)
# Processing lemma: van stavast (index 74278)
# Processing lemma: van stonde af aan (index 74279)
# Processing lemma: van tijd tot tijd (index 74280)
# Processing lemma: van twee kwaden het beste kiezen (index 74281)
# Processing lemma: van twee walletjes eten (index 74282)
# Processing lemma: van uur noch tijd weten (index 74283)
# Processing lemma: van vroegere datum (index 74284)
# Processing lemma: van wedstrijd tot wedstrijd (index 74285)
# Processing lemma: van week tot week (index 74286)
# Processing lemma: van zijn à propos raken (index 74287)
# Processing lemma: van zijn à propos zijn (index 74288)
# Processing lemma: van zijn hart een steen maken (index 74289)
# Processing lemma: van zijn hart geen moordkuil maken (index 74290)
# Processing lemma: van zijn kruk vallen (index 74291)
# Processing lemma: van zijn paard vallen (index 74292)
# Processing lemma: vanaf de eerste dag (index 74295)
# Processing lemma: vanaf 's avonds (index 74296)
# Processing lemma: vanavond (index 74297)
# Processing lemma: vandaag de dag (index 74299)
# Processing lemma: vandaal (index 74300)
# Processing lemma: vandaalbestendig (index 74301)
# Processing lemma: vandalisme (index 74305)
# Processing lemma: vandalismebestendig (index 74306)
# Processing lemma: vandehands paard (index 74308)
# Processing lemma: vangletsel (index 74315)
# Processing lemma: vanille (index 74327)
# Processing lemma: vanilleseks (index 74330)
# Processing lemma: vanillevla (index 74332)
# Processing lemma: vanmiddag (index 74333)
# Processing lemma: vanmorgen (index 74334)
# Processing lemma: vannacht (index 74335)
# Processing lemma: vannamiddag (index 74336)
# Processing lemma: vanochtend (index 74337)
# Processing lemma: vape (index 74350)
# Processing lemma: vapen (index 74351)
# Processing lemma: vaper (index 74352)
# Processing lemma: varaan (index 74353)
# Processing lemma: varen (index 74354)
# Processing lemma: varen onder de vlag van iets (index 74355)
# Processing lemma: varen onder een bepaalde vlag (index 74356)
# Processing lemma: varen op het kompas van iets of iemand (index 74357)
# Processing lemma: varen op iets (index 74358)
# Processing lemma: variabele werkuren (index 74362)
# Processing lemma: variété (index 74369)
# Processing lemma: varken (index 74371)
# Processing lemma: varkensboer (index 74374)
# Processing lemma: varkensfricandeau (index 74376)
# Processing lemma: varkenshaas (index 74377)
# Processing lemma: varkenshaasje (index 74378)
# Processing lemma: varkenshouder (index 74381)
# Processing lemma: varkenslap (index 74384)
# Processing lemma: varkenslapje (index 74385)
# Processing lemma: varkensleren (index 74386)
# Processing lemma: varkentje (index 74399)
# Processing lemma: varroamijt (index 74400)
# Processing lemma: vasculaire dementie (index 74401)
# Processing lemma: vasopressine (index 74402)
# Processing lemma: vasovagale collaps (index 74403)
# Processing lemma: vast bezoekuur (index 74405)
# Processing lemma: vast voorzetsel (index 74406)
# Processing lemma: vaste arbeider (index 74412)
# Processing lemma: vaste conducteur (index 74413)
# Processing lemma: vaste dag (index 74414)
# Processing lemma: vaste datum (index 74415)
# Processing lemma: vaste hengel (index 74416)
# Processing lemma: vaste lupine (index 74417)
# Processing lemma: vaste wastafel (index 74418)
# Processing lemma: vaste werkuren (index 74419)
# Processing lemma: Vastenavond (index 74423)
# Processing lemma: vastendag (index 74426)
# Processing lemma: vastentijd (index 74429)
# Processing lemma: vasteplantenteelt (index 74430)
# Processing lemma: vastestofbatterij (index 74431)
# Processing lemma: vastgoedbubbel (index 74438)
# Processing lemma: vastgoedhandelaar (index 74442)
# Processing lemma: vastgoedmakelaar (index 74444)
# Processing lemma: vastgoedstylist (index 74448)
# Processing lemma: vastgoedzeepbel (index 74450)
# Processing lemma: vastkokend (index 74459)
# Processing lemma: vastkokende aardappel (index 74460)
# Processing lemma: vatbom (index 74477)
# Processing lemma: vazal (index 74479)
# Processing lemma: vbo-leerling (index 74481)
# Processing lemma: vbo-school (index 74482)
# Processing lemma: v.d. (index 74483)
# Processing lemma: v.e. (index 74485)
# Processing lemma: vechten als een leeuw (index 74488)
# Processing lemma: vechten tegen de bierkaai (index 74489)
# Processing lemma: vechten tegen windmolens (index 74490)
# Processing lemma: vechtersbaas (index 74493)
# Processing lemma: vechthond (index 74496)
# Processing lemma: vechtkunstschool (index 74499)
# Processing lemma: vechtsportschool (index 74505)
# Processing lemma: vedel (index 74508)
# Processing lemma: veearts (index 74513)
# Processing lemma: veeboer (index 74519)
# Processing lemma: veedrijver (index 74521)
# Processing lemma: veehandelaar (index 74528)
# Processing lemma: veehouder (index 74530)
# Processing lemma: veejay (index 74533)
# Processing lemma: veekoopman (index 74535)
# Processing lemma: veel, te veel aan zijn kop hebben (index 74537)
# Processing lemma: veel bekijks hebben (index 74538)
# Processing lemma: veel bekijks krijgen (index 74539)
# Processing lemma: veel bekijks trekken (index 74540)
# Processing lemma: veel geschreeuw en weinig wol (index 74541)
# Processing lemma: veel hart hebben voor iets of iemand (index 74542)
# Processing lemma: veel zweet kosten (index 74543)
# Processing lemma: veelbekeken (index 74545)
# Processing lemma: veelbekroond (index 74546)
# Processing lemma: veelbeluisterd (index 74548)
# Processing lemma: veelbeproefd (index 74549)
# Processing lemma: veelbeschreven (index 74550)
# Processing lemma: veelbesproken (index 74551)
# Processing lemma: veelbewogen (index 74553)
# Processing lemma: veelgeciteerd (index 74556)
# ...
# Processing lemma: zout (index 86444)
# Processing lemma: zout in de wond strooien (index 86445)
# Processing lemma: zout in de wond wrijven (index 86446)
# Processing lemma: zout water (index 86447)
# Processing lemma: zoutarm (index 86450)
# Processing lemma: zoutarm dieet (index 86451)
# Processing lemma: zoutbrug (index 86453)
# Processing lemma: zoute drop (index 86454)
# Processing lemma: zoute kwel (index 86455)
# Processing lemma: zoute stengel (index 86456)
# Processing lemma: zoute zondag (index 86457)
# Processing lemma: zouteloos (index 86458)
# Processing lemma: zouten (index 86460)
# Processing lemma: zoutgehalte (index 86462)
# Processing lemma: zoutje (index 86465)
# Processing lemma: zoutkoepel (index 86466)
# Processing lemma: zoutlaag (index 86469)
# Processing lemma: zoutloket (index 86470)
# Processing lemma: zoutloos (index 86471)
# Processing lemma: zoutloos dieet (index 86472)
# Processing lemma: zoutmeer (index 86474)
# Processing lemma: zoutmijn (index 86475)
# Processing lemma: zoutoplossing (index 86478)
# Processing lemma: zoutpan (index 86479)
# Processing lemma: zoutpilaar (index 86480)
# Processing lemma: zouttong (index 86483)
# Processing lemma: zoutvaatje (index 86484)
# Processing lemma: zoutvlakte (index 86485)
# Processing lemma: zoutvlees (index 86486)
# Processing lemma: zoutvleesemmer (index 86487)
# Processing lemma: zoutwatervis (index 86490)
# Processing lemma: zoutwinning (index 86491)
# Processing lemma: zoutzak (index 86492)
# Processing lemma: zoutzuur (index 86494)
# Processing lemma: zoveel geven om iets als een boer om een kers (index 86496)
# Processing lemma: zoveel jaar na datum (index 86497)
# Processing lemma: z.o.z. (index 86501)
# Processing lemma: z.p. (index 86503)
# Processing lemma: z.pl. (index 86504)
# Processing lemma: Z-profiel (index 86505)
# Processing lemma: Zr (index 86506)
# Processing lemma: z.s.m. (index 86507)
# Processing lemma: z.u. (index 86508)
# Processing lemma: Zuid-Afrikaan (index 86514)
# Processing lemma: Zuid-Afrikaanse (index 86516)
# Processing lemma: Zuid-Amerikaan (index 86517)
# Processing lemma: Zuid-Amerikaanse (index 86519)
# Processing lemma: Zuid-Europeaan (index 86534)
# Processing lemma: Zuid-Europeaanse (index 86536)
# Processing lemma: Zuid-Europese (index 86538)
# Processing lemma: Zuid-Hollander (index 86541)
# Processing lemma: Zuid-Hollandse (index 86543)
# Processing lemma: zuidkaper (index 86544)
# Processing lemma: Zuid-Koreaan (index 86545)
# Processing lemma: Zuid-Koreaanse (index 86547)
# Processing lemma: zuidwaarts (index 86556)
# Processing lemma: zuidwester (index 86559)
# Processing lemma: zuigende borstwond (index 86566)
# Processing lemma: zuigende luis (index 86567)
# Processing lemma: zuigermotor (index 86570)
# Processing lemma: zuigfles (index 86573)
# Processing lemma: zuiglam (index 86576)
# Processing lemma: zuilvormig (index 86590)
# Processing lemma: zuipbus (index 86594)
# Processing lemma: zuipen als een zwijn (index 86595)
# Processing lemma: zuipkeet (index 86598)
# Processing lemma: zuiplap (index 86599)
# Processing lemma: zuiptoerisme (index 86602)
# Processing lemma: zuivelhulp (index 86610)
# Processing lemma: zuivelindustrie (index 86611)
# Processing lemma: zuiver goud (index 86618)
# Processing lemma: zuivere alcohol (index 86620)
# Processing lemma: zuiveringsstation (index 86636)
# Processing lemma: zuiveringszout (index 86639)
# Processing lemma: zumba (index 86643)
# Processing lemma: zure druiven (index 86644)
# Processing lemma: zure kers (index 86645)
# Processing lemma: zure melk (index 86646)
# Processing lemma: zure neerslag (index 86647)
# Processing lemma: zure regen (index 86648)
# Processing lemma: zure room (index 86649)
# Processing lemma: zure wijn (index 86650)
# Processing lemma: zure zult (index 86651)
# Processing lemma: zuring (index 86655)
# Processing lemma: zuringpollen (index 86656)
# Processing lemma: zuringstuifmeel (index 86657)
# Processing lemma: zuringzout (index 86658)
# Processing lemma: zus (index 86660)
# Processing lemma: zus en zo (index 86661)
# Processing lemma: zus en zoveel (index 86662)
# Processing lemma: zus of zo (index 86663)
# Processing lemma: zuster (index 86665)
# Processing lemma: zusterhuis (index 86668)
# Processing lemma: zusterschip (index 86676)
# Processing lemma: zustervereniging (index 86680)
# Processing lemma: Zutphenaar (index 86681)
# Processing lemma: Zutphense (index 86683)
# Processing lemma: zuur brood (index 86685)
# Processing lemma: zuur lachen (index 86686)
# Processing lemma: zuur vaatje bier (index 86687)
# Processing lemma: zuur zout (index 86688)
# Processing lemma: zuurgoed (index 86691)
# Processing lemma: zuurkool (index 86696)
# Processing lemma: zuurlinks (index 86697)
# Processing lemma: zuurpruim (index 86698)
# Processing lemma: zuurstofarm (index 86703)
# Processing lemma: zuurstofbar (index 86704)
# Processing lemma: zuurstoflievende bacterie (index 86711)
# Processing lemma: zuurstofloos (index 86712)
# Processing lemma: zuurstofloosheid (index 86713)
# Processing lemma: zuurstofrijk (index 86717)
# Processing lemma: zuurstok (index 86725)
# Processing lemma: zuurtje (index 86729)
# Processing lemma: zuurwater (index 86733)
# Processing lemma: zuurzak (index 86734)
# Processing lemma: zvp (index 86736)
# Processing lemma: zwaaimoment (index 86742)
# Processing lemma: zwaan (index 86743)
# Processing lemma: zwaan-kleef-aan (index 86744)
# Processing lemma: zwaar geweer (index 86749)
# Processing lemma: zwaar verkeer (index 86750)
# Processing lemma: zwaar vervoer (index 86751)
# Processing lemma: zwaarbeladen (index 86752)
# Processing lemma: zwaarbepakt (index 86753)
# Processing lemma: zwaarbeproefd (index 86754)
# Processing lemma: zwaarbeveiligd (index 86755)
# Processing lemma: zwaarbevochten (index 86756)
# Processing lemma: zwaarbewolkt (index 86758)
# Processing lemma: zwaardvis (index 86762)
# Processing lemma: zwaardwalvis (index 86764)
# Processing lemma: zwaargewond (index 86767)
# Processing lemma: zwaargewonde (index 86768)
# Processing lemma: zwabber (index 86781)
# Processing lemma: zwachtelen (index 86784)
# Processing lemma: zwager (index 86785)
# Processing lemma: zwageres (index 86786)
# Processing lemma: zwagerin (index 86787)
# Processing lemma: zwakke AI (index 86792)
# Processing lemma: zwakke frank (index 86793)
# Processing lemma: zwakke weggebruiker (index 86794)
# Processing lemma: zwakkeling (index 86796)
# Processing lemma: zwakzinnige (index 86802)
# Processing lemma: zwaluw (index 86809)
# Processing lemma: Zwammerdammer (index 86812)
# Processing lemma: Zwammerdamse (index 86814)
# Processing lemma: zwamp (index 86817)
# Processing lemma: zwampvis (index 86818)
# Processing lemma: zwangerschap (index 86821)
# Processing lemma: zwangerschapsbikini (index 86824)
# Processing lemma: zwangerschapsweek (index 86835)
# Processing lemma: zwans (index 86836)
# Processing lemma: zwanzen (index 86837)
# Processing lemma: zware fond (index 86838)
# Processing lemma: zware siroop (index 86839)
# Processing lemma: zware wijn (index 86840)
# Processing lemma: zware zee (index 86841)
# Processing lemma: zware zeegang (index 86842)
# Processing lemma: zwart (index 86844)
# Processing lemma: zwart brood (index 86845)
# Processing lemma: zwart brood eten (index 86846)
# Processing lemma: zwart gat (index 86847)
# Processing lemma: zwart kruit (index 86848)
# Processing lemma: zwart schaap (index 86849)
# Processing lemma: zwart zien van de mensen (index 86850)
# Processing lemma: zwart zien van het volk (index 86851)
# Processing lemma: zwartbruin (index 86855)
# Processing lemma: zwartbuikhamster (index 86856)
# Processing lemma: zwarte baars (index 86858)
# Processing lemma: zwarte band (index 86859)
# Processing lemma: Zwarte Beertjes (index 86860)
# Processing lemma: zwarte bes (index 86861)
# Processing lemma: zwarte bladzijde (index 86862)
# Processing lemma: zwarte bosbes (index 86863)
# Processing lemma: zwarte cijfers (index 86864)
# Processing lemma: zwarte comedo (index 86865)
# Processing lemma: zwarte dag (index 86866)
# Processing lemma: zwarte dinsdag (index 86867)
# Processing lemma: zwarte donderdag (index 86868)
# Processing lemma: Zwarte Dood (index 86869)
# Processing lemma: zwarte doos (index 86870)
# Processing lemma: zwarte dwerg (index 86871)
# Processing lemma: zwarte fraude (index 86872)
# Processing lemma: zwarte koolvis (index 86873)
# Processing lemma: zwarte kunst (index 86874)
# Processing lemma: zwarte lijst (index 86875)
# Processing lemma: zwarte maandag (index 86876)
# Processing lemma: zwarte madonna (index 86877)
# Processing lemma: zwarte magie (index 86878)
# Processing lemma: zwarte mamba (index 86879)
# Processing lemma: zwarte mangrove (index 86880)
# Processing lemma: zwarte markt (index 86881)
# Processing lemma: zwarte mees (index 86882)
# Processing lemma: zwarte mier (index 86883)
# Processing lemma: zwarte neushoorn (index 86884)
# Processing lemma: zwarte ooievaar (index 86885)
# Processing lemma: zwarte peper (index 86886)
# Processing lemma: zwarte pest (index 86887)
# Processing lemma: Zwarte Piet (index 86888)
# Processing lemma: zwarte rat (index 86889)
# Processing lemma: zwarte reiger (index 86890)
# Processing lemma: zwarte roodstaart (index 86891)
# Processing lemma: zwarte school (index 86892)
# Processing lemma: zwarte specht (index 86893)
# Processing lemma: zwarte stern (index 86894)
# Processing lemma: zwarte thee (index 86895)
# Processing lemma: zwarte trui (index 86896)
# Processing lemma: zwarte vrijdag (index 86897)
# Processing lemma: zwarte weduwe (index 86898)
# Processing lemma: zwarte werkster (index 86899)
# Processing lemma: zwarte woensdag (index 86900)
# Processing lemma: Zwarte Woud (index 86901)
# Processing lemma: zwarte wouw (index 86902)
# Processing lemma: zwarte zaterdag (index 86903)
# Processing lemma: Zwarte Zee (index 86904)
# Processing lemma: zwarte zee-eend (index 86905)
# Processing lemma: zwarte zondag (index 86906)
# Processing lemma: zwarte zwaan (index 86907)
# Processing lemma: zwartekoppenziekte (index 86908)
# Processing lemma: zwartepiet (index 86909)
# Processing lemma: zwartgelakt (index 86911)
# Processing lemma: zwartgerokt (index 86913)
# Processing lemma: zwartgeverfd (index 86914)
# Processing lemma: zwartgeverfde lippen (index 86915)
# Processing lemma: zwartgeverfde ogen (index 86916)
# Processing lemma: zwarthandel (index 86918)
# Processing lemma: zwarthandelaar (index 86919)
# Processing lemma: zwartharig (index 86920)
# Processing lemma: zwartkop (index 86926)
# Processing lemma: zwartleren (index 86927)
# Processing lemma: zwart-op-wit (index 86929)
# Processing lemma: zwartspaarder (index 86931)
# Processing lemma: zwartspeler (index 86932)
# Processing lemma: zwarttanker (index 86933)
# Processing lemma: zwartvissen (index 86934)
# Processing lemma: zwartvisser (index 86935)
# Processing lemma: zwartvoetkat (index 86937)
# Processing lemma: zwartwerker (index 86939)
# Processing lemma: zwavelarm (index 86948)
# Processing lemma: zwavelarm dieet (index 86949)
# Processing lemma: zwavelarm eten (index 86950)
# Processing lemma: zwavelarme diesel (index 86951)
# Processing lemma: zwavelgehalte (index 86953)
# Processing lemma: zwavelrijk (index 86958)
# Processing lemma: zwavelrijke bron (index 86959)
# Processing lemma: zwavelvrij (index 86963)
# Processing lemma: zwavelzure ammoniak (index 86964)
# Processing lemma: zwavelzuur (index 86965)
# Processing lemma: Zweed (index 86966)
# Processing lemma: Zweeds wittebrood (index 86968)
# Processing lemma: Zweedse (index 86969)
# Processing lemma: Zweedse gehaktbal (index 86970)
# Processing lemma: zweefbaan (index 86971)
# Processing lemma: zweefbij (index 86972)
# Processing lemma: zweeftrein (index 86978)
# Processing lemma: zweef-tv (index 86979)
# Processing lemma: zweeppartij (index 86984)
# Processing lemma: zweepworm (index 86985)
# Processing lemma: zweer (index 86986)
# Processing lemma: zweet (index 86987)
# Processing lemma: zweet en bloed kosten (index 86988)
# Processing lemma: zweethond (index 86994)
# Processing lemma: zweethut (index 86995)
# Processing lemma: zweetklier (index 86998)
# Batch complete. Checkpoint updated to 87000.
# Processing batch starting at index 87000
# Processing lemma: zweetvos (index 87003)
# Processing lemma: zwelling (index 87008)
# Processing lemma: zwembadbestuur (index 87011)
# Processing lemma: zwembadpas (index 87012)
# Processing lemma: zwembadpersoneel (index 87013)
# Processing lemma: zwembadprotocol (index 87014)
# Processing lemma: zwembadverbod (index 87015)
# Processing lemma: zwembadwater (index 87016)
# Processing lemma: zwembond (index 87020)
# Processing lemma: zwembroek (index 87021)
# Processing lemma: zwemclub (index 87022)
# Processing lemma: zwemdok (index 87024)
# Processing lemma: zwemeend (index 87025)
# Processing lemma: zwemfederatie (index 87027)
# Processing lemma: zwemgelegenheid (index 87028)
# Processing lemma: zwemkampioenschap (index 87034)
# Processing lemma: zwemkom (index 87036)
# Processing lemma: zwemleraar (index 87039)
# Processing lemma: zwemmen (index 87041)
# Processing lemma: zwemmen als een rat (index 87042)
# Processing lemma: zwemmen als een vis (index 87043)
# Processing lemma: zwemmen in het geld (index 87044)
# Processing lemma: zwempak (index 87048)
# Processing lemma: zwemschool (index 87053)
# Processing lemma: zwemseizoen (index 87054)
# Processing lemma: zwemselectie (index 87055)
# Processing lemma: zwemslag (index 87056)
# Processing lemma: zwemsport (index 87057)
# Processing lemma: zwemverbod (index 87061)
# Processing lemma: zwemvereniging (index 87062)
# Processing lemma: zwemvest (index 87063)
# Processing lemma: zwemvierdaagse (index 87064)
# Processing lemma: zwemvleugel (index 87066)
# Processing lemma: zwemvlies (index 87067)
# Processing lemma: zwemwedstrijd (index 87071)
# Processing lemma: zwemweek (index 87072)
# Processing lemma: zwendelaar (index 87073)
# Processing lemma: zwerfauto (index 87082)
# Processing lemma: zwerfbus (index 87083)
# Processing lemma: zwerffiets (index 87085)
# Processing lemma: zwerfhond (index 87086)
# Processing lemma: zwerfie (index 87087)
# Processing lemma: zwerfkapitaal (index 87090)
# Processing lemma: zwerfkapitalist (index 87091)
# Processing lemma: zwerfkat (index 87092)
# Processing lemma: zwerfkind (index 87094)
# Processing lemma: zwerflawaai (index 87095)
# Processing lemma: zwerfpension (index 87097)
# Processing lemma: zwerfwagen (index 87102)
# Processing lemma: zwerfzwangere (index 87103)
# Processing lemma: zwerkbal (index 87105)
# Processing lemma: zwermintelligentie (index 87108)
# Processing lemma: zwerver (index 87111)
# Processing lemma: zwerverspension (index 87114)
# Processing lemma: zweten als een os (index 87116)
# Processing lemma: zweten als een otter (index 87117)
# Processing lemma: zweten als een rund (index 87118)
# Processing lemma: zwetsen (index 87120)
# Processing lemma: zweven (index 87122)
# Processing lemma: zwexit (index 87128)
# Processing lemma: zwezerik (index 87129)
# Processing lemma: zwijgcultuur (index 87138)
# Processing lemma: zwijgdemonstratie (index 87139)
# Processing lemma: zwijggeld (index 87143)
# Processing lemma: zwijgprotest (index 87146)
# Processing lemma: zwijgrecht (index 87147)
# Processing lemma: zwijgschikking (index 87148)
# Processing lemma: zwijn (index 87155)
# Processing lemma: Zwijndrechtenaar (index 87157)
# Processing lemma: Zwijndrechter (index 87158)
# Processing lemma: Zwijndrechts (index 87159)
# Processing lemma: Zwijndrechtse (index 87160)
# Processing lemma: Zwijndrechtse wijnpeer (index 87161)
# Processing lemma: zwijnneusrat (index 87166)
# Processing lemma: zwijntje (index 87167)
# Processing lemma: zwik (index 87169)
# Processing lemma: zwikken (index 87171)
# Processing lemma: Zwitser (index 87175)
# Processing lemma: zwitserlevengevoel (index 87176)
# Processing lemma: Zwitsers zakmes (index 87178)
# Processing lemma: Zwitserse (index 87179)
# Processing lemma: Zwitserse wachters (index 87180)
# Processing lemma: zwoegen als een paard (index 87183)
# Processing lemma: zwoeger (index 87184)
# Processing lemma: Zwollenaar (index 87189)
# Processing lemma: Zwolse (index 87191)
# Processing lemma: zzp'en (index 87193)
# Processing lemma: zzp'er (index 87194)
# Processing lemma: ZZS (index 87195)
# Batch complete. Checkpoint updated to 88000.
# All batches processed.
# Results written to /content/drive/My Drive/Colab Notebooks/Thesis/definitions.tsv
# Lemmas missing definitions have been saved to /content/drive/My Drive/Colab Notebooks/Thesis/missing_definitions.txt

# %% [markdown]
# ## Convert to a Hugging Face Dataset

# %%
# !pip install datasets  # If you haven't already installed HF datasets

import pandas as pd
from datasets import Dataset, DatasetDict
# Out:
# Collecting datasets
#   Downloading datasets-3.3.2-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets) (3.17.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets) (4.67.1)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec<=2024.12.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets) (2024.10.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.12)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.28.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2025.1.31)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Downloading datasets-3.3.2-py3-none-any.whl (485 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.4/485.4 kB 30.0 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 11.7 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 12.6 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 15.9 MB/s eta 0:00:00
# Installing collected packages: xxhash, dill, multiprocess, datasets
# Successfully installed datasets-3.3.2 dill-0.3.8 multiprocess-0.70.16 xxhash-3.5.0

# %%
# Adjust this path to where your 'definitions.tsv' is located
tsv_path = "/content/drive/My Drive/Colab Notebooks/Thesis/definitions_run1.tsv"

df = pd.read_csv(tsv_path, sep="\t")

print("DataFrame columns:", df.columns.tolist())
print("Number of rows:", len(df))
df.head()
# Out:
# DataFrame columns: ['Lemma', 'POS', 'MeaningNumber', 'LemmaID', 'MeaningID', 'DefinitionFull', 'DefinitionShort']
# Number of rows: 43217
#                    Lemma          POS MeaningNumber  LemmaID  MeaningID  \
# 0              06-dealer  substantief           1.0   190832     190834
# 1              06-nummer  substantief           1.0      207        208
# 2         06-prostitutie  substantief           1.0   285832     285833
# 3      1,5 metereconomie  substantief           1.0   902410     907694
# 4  1,5 metermaatschappij  substantief           1.0   909355     909359
#
#                                       DefinitionFull  \
# 0  drugsdealer die via zijn mobiele telefoon een ...
# 1  nummer van een mobiele telefoon; mobieletelefo...
# 2  vorm van illegale prostitutie waarbij prostitu...
# 3  economisch systeem waarin mensen die niet tot ...
# 4  maatschappij waarin mensen die niet tot hetzel...
#
#                                 DefinitionShort
# 0         drugsdealer die via zijn mobiel werkt
# 1                         mobieletelefoonnummer
# 2          prostitutie via een mobiele telefoon
# 3    economie waarin fysieke afstand de norm is
# 4  maatschappij waarin fysieke afstand nodig is

# %%
# Convert the entire DataFrame to a Dataset
hf_dataset = Dataset.from_pandas(df)

# Check some rows
hf_dataset
# Out:
# Dataset({
#     features: ['Lemma', 'POS', 'MeaningNumber', 'LemmaID', 'MeaningID', 'DefinitionFull', 'DefinitionShort'],
#     num_rows: 43217
# })

# %%
hf_dataset[0]  # See first row
# Out:
# {'Lemma': '06-dealer',
#  'POS': 'substantief',
#  'MeaningNumber': '1.0',
#  'LemmaID': 190832,
#  'MeaningID': 190834,
#  'DefinitionFull': 'drugsdealer die via zijn mobiele telefoon een bestelling voor drugs doorkrijgt en deze vervolgens op afspraak aflevert',
#  'DefinitionShort': 'drugsdealer die via zijn mobiel werkt'}

# %%
# Saving the dataset in the Arrow fromat (default for HF Datasets)
hf_dataset.save_to_disk("/content/drive/My Drive/Colab Notebooks/Thesis/definitions_dataset")
# Out:
# Saving the dataset (0/1 shards):   0%|          | 0/43217 [00:00<?, ? examples/s]

# %%
# Later I can reload it:
from datasets import load_from_disk
loaded_dataset = load_from_disk("/content/drive/My Drive/Colab Notebooks/Thesis/definitions_dataset")
loaded_dataset

# %%
# !pip install huggingface_hub
from huggingface_hub import notebook_login

notebook_login()
# Out:
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.11/dist-packages (0.28.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface_hub) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub) (2024.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface_hub) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub) (2025.1.31)
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
# Pushing to Hugging Face Hub
hf_dataset.push_to_hub("RobbedoesHF/definitions-dataset1", private=True)
# Out:
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Creating parquet from Arrow format:   0%|          | 0/44 [00:00<?, ?ba/s]
# CommitInfo(commit_url='https://huggingface.co/datasets/RobbedoesHF/definitions-dataset1/commit/d9f3954b9f07a39dd3e70d964d835cff6ff61e66', commit_message='Upload dataset', commit_description='', oid='d9f3954b9f07a39dd3e70d964d835cff6ff61e66', pr_url=None, repo_url=RepoUrl('https://huggingface.co/datasets/RobbedoesHF/definitions-dataset1', endpoint='https://huggingface.co', repo_type='dataset', repo_id='RobbedoesHF/definitions-dataset1'), pr_revision=None, pr_num=None)
